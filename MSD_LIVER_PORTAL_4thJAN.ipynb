# %%
import os
import numpy as np
import pandas as pd
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import Callback
import tensorflow as tf
import nibabel as nib
import matplotlib.pyplot as plt
from scipy.ndimage import zoom
from skimage.morphology import binary_dilation, binary_erosion
from skimage.transform import resize

def resize_image(image, target_shape):
    # Resize the image using skimage.resize to match the target shape
    resized_image = resize(image, target_shape, mode='constant', preserve_range=True)
    return resized_image

# %%
# Define Dice coefficient
def dice_coefficient(y_true, y_pred):
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) + 1)

# Define Jaccard index
def jaccard_index(y_true, y_pred):
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
    return (intersection + 1) / (tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) - intersection + 1)

# Define Boundary F1 Score
def boundary_f1_score(y_true, y_pred, dilation_radius=1):
    def get_boundary(mask, dilation_radius):
        dilation = binary_dilation(mask, selem=np.ones((dilation_radius, dilation_radius, dilation_radius)))
        erosion = binary_erosion(mask, selem=np.ones((dilation_radius, dilation_radius, dilation_radius)))
        return np.logical_xor(dilation, erosion)

    y_true_boundary = get_boundary(y_true.astype(np.bool_), dilation_radius)
    y_pred_boundary = get_boundary(y_pred.astype(np.bool_), dilation_radius)

    intersection = np.sum(y_true_boundary & y_pred_boundary)
    precision = intersection / (np.sum(y_pred_boundary) + 1e-6)
    recall = intersection / (np.sum(y_true_boundary) + 1e-6)
    return 2 * precision * recall / (precision + recall + 1e-6)

# %%
# Load the saved model
model_path = 'unet3d_best_model.h5'
if not os.path.exists(model_path):
    raise FileNotFoundError(f"Model file not found: {model_path}")

model = load_model(model_path, custom_objects={'dice_coefficient': dice_coefficient, 'jaccard_index': jaccard_index, 'boundary_f1_score' : boundary_f1_score})

# %%
def load_nifti_memmap(img_path):
    
    
    img = nib.load(img_path)
    data = img.get_fdata(dtype=np.float32, caching='unchanged')  # Memory-mapped array
    affine = img.affine
    header = img.header
    return data, affine, header

def resize_volume(volume, target_shape):
    """
    Resizes a 3D volume to the target shape using interpolation.

    Args:
        volume (numpy.ndarray): Input 3D volume.
        target_shape (tuple): Target shape (depth, height, width).

    Returns:
        numpy.ndarray: Resized 3D volume.
    """
    factors = (
        target_shape[0] / volume.shape[0],
        target_shape[1] / volume.shape[1],
        target_shape[2] / volume.shape[2]
    )
    resized_volume = zoom(volume, factors, order=1)  # Order=1 for linear interpolation
    return resized_volume

def resize_image(image, target_shape):
    # Resize the image to match the target shape (height, width)
    return resize(image, target_shape, preserve_range=True, anti_aliasing=True)

def pad_or_crop_volume(volume, target_shape):
    current_shape = volume.shape
    
    # Calculate padding width for each dimension
    pad_width = [(0, max(target_shape[i] - current_shape[i], 0)) for i in range(3)]
    
    # Pad the volume to the target shape
    volume = np.pad(volume, pad_width, mode='constant', constant_values=0)
    
    # Calculate cropping dimensions for each dimension
    crop_start = [(volume.shape[i] - target_shape[i]) // 2 for i in range(3)]
    crop_end = [crop_start[i] + target_shape[i] for i in range(3)]
    
    # Crop the volume to the target shape
    slices = [slice(crop_start[i], crop_end[i]) for i in range(3)]
    volume = volume[slices[0], slices[1], slices[2]]
    
    return volume

# %%
# Define the testing generator
#os.environ["TF_GPU_ALLOCATOR"]="cuda_malloc_async"
#tf.config.LogicalDeviceConfiguration(memory_limit=10240000)
def data_generator(file_list, test_data_path, test_mask_path, batch_size, target_shape=None):
    while True:
        for start in range(0, len(file_list), batch_size):
            end = min(start + batch_size, len(file_list))
            batch_files = file_list[start:end]
            
            X_batch = []
            y_batch = []
            
            for filename in batch_files:
                img_path = os.path.join(test_data_path, filename)
                corresponding_mask_path = os.path.join(test_mask_path, filename)
                
                # Load NIfTI data (assumes a function `load_nifti_memmap` is already defined)
                image, _, _ = load_nifti_memmap(img_path)
                mask, _, _ = load_nifti_memmap(corresponding_mask_path)
                
                if target_shape:
                    image = resize_volume(image, target_shape)
                    mask = resize_volume(mask, target_shape)
                
                X_batch.append(image)
                y_batch.append(mask)
            
            X_batch = np.array(X_batch)[..., np.newaxis]
            y_batch = np.array(y_batch)[..., np.newaxis]
            
            yield X_batch, y_batch

# Paths for testing data and masks
test_data_path = r'/home/icmr/Documents/DATASET/MSD_LIVER/Portal/Test/imageTs'
test_mask_path = r'/home/icmr/Documents/DATASET/MSD_LIVER/Portal/Test/LabelTs'


# Filter for the specific patient's file (example: patient ID starts with "patient001")
test_files = [filename for filename in os.listdir(test_data_path) if "liver_127.nii.gz" in filename]

# Define batch size and target shape
batch_size = 1
input_shape = (128, 128, 800, 1)

# Create testing generator
test_generator = data_generator(test_files, test_data_path, test_mask_path, batch_size, target_shape=input_shape[:3])

# Calculate steps for testing
test_steps = 1

# Perform evaluation on the test set
test_loss, test_accuracy, test_dice, test_jaccard = model.evaluate(test_generator, steps=test_steps)

# Print the test metrics
print("\nTest Metrics:")
print(f"Test file: {test_files}")
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
print(f"Test Dice Coefficient: {test_dice}")
print(f"Test Jaccard Index: {test_jaccard}")
# Out:
# 1/1 [==============================] - 1s 658ms/step - loss: 0.0314 - accuracy: 0.9901 - dice_coefficient: 0.5630 - jaccard_index: 0.3918
#
# Test Metrics:
# Test file: ['liver_127.nii.gz']
# Test Loss: 0.03138776123523712
# Test Accuracy: 0.9900537133216858
# Test Dice Coefficient: 0.563030481338501
# Test Jaccard Index: 0.39181894063949585

# %%
# Save test metrics to a file
test_metrics = {
    "Test file": test_files,
    "Test Loss": test_loss,
    "Test Accuracy": test_accuracy,
    "Test Dice Coefficient": test_dice,
    "Test Jaccard Index": test_jaccard,
    
}
# Define the file path
metrics_file = 'test_metrics.csv'

# Check if the file exists
file_exists = os.path.isfile(metrics_file)

# Convert metrics to a DataFrame
metrics_df = pd.DataFrame([test_metrics])

# Append metrics to the file
metrics_df.to_csv(metrics_file, mode='a', index=False, header=not file_exists)

print(f"\nTest Metrics appended to '{metrics_file}'.")
# Out:
# Test Metrics appended to 'test_metrics.csv'.

# %%
def display_and_save_results_for_one_patient(model, patient_filename, test_data_path, test_mask_path, save_dir):
    target_shape = (128, 128, 800, 1)  # Fixed shape for all volumes

    # Construct file paths for the image and mask
    image_file_path = os.path.join(test_data_path, patient_filename)
    mask_file_path = os.path.join(test_mask_path, patient_filename)

    print(f"Processing file: {patient_filename}")

    try:
        # Load image and mask data from .nii files
        image = nib.load(image_file_path).get_fdata(dtype=np.float32)
        mask = nib.load(mask_file_path).get_fdata(dtype=np.float32)

        # Resize image and mask to expected shape
        image = resize_image(image, target_shape[:2])
        mask = resize_image(mask, target_shape[:2])

        # Pad or crop image and mask to match target depth
        image = pad_or_crop_volume(image, target_shape)
        mask = pad_or_crop_volume(mask, target_shape)

        # Preprocess image and mask
        image = image[..., np.newaxis]
        mask = mask[..., np.newaxis]

        # Get prediction
        prediction = model.predict(np.expand_dims(image, axis=0))[0, ..., 0]

        # Ensure save directory exists
        os.makedirs(save_dir, exist_ok=True)

        # Save each slice of the image, mask, and prediction
        for z in range(target_shape[2]):
            fig, axs = plt.subplots(1, 3, figsize=(15, 5))

            # Subplot 1: Original Image Slice
            axs[0].imshow(image[:, :, z, 0], cmap='gray')
            axs[0].set_title(f"Image Slice {z}")
            axs[0].axis('off')

            # Subplot 2: Ground Truth Mask Slice
            axs[1].imshow(mask[:, :, z, 0], cmap='gray')
            axs[1].set_title(f"Mask Slice {z}")
            axs[1].axis('off')

            # Subplot 3: Prediction Slice
            axs[2].imshow(prediction[:, :, z], cmap='gray')
            axs[2].set_title(f"Prediction Slice {z}")
            axs[2].axis('off')

            plt.tight_layout()

            # Save the plot
            save_path = os.path.join(save_dir, f"{patient_filename}_slice_{z}.png")
            plt.savefig(save_path, dpi=300)
            plt.close(fig)  # Close the figure to free memory

            print(f"Saved slice {z} to {save_path}")

    except Exception as e:
        print(f"Error processing file {patient_filename}: {e}")

# Specify the single patient's filename and save directory
patient_filename = "liver_127.nii.gz"  # Replace with the desired filename
save_dir = "/home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127"  # Replace with the desired save directory

# Call the function to process and save the results
display_and_save_results_for_one_patient(model, patient_filename, test_data_path, test_mask_path, save_dir)
# Out:
# Processing file: liver_127.nii.gz
# 1/1 [==============================] - 0s 43ms/step
# Saved slice 0 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_0.png
# Saved slice 1 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_1.png
# Saved slice 2 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_2.png
# Saved slice 3 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_3.png
# Saved slice 4 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_4.png
# Saved slice 5 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_5.png
# Saved slice 6 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_6.png
# Saved slice 7 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_7.png
# Saved slice 8 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_8.png
# Saved slice 9 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_9.png
# Saved slice 10 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_10.png
# Saved slice 11 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_11.png
# Saved slice 12 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_12.png
# Saved slice 13 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_13.png
# Saved slice 14 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_14.png
# Saved slice 15 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_15.png
# Saved slice 16 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_16.png
# Saved slice 17 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_17.png
# Saved slice 18 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_18.png
# Saved slice 19 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_19.png
# Saved slice 20 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_20.png
# Saved slice 21 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_21.png
# Saved slice 22 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_22.png
# Saved slice 23 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_23.png
# Saved slice 24 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_24.png
# Saved slice 25 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_25.png
# Saved slice 26 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_26.png
# Saved slice 27 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_27.png
# Saved slice 28 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_28.png
# Saved slice 29 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_29.png
# Saved slice 30 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_30.png
# Saved slice 31 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_31.png
# Saved slice 32 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_32.png
# Saved slice 33 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_33.png
# Saved slice 34 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_34.png
# Saved slice 35 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_35.png
# Saved slice 36 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_36.png
# Saved slice 37 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_37.png
# Saved slice 38 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_38.png
# Saved slice 39 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_39.png
# Saved slice 40 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_40.png
# Saved slice 41 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_41.png
# Saved slice 42 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_42.png
# Saved slice 43 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_43.png
# Saved slice 44 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_44.png
# Saved slice 45 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_45.png
# Saved slice 46 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_46.png
# Saved slice 47 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_47.png
# Saved slice 48 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_48.png
# Saved slice 49 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_49.png
# Saved slice 50 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_50.png
# Saved slice 51 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_51.png
# Saved slice 52 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_52.png
# Saved slice 53 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_53.png
# Saved slice 54 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_54.png
# Saved slice 55 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_55.png
# Saved slice 56 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_56.png
# Saved slice 57 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_57.png
# Saved slice 58 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_58.png
# Saved slice 59 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_59.png
# Saved slice 60 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_60.png
# Saved slice 61 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_61.png
# Saved slice 62 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_62.png
# Saved slice 63 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_63.png
# Saved slice 64 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_64.png
# Saved slice 65 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_65.png
# Saved slice 66 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_66.png
# Saved slice 67 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_67.png
# Saved slice 68 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_68.png
# Saved slice 69 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_69.png
# Saved slice 70 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_70.png
# Saved slice 71 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_71.png
# Saved slice 72 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_72.png
# Saved slice 73 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_73.png
# Saved slice 74 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_74.png
# Saved slice 75 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_75.png
# Saved slice 76 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_76.png
# Saved slice 77 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_77.png
# Saved slice 78 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_78.png
# Saved slice 79 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_79.png
# Saved slice 80 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_80.png
# Saved slice 81 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_81.png
# Saved slice 82 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_82.png
# Saved slice 83 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_83.png
# Saved slice 84 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_84.png
# Saved slice 85 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_85.png
# Saved slice 86 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_86.png
# Saved slice 87 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_87.png
# Saved slice 88 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_88.png
# Saved slice 89 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_89.png
# Saved slice 90 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_90.png
# Saved slice 91 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_91.png
# Saved slice 92 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_92.png
# Saved slice 93 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_93.png
# Saved slice 94 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_94.png
# Saved slice 95 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_95.png
# Saved slice 96 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_96.png
# Saved slice 97 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_97.png
# Saved slice 98 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_98.png
# Saved slice 99 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_99.png
# Saved slice 100 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_100.png
# Saved slice 101 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_101.png
# Saved slice 102 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_102.png
# Saved slice 103 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_103.png
# Saved slice 104 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_104.png
# Saved slice 105 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_105.png
# Saved slice 106 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_106.png
# Saved slice 107 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_107.png
# Saved slice 108 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_108.png
# Saved slice 109 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_109.png
# Saved slice 110 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_110.png
# Saved slice 111 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_111.png
# Saved slice 112 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_112.png
# Saved slice 113 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_113.png
# Saved slice 114 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_114.png
# Saved slice 115 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_115.png
# Saved slice 116 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_116.png
# Saved slice 117 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_117.png
# Saved slice 118 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_118.png
# Saved slice 119 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_119.png
# Saved slice 120 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_120.png
# Saved slice 121 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_121.png
# Saved slice 122 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_122.png
# Saved slice 123 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_123.png
# Saved slice 124 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_124.png
# Saved slice 125 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_125.png
# Saved slice 126 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_126.png
# Saved slice 127 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_127.png
# Saved slice 128 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_128.png
# Saved slice 129 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_129.png
# Saved slice 130 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_130.png
# Saved slice 131 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_131.png
# Saved slice 132 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_132.png
# Saved slice 133 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_133.png
# Saved slice 134 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_134.png
# Saved slice 135 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_135.png
# Saved slice 136 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_136.png
# Saved slice 137 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_137.png
# Saved slice 138 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_138.png
# Saved slice 139 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_139.png
# Saved slice 140 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_140.png
# Saved slice 141 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_141.png
# Saved slice 142 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_142.png
# Saved slice 143 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_143.png
# Saved slice 144 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_144.png
# Saved slice 145 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_145.png
# Saved slice 146 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_146.png
# Saved slice 147 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_147.png
# Saved slice 148 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_148.png
# Saved slice 149 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_149.png
# Saved slice 150 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_150.png
# Saved slice 151 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_151.png
# Saved slice 152 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_152.png
# Saved slice 153 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_153.png
# Saved slice 154 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_154.png
# Saved slice 155 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_155.png
# Saved slice 156 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_156.png
# Saved slice 157 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_157.png
# Saved slice 158 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_158.png
# Saved slice 159 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_159.png
# Saved slice 160 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_160.png
# Saved slice 161 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_161.png
# Saved slice 162 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_162.png
# Saved slice 163 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_163.png
# Saved slice 164 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_164.png
# Saved slice 165 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_165.png
# Saved slice 166 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_166.png
# Saved slice 167 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_167.png
# Saved slice 168 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_168.png
# Saved slice 169 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_169.png
# Saved slice 170 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_170.png
# Saved slice 171 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_171.png
# Saved slice 172 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_172.png
# Saved slice 173 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_173.png
# Saved slice 174 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_174.png
# Saved slice 175 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_175.png
# Saved slice 176 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_176.png
# Saved slice 177 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_177.png
# Saved slice 178 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_178.png
# Saved slice 179 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_179.png
# Saved slice 180 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_180.png
# Saved slice 181 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_181.png
# Saved slice 182 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_182.png
# Saved slice 183 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_183.png
# Saved slice 184 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_184.png
# Saved slice 185 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_185.png
# Saved slice 186 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_186.png
# Saved slice 187 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_187.png
# Saved slice 188 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_188.png
# Saved slice 189 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_189.png
# Saved slice 190 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_190.png
# Saved slice 191 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_191.png
# Saved slice 192 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_192.png
# Saved slice 193 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_193.png
# Saved slice 194 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_194.png
# Saved slice 195 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_195.png
# Saved slice 196 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_196.png
# Saved slice 197 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_197.png
# Saved slice 198 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_198.png
# Saved slice 199 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_199.png
# Saved slice 200 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_200.png
# Saved slice 201 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_201.png
# Saved slice 202 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_202.png
# Saved slice 203 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_203.png
# Saved slice 204 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_204.png
# Saved slice 205 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_205.png
# Saved slice 206 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_206.png
# Saved slice 207 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_207.png
# Saved slice 208 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_208.png
# Saved slice 209 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_209.png
# Saved slice 210 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_210.png
# Saved slice 211 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_211.png
# Saved slice 212 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_212.png
# Saved slice 213 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_213.png
# Saved slice 214 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_214.png
# Saved slice 215 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_215.png
# Saved slice 216 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_216.png
# Saved slice 217 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_217.png
# Saved slice 218 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_218.png
# Saved slice 219 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_219.png
# Saved slice 220 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_220.png
# Saved slice 221 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_221.png
# Saved slice 222 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_222.png
# Saved slice 223 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_223.png
# Saved slice 224 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_224.png
# Saved slice 225 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_225.png
# Saved slice 226 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_226.png
# Saved slice 227 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_227.png
# Saved slice 228 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_228.png
# Saved slice 229 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_229.png
# Saved slice 230 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_230.png
# Saved slice 231 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_231.png
# Saved slice 232 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_232.png
# Saved slice 233 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_233.png
# Saved slice 234 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_234.png
# Saved slice 235 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_235.png
# Saved slice 236 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_236.png
# Saved slice 237 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_237.png
# Saved slice 238 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_238.png
# Saved slice 239 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_239.png
# Saved slice 240 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_240.png
# Saved slice 241 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_241.png
# Saved slice 242 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_242.png
# Saved slice 243 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_243.png
# Saved slice 244 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_244.png
# Saved slice 245 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_245.png
# Saved slice 246 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_246.png
# Saved slice 247 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_247.png
# Saved slice 248 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_248.png
# Saved slice 249 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_249.png
# Saved slice 250 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_250.png
# Saved slice 251 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_251.png
# Saved slice 252 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_252.png
# Saved slice 253 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_253.png
# Saved slice 254 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_254.png
# Saved slice 255 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_255.png
# Saved slice 256 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_256.png
# Saved slice 257 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_257.png
# Saved slice 258 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_258.png
# Saved slice 259 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_259.png
# Saved slice 260 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_260.png
# Saved slice 261 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_261.png
# Saved slice 262 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_262.png
# Saved slice 263 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_263.png
# Saved slice 264 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_264.png
# Saved slice 265 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_265.png
# Saved slice 266 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_266.png
# Saved slice 267 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_267.png
# Saved slice 268 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_268.png
# Saved slice 269 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_269.png
# Saved slice 270 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_270.png
# Saved slice 271 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_271.png
# Saved slice 272 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_272.png
# Saved slice 273 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_273.png
# Saved slice 274 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_274.png
# Saved slice 275 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_275.png
# Saved slice 276 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_276.png
# Saved slice 277 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_277.png
# Saved slice 278 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_278.png
# Saved slice 279 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_279.png
# Saved slice 280 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_280.png
# Saved slice 281 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_281.png
# Saved slice 282 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_282.png
# Saved slice 283 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_283.png
# Saved slice 284 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_284.png
# Saved slice 285 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_285.png
# Saved slice 286 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_286.png
# Saved slice 287 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_287.png
# Saved slice 288 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_288.png
# Saved slice 289 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_289.png
# Saved slice 290 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_290.png
# Saved slice 291 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_291.png
# Saved slice 292 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_292.png
# Saved slice 293 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_293.png
# Saved slice 294 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_294.png
# Saved slice 295 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_295.png
# Saved slice 296 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_296.png
# Saved slice 297 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_297.png
# Saved slice 298 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_298.png
# Saved slice 299 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_299.png
# Saved slice 300 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_300.png
# Saved slice 301 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_301.png
# Saved slice 302 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_302.png
# Saved slice 303 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_303.png
# Saved slice 304 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_304.png
# Saved slice 305 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_305.png
# Saved slice 306 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_306.png
# Saved slice 307 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_307.png
# Saved slice 308 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_308.png
# Saved slice 309 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_309.png
# Saved slice 310 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_310.png
# Saved slice 311 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_311.png
# Saved slice 312 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_312.png
# Saved slice 313 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_313.png
# Saved slice 314 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_314.png
# Saved slice 315 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_315.png
# Saved slice 316 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_316.png
# Saved slice 317 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_317.png
# Saved slice 318 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_318.png
# Saved slice 319 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_319.png
# Saved slice 320 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_320.png
# Saved slice 321 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_321.png
# Saved slice 322 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_322.png
# Saved slice 323 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_323.png
# Saved slice 324 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_324.png
# Saved slice 325 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_325.png
# Saved slice 326 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_326.png
# Saved slice 327 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_327.png
# Saved slice 328 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_328.png
# Saved slice 329 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_329.png
# Saved slice 330 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_330.png
# Saved slice 331 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_331.png
# Saved slice 332 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_332.png
# Saved slice 333 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_333.png
# Saved slice 334 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_334.png
# Saved slice 335 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_335.png
# Saved slice 336 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_336.png
# Saved slice 337 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_337.png
# Saved slice 338 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_338.png
# Saved slice 339 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_339.png
# Saved slice 340 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_340.png
# Saved slice 341 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_341.png
# Saved slice 342 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_342.png
# Saved slice 343 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_343.png
# Saved slice 344 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_344.png
# Saved slice 345 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_345.png
# Saved slice 346 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_346.png
# Saved slice 347 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_347.png
# Saved slice 348 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_348.png
# Saved slice 349 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_349.png
# Saved slice 350 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_350.png
# Saved slice 351 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_351.png
# Saved slice 352 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_352.png
# Saved slice 353 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_353.png
# Saved slice 354 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_354.png
# Saved slice 355 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_355.png
# Saved slice 356 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_356.png
# Saved slice 357 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_357.png
# Saved slice 358 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_358.png
# Saved slice 359 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_359.png
# Saved slice 360 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_360.png
# Saved slice 361 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_361.png
# Saved slice 362 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_362.png
# Saved slice 363 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_363.png
# Saved slice 364 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_364.png
# Saved slice 365 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_365.png
# Saved slice 366 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_366.png
# Saved slice 367 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_367.png
# Saved slice 368 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_368.png
# Saved slice 369 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_369.png
# Saved slice 370 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_370.png
# Saved slice 371 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_371.png
# Saved slice 372 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_372.png
# Saved slice 373 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_373.png
# Saved slice 374 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_374.png
# Saved slice 375 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_375.png
# Saved slice 376 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_376.png
# Saved slice 377 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_377.png
# Saved slice 378 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_378.png
# Saved slice 379 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_379.png
# Saved slice 380 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_380.png
# Saved slice 381 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_381.png
# Saved slice 382 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_382.png
# Saved slice 383 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_383.png
# Saved slice 384 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_384.png
# Saved slice 385 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_385.png
# Saved slice 386 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_386.png
# Saved slice 387 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_387.png
# Saved slice 388 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_388.png
# Saved slice 389 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_389.png
# Saved slice 390 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_390.png
# Saved slice 391 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_391.png
# Saved slice 392 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_392.png
# Saved slice 393 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_393.png
# Saved slice 394 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_394.png
# Saved slice 395 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_395.png
# Saved slice 396 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_396.png
# Saved slice 397 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_397.png
# Saved slice 398 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_398.png
# Saved slice 399 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_399.png
# Saved slice 400 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_400.png
# Saved slice 401 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_401.png
# Saved slice 402 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_402.png
# Saved slice 403 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_403.png
# Saved slice 404 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_404.png
# Saved slice 405 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_405.png
# Saved slice 406 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_406.png
# Saved slice 407 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_407.png
# Saved slice 408 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_408.png
# Saved slice 409 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_409.png
# Saved slice 410 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_410.png
# Saved slice 411 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_411.png
# Saved slice 412 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_412.png
# Saved slice 413 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_413.png
# Saved slice 414 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_414.png
# Saved slice 415 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_415.png
# Saved slice 416 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_416.png
# Saved slice 417 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_417.png
# Saved slice 418 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_418.png
# Saved slice 419 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_419.png
# Saved slice 420 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_420.png
# Saved slice 421 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_421.png
# Saved slice 422 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_422.png
# Saved slice 423 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_423.png
# Saved slice 424 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_424.png
# Saved slice 425 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_425.png
# Saved slice 426 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_426.png
# Saved slice 427 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_427.png
# Saved slice 428 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_428.png
# Saved slice 429 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_429.png
# Saved slice 430 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_430.png
# Saved slice 431 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_431.png
# Saved slice 432 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_432.png
# Saved slice 433 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_433.png
# Saved slice 434 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_434.png
# Saved slice 435 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_435.png
# Saved slice 436 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_436.png
# Saved slice 437 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_437.png
# Saved slice 438 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_438.png
# Saved slice 439 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_439.png
# Saved slice 440 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_440.png
# Saved slice 441 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_441.png
# Saved slice 442 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_442.png
# Saved slice 443 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_443.png
# Saved slice 444 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_444.png
# Saved slice 445 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_445.png
# Saved slice 446 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_446.png
# Saved slice 447 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_447.png
# Saved slice 448 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_448.png
# Saved slice 449 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_449.png
# Saved slice 450 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_450.png
# Saved slice 451 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_451.png
# Saved slice 452 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_452.png
# Saved slice 453 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_453.png
# Saved slice 454 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_454.png
# Saved slice 455 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_455.png
# Saved slice 456 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_456.png
# Saved slice 457 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_457.png
# Saved slice 458 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_458.png
# Saved slice 459 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_459.png
# Saved slice 460 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_460.png
# Saved slice 461 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_461.png
# ...
# Saved slice 647 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_647.png
# Saved slice 648 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_648.png
# Saved slice 649 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_649.png
# Saved slice 650 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_650.png
# Saved slice 651 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_651.png
# Saved slice 652 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_652.png
# Saved slice 653 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_653.png
# Saved slice 654 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_654.png
# Saved slice 655 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_655.png
# Saved slice 656 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_656.png
# Saved slice 657 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_657.png
# Saved slice 658 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_658.png
# Saved slice 659 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_659.png
# Saved slice 660 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_660.png
# Saved slice 661 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_661.png
# Saved slice 662 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_662.png
# Saved slice 663 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_663.png
# Saved slice 664 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_664.png
# Saved slice 665 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_665.png
# Saved slice 666 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_666.png
# Saved slice 667 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_667.png
# Saved slice 668 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_668.png
# Saved slice 669 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_669.png
# Saved slice 670 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_670.png
# Saved slice 671 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_671.png
# Saved slice 672 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_672.png
# Saved slice 673 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_673.png
# Saved slice 674 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_674.png
# Saved slice 675 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_675.png
# Saved slice 676 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_676.png
# Saved slice 677 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_677.png
# Saved slice 678 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_678.png
# Saved slice 679 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_679.png
# Saved slice 680 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_680.png
# Saved slice 681 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_681.png
# Saved slice 682 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_682.png
# Saved slice 683 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_683.png
# Saved slice 684 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_684.png
# Saved slice 685 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_685.png
# Saved slice 686 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_686.png
# Saved slice 687 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_687.png
# Saved slice 688 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_688.png
# Saved slice 689 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_689.png
# Saved slice 690 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_690.png
# Saved slice 691 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_691.png
# Saved slice 692 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_692.png
# Saved slice 693 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_693.png
# Saved slice 694 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_694.png
# Saved slice 695 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_695.png
# Saved slice 696 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_696.png
# Saved slice 697 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_697.png
# Saved slice 698 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_698.png
# Saved slice 699 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_699.png
# Saved slice 700 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_700.png
# Saved slice 701 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_701.png
# Saved slice 702 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_702.png
# Saved slice 703 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_703.png
# Saved slice 704 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_704.png
# Saved slice 705 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_705.png
# Saved slice 706 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_706.png
# Saved slice 707 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_707.png
# Saved slice 708 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_708.png
# Saved slice 709 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_709.png
# Saved slice 710 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_710.png
# Saved slice 711 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_711.png
# Saved slice 712 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_712.png
# Saved slice 713 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_713.png
# Saved slice 714 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_714.png
# Saved slice 715 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_715.png
# Saved slice 716 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_716.png
# Saved slice 717 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_717.png
# Saved slice 718 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_718.png
# Saved slice 719 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_719.png
# Saved slice 720 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_720.png
# Saved slice 721 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_721.png
# Saved slice 722 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_722.png
# Saved slice 723 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_723.png
# Saved slice 724 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_724.png
# Saved slice 725 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_725.png
# Saved slice 726 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_726.png
# Saved slice 727 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_727.png
# Saved slice 728 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_728.png
# Saved slice 729 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_729.png
# Saved slice 730 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_730.png
# Saved slice 731 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_731.png
# Saved slice 732 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_732.png
# Saved slice 733 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_733.png
# Saved slice 734 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_734.png
# Saved slice 735 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_735.png
# Saved slice 736 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_736.png
# Saved slice 737 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_737.png
# Saved slice 738 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_738.png
# Saved slice 739 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_739.png
# Saved slice 740 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_740.png
# Saved slice 741 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_741.png
# Saved slice 742 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_742.png
# Saved slice 743 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_743.png
# Saved slice 744 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_744.png
# Saved slice 745 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_745.png
# Saved slice 746 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_746.png
# Saved slice 747 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_747.png
# Saved slice 748 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_748.png
# Saved slice 749 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_749.png
# Saved slice 750 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_750.png
# Saved slice 751 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_751.png
# Saved slice 752 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_752.png
# Saved slice 753 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_753.png
# Saved slice 754 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_754.png
# Saved slice 755 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_755.png
# Saved slice 756 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_756.png
# Saved slice 757 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_757.png
# Saved slice 758 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_758.png
# Saved slice 759 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_759.png
# Saved slice 760 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_760.png
# Saved slice 761 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_761.png
# Saved slice 762 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_762.png
# Saved slice 763 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_763.png
# Saved slice 764 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_764.png
# Saved slice 765 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_765.png
# Saved slice 766 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_766.png
# Saved slice 767 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_767.png
# Saved slice 768 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_768.png
# Saved slice 769 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_769.png
# Saved slice 770 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_770.png
# Saved slice 771 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_771.png
# Saved slice 772 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_772.png
# Saved slice 773 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_773.png
# Saved slice 774 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_774.png
# Saved slice 775 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_775.png
# Saved slice 776 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_776.png
# Saved slice 777 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_777.png
# Saved slice 778 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_778.png
# Saved slice 779 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_779.png
# Saved slice 780 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_780.png
# Saved slice 781 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_781.png
# Saved slice 782 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_782.png
# Saved slice 783 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_783.png
# Saved slice 784 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_784.png
# Saved slice 785 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_785.png
# Saved slice 786 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_786.png
# Saved slice 787 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_787.png
# Saved slice 788 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_788.png
# Saved slice 789 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_789.png
# Saved slice 790 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_790.png
# Saved slice 791 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_791.png
# Saved slice 792 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_792.png
# Saved slice 793 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_793.png
# Saved slice 794 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_794.png
# Saved slice 795 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_795.png
# Saved slice 796 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_796.png
# Saved slice 797 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_797.png
# Saved slice 798 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_798.png
# Saved slice 799 to /home/icmr/Documents/MSD_LIVER_OUTPUT/PORTALPHASE/127/liver_127.nii.gz_slice_799.png
