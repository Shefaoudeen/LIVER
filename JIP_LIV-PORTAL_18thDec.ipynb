# %%
from skimage.measure import marching_cubes
from mpl_toolkits.mplot3d.art3d import Poly3DCollection

# %%
import os
import numpy as np
import numpy as np
import cv2
import nibabel as nib
#%matplotlib inline
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv3D, MaxPooling3D, UpSampling3D, concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from skimage.transform import resize
from mpl_toolkits.mplot3d import Axes3D
import tensorflow as tf
import scipy.ndimage
# Out:
# 2024-12-18 11:11:06.215835: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-18 11:11:06.272346: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-18 11:11:06.272399: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-18 11:11:06.273845: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-18 11:11:06.284002: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-18 11:11:07.532504: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Function to load NIfTI files with memory mapping
def load_nifti_memmap(file_path):
    img = nib.load(file_path)
    data = img.get_fdata(dtype=np.float32, caching='unchanged')  # Memory-mapped array
    affine = img.affine
    header = img.header
    return data, affine, header

# Generator function to load data in batches
def data_generator(file_list, data_path, mask_path, batch_size, target_shape=None):
    while True:
        np.random.shuffle(file_list)
        for start in range(0, len(file_list), batch_size):
            end = min(start + batch_size, len(file_list))
            batch_files = file_list[start:end]
            
            X_batch = []
            y_batch = []
            
            for filename in batch_files:
                img_path = os.path.join(data_path, filename)
                corresponding_mask_path = os.path.join(mask_path, filename)
                
                image, _, _ = load_nifti_memmap(img_path)
                mask, _, _ = load_nifti_memmap(corresponding_mask_path)
                
                # Ensure image and mask have the same shape (and possibly resize if needed)
                if target_shape:
                    image = resize_volume(image, target_shape)
                    mask = resize_volume(mask, target_shape)
                
                X_batch.append(image)
                y_batch.append(mask)
            
            X_batch = np.array(X_batch)[..., np.newaxis]  # Adding channel dimension
            y_batch = np.array(y_batch)[..., np.newaxis]  # Adding channel dimension
            
            yield X_batch, y_batch

# Function to resize volumes (if needed)
def resize_volume(img, target_shape):
    current_shape = img.shape
    if current_shape == target_shape:
        return img
    # Example: using scipy for interpolation
    resized_img = scipy.ndimage.zoom(img, (target_shape[0]/current_shape[0], target_shape[1]/current_shape[1], target_shape[2]/current_shape[2]), order=3)
    return resized_img

def resize_image(image, target_shape):
    # Resize the image to match the target shape (height, width)
    return resize(image, target_shape, preserve_range=True, anti_aliasing=True)

def pad_or_crop_volume(volume, target_shape):
    current_shape = volume.shape
    
    # Calculate padding width for each dimension
    pad_width = [(0, max(target_shape[i] - current_shape[i], 0)) for i in range(3)]
    
    # Pad the volume to the target shape
    volume = np.pad(volume, pad_width, mode='constant', constant_values=0)
    
    # Calculate cropping dimensions for each dimension
    crop_start = [(volume.shape[i] - target_shape[i]) // 2 for i in range(3)]
    crop_end = [crop_start[i] + target_shape[i] for i in range(3)]
    
    # Crop the volume to the target shape
    slices = [slice(crop_start[i], crop_end[i]) for i in range(3)]
    volume = volume[slices[0], slices[1], slices[2]]
    
    return volume

def calculate_volume(mask, voxel_volume):
    # Calculate the volume based on the mask
    return np.sum(mask) * voxel_volume
    
def unet_3d(input_shape):
    inputs = Input(input_shape)
    
    # Downsampling
    c1 = Conv3D(32, (3, 3, 3), activation='relu', padding='same')(inputs)
    c1 = Conv3D(32, (3, 3, 3), activation='relu', padding='same')(c1)
    c1 = Conv3D(32, (3, 3, 3), activation='relu', padding='same')(c1)  # Added layer
    c1 = Conv3D(32, (3, 3, 3), activation='relu', padding='same')(c1)  # Added layer
    p1 = MaxPooling3D((2, 2, 2))(c1)
    
    c2 = Conv3D(64, (3, 3, 3), activation='relu', padding='same')(p1)
    c2 = Conv3D(64, (3, 3, 3), activation='relu', padding='same')(c2)
    c2 = Conv3D(64, (3, 3, 3), activation='relu', padding='same')(c2)  # Added layer
    c2 = Conv3D(64, (3, 3, 3), activation='relu', padding='same')(c2)  # Added layer
    p2 = MaxPooling3D((2, 2, 2))(c2)
    
    c3 = Conv3D(128, (3, 3, 3), activation='relu', padding='same')(p2)
    c3 = Conv3D(128, (3, 3, 3), activation='relu', padding='same')(c3)
    c3 = Conv3D(128, (3, 3, 3), activation='relu', padding='same')(c3)  # Added layer
    c3 = Conv3D(128, (3, 3, 3), activation='relu', padding='same')(c3)  # Added layer
    
    # Upsampling
    u4 = UpSampling3D((2, 2, 2))(c3)
    u4 = concatenate([u4, c2])
    c4 = Conv3D(64, (3, 3, 3), activation='relu', padding='same')(u4)
    c4 = Conv3D(64, (3, 3, 3), activation='relu', padding='same')(c4)
    c4 = Conv3D(64, (3, 3, 3), activation='relu', padding='same')(c4)  # Added layer
    c4 = Conv3D(64, (3, 3, 3), activation='relu', padding='same')(c4)  # Added layer
    
    u5 = UpSampling3D((2, 2, 2))(c4)
    u5 = concatenate([u5, c1])
    c5 = Conv3D(32, (3, 3, 3), activation='relu', padding='same')(u5)
    c5 = Conv3D(32, (3, 3, 3), activation='relu', padding='same')(c5)
    c5 = Conv3D(32, (3, 3, 3), activation='relu', padding='same')(c5)  # Added layer
    c5 = Conv3D(32, (3, 3, 3), activation='relu', padding='same')(c5)  # Added layer
    
    outputs = Conv3D(1, (1, 1, 1), activation='sigmoid')(c5)
    
    model = Model(inputs=[inputs], outputs=[outputs])
    return model
    
    model = Model(inputs, outputs)
    #model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy', dice_coefficient, jaccard_index])
    return model

# Dice coefficient
def dice_coefficient(y_true, y_pred):
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) + 1)

# Jaccard index
def jaccard_index(y_true, y_pred):
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
    return (intersection + 1) / (tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) - intersection + 1)

# Example paths (update these to your dataset paths)
data_path = r'/home/icmr/Downloads/niigz dicom/Portal Phase'  # Update with the correct path
mask_path = r'/home/icmr/Downloads/niigz liver/Portal Phase'  # Update with the correct path

# Verify paths exist
if not os.path.exists(data_path):
    raise FileNotFoundError(f"Data path not found: {data_path}")
if not os.path.exists(mask_path):
    raise FileNotFoundError(f"Mask path not found: {mask_path}")

# List of files
file_list = [filename for filename in os.listdir(data_path) if filename.endswith('.nii.gz')]

# Split the dataset
train_val_files, test_files = train_test_split(file_list, test_size=0.2, random_state=42)
train_files, val_files = train_test_split(train_val_files, test_size=0.25, random_state=42)  # 0.25 * 0.8 = 0.2

# Define and compile the model
input_shape = (128, 128, 64, 1)  # Example input shape, adjust accordingly
model = unet_3d(input_shape)
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy', dice_coefficient, jaccard_index])
  
# Define callbacks
checkpoint = ModelCheckpoint('unet3d_best_model.h5', save_best_only=True, monitor='val_loss', mode='min')
#early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Define batch size
batch_size = 2

# Create data generators
train_generator = data_generator(train_files, data_path, mask_path, batch_size, target_shape=input_shape[:3])
val_generator = data_generator(val_files, data_path, mask_path, batch_size, target_shape=input_shape[:3])
test_generator = data_generator(test_files, data_path, mask_path, batch_size, target_shape=input_shape[:3])

# Calculate steps per epoch
steps_per_epoch = len(train_files) // batch_size
validation_steps = len(val_files) // batch_size
test_steps = len(test_files) // batch_size

# Train the model
history = model.fit(train_generator, validation_data=val_generator, epochs=200, steps_per_epoch=steps_per_epoch, validation_steps=validation_steps, callbacks=[checkpoint])

# Save the model
model.save('unet3d_model.h5')

# Evaluate the model on the test set
test_loss, test_accuracy, test_dice, test_jaccard = model.evaluate(test_generator, steps=test_steps)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
print(f"Test Dice Coefficient: {test_dice}")
print(f"Test Jaccard Index: {test_jaccard}")
# Out:
# 2024-12-18 11:11:08.383627: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 41974 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:51:00.0, compute capability: 8.6
# Epoch 1/200
# 2024-12-18 11:11:46.919221: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8902
# 2024-12-18 11:11:47.042004: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-12-18 11:11:47.507257: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-12-18 11:11:54.177149: I external/local_xla/xla/service/service.cc:168] XLA service 0x7b52117dbc60 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-12-18 11:11:54.177183: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2024-12-18 11:11:54.183446: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1734500514.334040  144254 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 6/6 [==============================] - 132s 22s/step - loss: 0.7819 - accuracy: 0.6844 - dice_coefficient: 0.0630 - jaccard_index: 0.0335 - val_loss: 0.0581 - val_accuracy: 0.8443 - val_dice_coefficient: 0.1503 - val_jaccard_index: 0.0813
# Epoch 2/200
# /home/icmr/myenv_py311/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 6/6 [==============================] - 105s 21s/step - loss: 0.0710 - accuracy: 0.8340 - dice_coefficient: 0.1376 - jaccard_index: 0.0745 - val_loss: 0.0472 - val_accuracy: 0.8547 - val_dice_coefficient: 0.1481 - val_jaccard_index: 0.0801
# Epoch 3/200
# 6/6 [==============================] - 115s 23s/step - loss: 0.0568 - accuracy: 0.8340 - dice_coefficient: 0.2096 - jaccard_index: 0.1174 - val_loss: 0.0429 - val_accuracy: 0.8443 - val_dice_coefficient: 0.2573 - val_jaccard_index: 0.1487
# Epoch 4/200
# 6/6 [==============================] - 98s 19s/step - loss: 0.0489 - accuracy: 0.8340 - dice_coefficient: 0.2898 - jaccard_index: 0.1702 - val_loss: 0.0318 - val_accuracy: 0.8172 - val_dice_coefficient: 0.3320 - val_jaccard_index: 0.1991
# Epoch 5/200
# 6/6 [==============================] - 108s 22s/step - loss: 0.0389 - accuracy: 0.8341 - dice_coefficient: 0.3512 - jaccard_index: 0.2144 - val_loss: 0.0314 - val_accuracy: 0.8440 - val_dice_coefficient: 0.3684 - val_jaccard_index: 0.2271
# Epoch 6/200
# 6/6 [==============================] - 119s 24s/step - loss: 0.0347 - accuracy: 0.8353 - dice_coefficient: 0.4319 - jaccard_index: 0.2766 - val_loss: 0.0282 - val_accuracy: 0.8744 - val_dice_coefficient: 0.4413 - val_jaccard_index: 0.2831
# Epoch 7/200
# 6/6 [==============================] - 112s 22s/step - loss: 0.0318 - accuracy: 0.8394 - dice_coefficient: 0.4573 - jaccard_index: 0.2979 - val_loss: 0.0269 - val_accuracy: 0.8467 - val_dice_coefficient: 0.4492 - val_jaccard_index: 0.2907
# Epoch 8/200
# 6/6 [==============================] - 94s 19s/step - loss: 0.0293 - accuracy: 0.8396 - dice_coefficient: 0.5108 - jaccard_index: 0.3438 - val_loss: 0.0404 - val_accuracy: 0.8419 - val_dice_coefficient: 0.3914 - val_jaccard_index: 0.2433
# Epoch 9/200
# 6/6 [==============================] - 111s 22s/step - loss: 0.0293 - accuracy: 0.8388 - dice_coefficient: 0.4958 - jaccard_index: 0.3325 - val_loss: 0.0239 - val_accuracy: 0.8469 - val_dice_coefficient: 0.4999 - val_jaccard_index: 0.3336
# Epoch 10/200
# 6/6 [==============================] - 99s 20s/step - loss: 0.0416 - accuracy: 0.8387 - dice_coefficient: 0.4680 - jaccard_index: 0.3091 - val_loss: 0.0517 - val_accuracy: 0.8446 - val_dice_coefficient: 0.2543 - val_jaccard_index: 0.1469
# Epoch 11/200
# 6/6 [==============================] - 114s 23s/step - loss: 0.0397 - accuracy: 0.8379 - dice_coefficient: 0.3870 - jaccard_index: 0.2439 - val_loss: 0.0278 - val_accuracy: 0.8472 - val_dice_coefficient: 0.4458 - val_jaccard_index: 0.2882
# Epoch 12/200
# 6/6 [==============================] - 95s 19s/step - loss: 0.0668 - accuracy: 0.8318 - dice_coefficient: 0.4129 - jaccard_index: 0.2747 - val_loss: 0.0845 - val_accuracy: 0.8251 - val_dice_coefficient: 0.2851 - val_jaccard_index: 0.1692
# Epoch 13/200
# 6/6 [==============================] - 102s 20s/step - loss: 0.0614 - accuracy: 0.8293 - dice_coefficient: 0.2563 - jaccard_index: 0.1496 - val_loss: 0.0388 - val_accuracy: 0.8443 - val_dice_coefficient: 0.2413 - val_jaccard_index: 0.1372
# Epoch 14/200
# 6/6 [==============================] - 114s 23s/step - loss: 0.0454 - accuracy: 0.8340 - dice_coefficient: 0.2948 - jaccard_index: 0.1738 - val_loss: 0.0334 - val_accuracy: 0.8325 - val_dice_coefficient: 0.3808 - val_jaccard_index: 0.2352
# Epoch 15/200
# 6/6 [==============================] - 92s 18s/step - loss: 0.0405 - accuracy: 0.8339 - dice_coefficient: 0.3573 - jaccard_index: 0.2203 - val_loss: 0.0333 - val_accuracy: 0.8441 - val_dice_coefficient: 0.3635 - val_jaccard_index: 0.2221
# Epoch 16/200
# 6/6 [==============================] - 112s 22s/step - loss: 0.0342 - accuracy: 0.8339 - dice_coefficient: 0.4152 - jaccard_index: 0.2630 - val_loss: 0.0474 - val_accuracy: 0.8590 - val_dice_coefficient: 0.4207 - val_jaccard_index: 0.2665
# Epoch 17/200
# 6/6 [==============================] - 92s 18s/step - loss: 0.0371 - accuracy: 0.8341 - dice_coefficient: 0.4155 - jaccard_index: 0.2639 - val_loss: 0.0276 - val_accuracy: 0.8443 - val_dice_coefficient: 0.4270 - val_jaccard_index: 0.2715
# Epoch 18/200
# 6/6 [==============================] - 110s 22s/step - loss: 0.0319 - accuracy: 0.8350 - dice_coefficient: 0.4522 - jaccard_index: 0.2932 - val_loss: 0.0303 - val_accuracy: 0.8617 - val_dice_coefficient: 0.4499 - val_jaccard_index: 0.2904
# Epoch 19/200
# 6/6 [==============================] - 95s 19s/step - loss: 0.0317 - accuracy: 0.8368 - dice_coefficient: 0.4585 - jaccard_index: 0.2983 - val_loss: 0.0270 - val_accuracy: 0.8468 - val_dice_coefficient: 0.4754 - val_jaccard_index: 0.3120
# Epoch 20/200
# 6/6 [==============================] - 90s 18s/step - loss: 0.0290 - accuracy: 0.8394 - dice_coefficient: 0.5328 - jaccard_index: 0.3637 - val_loss: 0.0206 - val_accuracy: 0.8406 - val_dice_coefficient: 0.5212 - val_jaccard_index: 0.3525
# Epoch 21/200
# 6/6 [==============================] - 104s 21s/step - loss: 0.0270 - accuracy: 0.8395 - dice_coefficient: 0.5873 - jaccard_index: 0.4174 - val_loss: 0.0238 - val_accuracy: 0.8466 - val_dice_coefficient: 0.5269 - val_jaccard_index: 0.3577
# Epoch 22/200
# 6/6 [==============================] - 103s 20s/step - loss: 0.0266 - accuracy: 0.8395 - dice_coefficient: 0.5769 - jaccard_index: 0.4065 - val_loss: 0.0258 - val_accuracy: 0.8638 - val_dice_coefficient: 0.5907 - val_jaccard_index: 0.4193
# Epoch 23/200
# 6/6 [==============================] - 94s 19s/step - loss: 0.0249 - accuracy: 0.8400 - dice_coefficient: 0.6218 - jaccard_index: 0.4527 - val_loss: 0.0218 - val_accuracy: 0.8471 - val_dice_coefficient: 0.5886 - val_jaccard_index: 0.4171
# Epoch 24/200
# 6/6 [==============================] - 108s 22s/step - loss: 0.0225 - accuracy: 0.8399 - dice_coefficient: 0.6562 - jaccard_index: 0.4888 - val_loss: 0.0179 - val_accuracy: 0.8586 - val_dice_coefficient: 0.6164 - val_jaccard_index: 0.4460
# Epoch 25/200
# 6/6 [==============================] - 104s 21s/step - loss: 0.0215 - accuracy: 0.8403 - dice_coefficient: 0.6648 - jaccard_index: 0.5008 - val_loss: 0.0264 - val_accuracy: 0.8471 - val_dice_coefficient: 0.5846 - val_jaccard_index: 0.4157
# Epoch 26/200
# 6/6 [==============================] - 91s 18s/step - loss: 0.0241 - accuracy: 0.8393 - dice_coefficient: 0.6438 - jaccard_index: 0.4774 - val_loss: 0.0164 - val_accuracy: 0.8302 - val_dice_coefficient: 0.6426 - val_jaccard_index: 0.4743
# Epoch 27/200
# 6/6 [==============================] - 110s 22s/step - loss: 0.0216 - accuracy: 0.8404 - dice_coefficient: 0.6716 - jaccard_index: 0.5065 - val_loss: 0.0186 - val_accuracy: 0.8476 - val_dice_coefficient: 0.6278 - val_jaccard_index: 0.4577
# Epoch 28/200
# 6/6 [==============================] - 92s 18s/step - loss: 0.0187 - accuracy: 0.8405 - dice_coefficient: 0.7013 - jaccard_index: 0.5417 - val_loss: 0.0212 - val_accuracy: 0.8359 - val_dice_coefficient: 0.6891 - val_jaccard_index: 0.5281
# Epoch 29/200
# 6/6 [==============================] - 102s 20s/step - loss: 0.0178 - accuracy: 0.8404 - dice_coefficient: 0.7502 - jaccard_index: 0.6018 - val_loss: 0.0164 - val_accuracy: 0.8481 - val_dice_coefficient: 0.7165 - val_jaccard_index: 0.5592
# Epoch 30/200
# 6/6 [==============================] - 111s 22s/step - loss: 0.0200 - accuracy: 0.8404 - dice_coefficient: 0.6953 - jaccard_index: 0.5363 - val_loss: 0.0193 - val_accuracy: 0.8583 - val_dice_coefficient: 0.5975 - val_jaccard_index: 0.4265
# Epoch 31/200
# 6/6 [==============================] - 103s 20s/step - loss: 0.0249 - accuracy: 0.8398 - dice_coefficient: 0.7082 - jaccard_index: 0.5545 - val_loss: 0.0221 - val_accuracy: 0.8471 - val_dice_coefficient: 0.6040 - val_jaccard_index: 0.4336
# Epoch 32/200
# 6/6 [==============================] - 94s 19s/step - loss: 0.0264 - accuracy: 0.8392 - dice_coefficient: 0.5538 - jaccard_index: 0.3854 - val_loss: 0.0219 - val_accuracy: 0.8195 - val_dice_coefficient: 0.5570 - val_jaccard_index: 0.3861
# Epoch 33/200
# 6/6 [==============================] - 103s 20s/step - loss: 0.0235 - accuracy: 0.8402 - dice_coefficient: 0.6331 - jaccard_index: 0.4641 - val_loss: 0.0444 - val_accuracy: 0.8469 - val_dice_coefficient: 0.5178 - val_jaccard_index: 0.3496
# Epoch 34/200
# 6/6 [==============================] - 112s 22s/step - loss: 0.0694 - accuracy: 0.8342 - dice_coefficient: 0.4261 - jaccard_index: 0.2742 - val_loss: 0.0451 - val_accuracy: 0.8444 - val_dice_coefficient: 0.2864 - val_jaccard_index: 0.1672
# Epoch 35/200
# 6/6 [==============================] - 99s 20s/step - loss: 0.0582 - accuracy: 0.8341 - dice_coefficient: 0.2908 - jaccard_index: 0.1738 - val_loss: 0.0353 - val_accuracy: 0.8442 - val_dice_coefficient: 0.3371 - val_jaccard_index: 0.2030
# Epoch 36/200
# 6/6 [==============================] - 96s 19s/step - loss: 0.0396 - accuracy: 0.8341 - dice_coefficient: 0.3634 - jaccard_index: 0.2227 - val_loss: 0.0281 - val_accuracy: 0.8285 - val_dice_coefficient: 0.3615 - val_jaccard_index: 0.2210
# Epoch 37/200
# 6/6 [==============================] - 110s 22s/step - loss: 0.0351 - accuracy: 0.8340 - dice_coefficient: 0.4195 - jaccard_index: 0.2663 - val_loss: 0.0348 - val_accuracy: 0.8433 - val_dice_coefficient: 0.3747 - val_jaccard_index: 0.2327
# Epoch 38/200
# 6/6 [==============================] - 92s 18s/step - loss: 0.0360 - accuracy: 0.8339 - dice_coefficient: 0.4170 - jaccard_index: 0.2638 - val_loss: 0.0270 - val_accuracy: 0.8194 - val_dice_coefficient: 0.3779 - val_jaccard_index: 0.2330
# Epoch 39/200
# 6/6 [==============================] - 102s 20s/step - loss: 0.0327 - accuracy: 0.8343 - dice_coefficient: 0.4326 - jaccard_index: 0.2768 - val_loss: 0.0301 - val_accuracy: 0.8441 - val_dice_coefficient: 0.4192 - val_jaccard_index: 0.2653
# Epoch 40/200
# 6/6 [==============================] - 111s 22s/step - loss: 0.0310 - accuracy: 0.8357 - dice_coefficient: 0.4714 - jaccard_index: 0.3099 - val_loss: 0.0285 - val_accuracy: 0.8568 - val_dice_coefficient: 0.4154 - val_jaccard_index: 0.2623
# Epoch 41/200
# 6/6 [==============================] - 100s 20s/step - loss: 0.0284 - accuracy: 0.8385 - dice_coefficient: 0.5105 - jaccard_index: 0.3431 - val_loss: 0.0295 - val_accuracy: 0.8464 - val_dice_coefficient: 0.4751 - val_jaccard_index: 0.3116
# Epoch 42/200
# 6/6 [==============================] - 92s 18s/step - loss: 0.0282 - accuracy: 0.8393 - dice_coefficient: 0.5230 - jaccard_index: 0.3547 - val_loss: 0.0194 - val_accuracy: 0.8313 - val_dice_coefficient: 0.5202 - val_jaccard_index: 0.3515
# Epoch 43/200
# 6/6 [==============================] - 114s 23s/step - loss: 0.0250 - accuracy: 0.8395 - dice_coefficient: 0.5959 - jaccard_index: 0.4265 - val_loss: 0.0278 - val_accuracy: 0.8468 - val_dice_coefficient: 0.5569 - val_jaccard_index: 0.3872
# Epoch 44/200
# 6/6 [==============================] - 93s 19s/step - loss: 0.0277 - accuracy: 0.8398 - dice_coefficient: 0.6105 - jaccard_index: 0.4416 - val_loss: 0.0370 - val_accuracy: 0.8280 - val_dice_coefficient: 0.4502 - val_jaccard_index: 0.2911
# Epoch 45/200
# 6/6 [==============================] - 106s 21s/step - loss: 0.0297 - accuracy: 0.8389 - dice_coefficient: 0.5425 - jaccard_index: 0.3730 - val_loss: 0.0271 - val_accuracy: 0.8470 - val_dice_coefficient: 0.5042 - val_jaccard_index: 0.3376
# Epoch 46/200
# 6/6 [==============================] - 110s 22s/step - loss: 0.0252 - accuracy: 0.8399 - dice_coefficient: 0.5909 - jaccard_index: 0.4235 - val_loss: 0.0285 - val_accuracy: 0.8540 - val_dice_coefficient: 0.6252 - val_jaccard_index: 0.4548
# Epoch 47/200
# 6/6 [==============================] - 96s 19s/step - loss: 0.0245 - accuracy: 0.8394 - dice_coefficient: 0.6495 - jaccard_index: 0.4834 - val_loss: 0.0272 - val_accuracy: 0.8468 - val_dice_coefficient: 0.6034 - val_jaccard_index: 0.4334
# Epoch 48/200
# 6/6 [==============================] - 109s 22s/step - loss: 0.0223 - accuracy: 0.8395 - dice_coefficient: 0.6775 - jaccard_index: 0.5144 - val_loss: 0.0231 - val_accuracy: 0.8372 - val_dice_coefficient: 0.6639 - val_jaccard_index: 0.4973
# Epoch 49/200
# 6/6 [==============================] - 103s 20s/step - loss: 0.0217 - accuracy: 0.8406 - dice_coefficient: 0.6788 - jaccard_index: 0.5173 - val_loss: 0.0271 - val_accuracy: 0.8474 - val_dice_coefficient: 0.6147 - val_jaccard_index: 0.4444
# Epoch 50/200
# 6/6 [==============================] - 92s 18s/step - loss: 0.0210 - accuracy: 0.8402 - dice_coefficient: 0.6767 - jaccard_index: 0.5127 - val_loss: 0.0227 - val_accuracy: 0.8462 - val_dice_coefficient: 0.6230 - val_jaccard_index: 0.4530
# Epoch 51/200
# 6/6 [==============================] - 112s 22s/step - loss: 0.0186 - accuracy: 0.8403 - dice_coefficient: 0.7127 - jaccard_index: 0.5544 - val_loss: 0.0238 - val_accuracy: 0.8475 - val_dice_coefficient: 0.6767 - val_jaccard_index: 0.5134
# Epoch 52/200
# 6/6 [==============================] - 96s 19s/step - loss: 0.0183 - accuracy: 0.8404 - dice_coefficient: 0.7572 - jaccard_index: 0.6116 - val_loss: 0.0160 - val_accuracy: 0.8418 - val_dice_coefficient: 0.6451 - val_jaccard_index: 0.4762
# Epoch 53/200
# 6/6 [==============================] - 110s 22s/step - loss: 0.0169 - accuracy: 0.8407 - dice_coefficient: 0.7273 - jaccard_index: 0.5744 - val_loss: 0.0183 - val_accuracy: 0.8480 - val_dice_coefficient: 0.6906 - val_jaccard_index: 0.5282
# Epoch 54/200
# 6/6 [==============================] - 95s 19s/step - loss: 0.0142 - accuracy: 0.8409 - dice_coefficient: 0.7867 - jaccard_index: 0.6492 - val_loss: 0.0190 - val_accuracy: 0.8474 - val_dice_coefficient: 0.7372 - val_jaccard_index: 0.5838
# Epoch 55/200
# 6/6 [==============================] - 99s 20s/step - loss: 0.0128 - accuracy: 0.8412 - dice_coefficient: 0.8027 - jaccard_index: 0.6718 - val_loss: 0.0192 - val_accuracy: 0.8479 - val_dice_coefficient: 0.7198 - val_jaccard_index: 0.5624
# Epoch 56/200
# 6/6 [==============================] - 108s 21s/step - loss: 0.0125 - accuracy: 0.8409 - dice_coefficient: 0.8094 - jaccard_index: 0.6812 - val_loss: 0.0384 - val_accuracy: 0.8476 - val_dice_coefficient: 0.6831 - val_jaccard_index: 0.5210
# Epoch 57/200
# 6/6 [==============================] - 103s 21s/step - loss: 0.0142 - accuracy: 0.8411 - dice_coefficient: 0.7935 - jaccard_index: 0.6587 - val_loss: 0.0299 - val_accuracy: 0.8467 - val_dice_coefficient: 0.6113 - val_jaccard_index: 0.4424
# Epoch 58/200
# 6/6 [==============================] - 94s 19s/step - loss: 0.0153 - accuracy: 0.8407 - dice_coefficient: 0.7554 - jaccard_index: 0.6087 - val_loss: 0.0166 - val_accuracy: 0.8203 - val_dice_coefficient: 0.7133 - val_jaccard_index: 0.5543
# Epoch 59/200
# 6/6 [==============================] - 111s 22s/step - loss: 0.0196 - accuracy: 0.8404 - dice_coefficient: 0.7378 - jaccard_index: 0.5862 - val_loss: 0.0232 - val_accuracy: 0.8474 - val_dice_coefficient: 0.6376 - val_jaccard_index: 0.4680
# Epoch 60/200
# 6/6 [==============================] - 95s 19s/step - loss: 0.0181 - accuracy: 0.8404 - dice_coefficient: 0.7278 - jaccard_index: 0.5778 - val_loss: 0.0148 - val_accuracy: 0.8417 - val_dice_coefficient: 0.6878 - val_jaccard_index: 0.5242
# Epoch 61/200
# 6/6 [==============================] - 105s 21s/step - loss: 0.0166 - accuracy: 0.8402 - dice_coefficient: 0.7615 - jaccard_index: 0.6217 - val_loss: 0.0256 - val_accuracy: 0.8472 - val_dice_coefficient: 0.6341 - val_jaccard_index: 0.4675
# Epoch 62/200
# 6/6 [==============================] - 109s 22s/step - loss: 0.0182 - accuracy: 0.8404 - dice_coefficient: 0.7254 - jaccard_index: 0.5720 - val_loss: 0.0225 - val_accuracy: 0.8372 - val_dice_coefficient: 0.7017 - val_jaccard_index: 0.5411
# Epoch 63/200
# 6/6 [==============================] - 89s 18s/step - loss: 0.0161 - accuracy: 0.8409 - dice_coefficient: 0.7639 - jaccard_index: 0.6212 - val_loss: 0.0226 - val_accuracy: 0.8486 - val_dice_coefficient: 0.6813 - val_jaccard_index: 0.5168
# Epoch 64/200
# 6/6 [==============================] - 111s 22s/step - loss: 0.0153 - accuracy: 0.8411 - dice_coefficient: 0.7627 - jaccard_index: 0.6182 - val_loss: 0.0261 - val_accuracy: 0.8655 - val_dice_coefficient: 0.6826 - val_jaccard_index: 0.5186
# Epoch 65/200
# 6/6 [==============================] - 96s 19s/step - loss: 0.0128 - accuracy: 0.8412 - dice_coefficient: 0.7927 - jaccard_index: 0.6593 - val_loss: 0.0178 - val_accuracy: 0.8485 - val_dice_coefficient: 0.7497 - val_jaccard_index: 0.5998
# Epoch 66/200
# 6/6 [==============================] - 110s 22s/step - loss: 0.0166 - accuracy: 0.8408 - dice_coefficient: 0.8014 - jaccard_index: 0.6692 - val_loss: 0.0249 - val_accuracy: 0.8758 - val_dice_coefficient: 0.6333 - val_jaccard_index: 0.4633
# Epoch 67/200
# 6/6 [==============================] - 91s 18s/step - loss: 0.0142 - accuracy: 0.8405 - dice_coefficient: 0.7876 - jaccard_index: 0.6506 - val_loss: 0.0183 - val_accuracy: 0.8475 - val_dice_coefficient: 0.7021 - val_jaccard_index: 0.5444
# Epoch 68/200
# 6/6 [==============================] - 110s 22s/step - loss: 0.0131 - accuracy: 0.8411 - dice_coefficient: 0.7933 - jaccard_index: 0.6591 - val_loss: 0.0143 - val_accuracy: 0.8485 - val_dice_coefficient: 0.7666 - val_jaccard_index: 0.6217
# Epoch 69/200
# 6/6 [==============================] - 99s 20s/step - loss: 0.0110 - accuracy: 0.8413 - dice_coefficient: 0.8251 - jaccard_index: 0.7039 - val_loss: 0.0131 - val_accuracy: 0.8486 - val_dice_coefficient: 0.7817 - val_jaccard_index: 0.6417
# Epoch 70/200
# 6/6 [==============================] - 92s 18s/step - loss: 0.0102 - accuracy: 0.8412 - dice_coefficient: 0.8385 - jaccard_index: 0.7232 - val_loss: 0.0097 - val_accuracy: 0.8315 - val_dice_coefficient: 0.7866 - val_jaccard_index: 0.6486
# Epoch 71/200
# 6/6 [==============================] - 100s 20s/step - loss: 0.0098 - accuracy: 0.8413 - dice_coefficient: 0.8463 - jaccard_index: 0.7351 - val_loss: 0.0143 - val_accuracy: 0.8482 - val_dice_coefficient: 0.7880 - val_jaccard_index: 0.6509
# Epoch 72/200
# 6/6 [==============================] - 110s 22s/step - loss: 0.0089 - accuracy: 0.8413 - dice_coefficient: 0.8591 - jaccard_index: 0.7538 - val_loss: 0.0139 - val_accuracy: 0.8485 - val_dice_coefficient: 0.7854 - val_jaccard_index: 0.6467
# Epoch 73/200
# 6/6 [==============================] - 92s 18s/step - loss: 0.0093 - accuracy: 0.8413 - dice_coefficient: 0.8543 - jaccard_index: 0.7467 - val_loss: 0.0139 - val_accuracy: 0.8483 - val_dice_coefficient: 0.7880 - val_jaccard_index: 0.6520
# Epoch 74/200
# 6/6 [==============================] - 114s 23s/step - loss: 0.0087 - accuracy: 0.8413 - dice_coefficient: 0.8677 - jaccard_index: 0.7670 - val_loss: 0.0184 - val_accuracy: 0.8650 - val_dice_coefficient: 0.7851 - val_jaccard_index: 0.6464
# Epoch 75/200
# 6/6 [==============================] - 94s 19s/step - loss: 0.0085 - accuracy: 0.8413 - dice_coefficient: 0.8680 - jaccard_index: 0.7674 - val_loss: 0.0139 - val_accuracy: 0.8482 - val_dice_coefficient: 0.7828 - val_jaccard_index: 0.6449
# Epoch 76/200
# 6/6 [==============================] - 111s 22s/step - loss: 0.0083 - accuracy: 0.8413 - dice_coefficient: 0.8658 - jaccard_index: 0.7640 - val_loss: 0.0182 - val_accuracy: 0.8770 - val_dice_coefficient: 0.7704 - val_jaccard_index: 0.6266
# Epoch 77/200
# 6/6 [==============================] - 102s 20s/step - loss: 0.0082 - accuracy: 0.8413 - dice_coefficient: 0.8747 - jaccard_index: 0.7780 - val_loss: 0.0144 - val_accuracy: 0.8483 - val_dice_coefficient: 0.8055 - val_jaccard_index: 0.6762
# Epoch 78/200
# 6/6 [==============================] - 93s 18s/step - loss: 0.0082 - accuracy: 0.8413 - dice_coefficient: 0.8705 - jaccard_index: 0.7715 - val_loss: 0.0183 - val_accuracy: 0.8583 - val_dice_coefficient: 0.7779 - val_jaccard_index: 0.6372
# Epoch 79/200
# 6/6 [==============================] - 103s 21s/step - loss: 0.0079 - accuracy: 0.8413 - dice_coefficient: 0.8760 - jaccard_index: 0.7799 - val_loss: 0.0177 - val_accuracy: 0.8482 - val_dice_coefficient: 0.7949 - val_jaccard_index: 0.6623
# Epoch 80/200
# 6/6 [==============================] - 108s 21s/step - loss: 0.0078 - accuracy: 0.8413 - dice_coefficient: 0.8762 - jaccard_index: 0.7804 - val_loss: 0.0201 - val_accuracy: 0.8660 - val_dice_coefficient: 0.7869 - val_jaccard_index: 0.6491
# Epoch 81/200
# 6/6 [==============================] - 93s 19s/step - loss: 0.0075 - accuracy: 0.8413 - dice_coefficient: 0.8715 - jaccard_index: 0.7731 - val_loss: 0.0127 - val_accuracy: 0.8486 - val_dice_coefficient: 0.8166 - val_jaccard_index: 0.6904
# Epoch 82/200
# 6/6 [==============================] - 110s 22s/step - loss: 0.0070 - accuracy: 0.8414 - dice_coefficient: 0.8809 - jaccard_index: 0.7881 - val_loss: 0.0149 - val_accuracy: 0.8382 - val_dice_coefficient: 0.8339 - val_jaccard_index: 0.7153
# Epoch 83/200
# 6/6 [==============================] - 90s 18s/step - loss: 0.0067 - accuracy: 0.8414 - dice_coefficient: 0.8954 - jaccard_index: 0.8111 - val_loss: 0.0227 - val_accuracy: 0.8483 - val_dice_coefficient: 0.8273 - val_jaccard_index: 0.7085
# Epoch 84/200
# 6/6 [==============================] - 110s 22s/step - loss: 0.0065 - accuracy: 0.8414 - dice_coefficient: 0.8987 - jaccard_index: 0.8166 - val_loss: 0.0306 - val_accuracy: 0.8650 - val_dice_coefficient: 0.8040 - val_jaccard_index: 0.6724
# Epoch 85/200
# 6/6 [==============================] - 102s 20s/step - loss: 0.0064 - accuracy: 0.8414 - dice_coefficient: 0.8990 - jaccard_index: 0.8170 - val_loss: 0.0172 - val_accuracy: 0.8485 - val_dice_coefficient: 0.8377 - val_jaccard_index: 0.7215
# Epoch 86/200
# 6/6 [==============================] - 92s 18s/step - loss: 0.0067 - accuracy: 0.8413 - dice_coefficient: 0.8929 - jaccard_index: 0.8072 - val_loss: 0.0275 - val_accuracy: 0.8377 - val_dice_coefficient: 0.8100 - val_jaccard_index: 0.6820
# Epoch 87/200
# 6/6 [==============================] - 101s 20s/step - loss: 0.0076 - accuracy: 0.8413 - dice_coefficient: 0.8859 - jaccard_index: 0.7959 - val_loss: 0.0167 - val_accuracy: 0.8484 - val_dice_coefficient: 0.8122 - val_jaccard_index: 0.6838
# Epoch 88/200
# 6/6 [==============================] - 111s 22s/step - loss: 0.0075 - accuracy: 0.8414 - dice_coefficient: 0.8786 - jaccard_index: 0.7842 - val_loss: 0.0105 - val_accuracy: 0.8382 - val_dice_coefficient: 0.8298 - val_jaccard_index: 0.7091
# Epoch 89/200
# 6/6 [==============================] - 102s 20s/step - loss: 0.0070 - accuracy: 0.8414 - dice_coefficient: 0.8807 - jaccard_index: 0.7876 - val_loss: 0.0132 - val_accuracy: 0.8483 - val_dice_coefficient: 0.8254 - val_jaccard_index: 0.7028
# Epoch 90/200
# 6/6 [==============================] - 90s 18s/step - loss: 0.0064 - accuracy: 0.8414 - dice_coefficient: 0.8907 - jaccard_index: 0.8037 - val_loss: 0.0066 - val_accuracy: 0.8315 - val_dice_coefficient: 0.8533 - val_jaccard_index: 0.7443
# Epoch 91/200
# 6/6 [==============================] - 112s 22s/step - loss: 0.0061 - accuracy: 0.8414 - dice_coefficient: 0.9055 - jaccard_index: 0.8277 - val_loss: 0.0155 - val_accuracy: 0.8484 - val_dice_coefficient: 0.8435 - val_jaccard_index: 0.7308
# Epoch 92/200
# 6/6 [==============================] - 89s 18s/step - loss: 0.0059 - accuracy: 0.8414 - dice_coefficient: 0.9086 - jaccard_index: 0.8330 - val_loss: 0.0072 - val_accuracy: 0.8417 - val_dice_coefficient: 0.8384 - val_jaccard_index: 0.7218
# Epoch 93/200
# 6/6 [==============================] - 103s 21s/step - loss: 0.0058 - accuracy: 0.8414 - dice_coefficient: 0.9017 - jaccard_index: 0.8218 - val_loss: 0.0207 - val_accuracy: 0.8483 - val_dice_coefficient: 0.8375 - val_jaccard_index: 0.7207
# Epoch 94/200
# 6/6 [==============================] - 109s 22s/step - loss: 0.0055 - accuracy: 0.8414 - dice_coefficient: 0.9059 - jaccard_index: 0.8285 - val_loss: 0.0436 - val_accuracy: 0.8759 - val_dice_coefficient: 0.7762 - val_jaccard_index: 0.6344
# Epoch 95/200
# 6/6 [==============================] - 101s 20s/step - loss: 0.0056 - accuracy: 0.8414 - dice_coefficient: 0.9097 - jaccard_index: 0.8348 - val_loss: 0.0193 - val_accuracy: 0.8484 - val_dice_coefficient: 0.8380 - val_jaccard_index: 0.7211
# Epoch 96/200
# 6/6 [==============================] - 91s 18s/step - loss: 0.0054 - accuracy: 0.8414 - dice_coefficient: 0.9112 - jaccard_index: 0.8372 - val_loss: 0.0263 - val_accuracy: 0.8585 - val_dice_coefficient: 0.8365 - val_jaccard_index: 0.7198
# Epoch 97/200
# 6/6 [==============================] - 113s 22s/step - loss: 0.0058 - accuracy: 0.8414 - dice_coefficient: 0.9063 - jaccard_index: 0.8295 - val_loss: 0.0209 - val_accuracy: 0.8481 - val_dice_coefficient: 0.8086 - val_jaccard_index: 0.6787
# Epoch 98/200
# 6/6 [==============================] - 92s 18s/step - loss: 0.0057 - accuracy: 0.8413 - dice_coefficient: 0.9067 - jaccard_index: 0.8300 - val_loss: 0.0231 - val_accuracy: 0.8370 - val_dice_coefficient: 0.8379 - val_jaccard_index: 0.7229
# Epoch 99/200
# 6/6 [==============================] - 109s 22s/step - loss: 0.0064 - accuracy: 0.8414 - dice_coefficient: 0.9087 - jaccard_index: 0.8329 - val_loss: 0.0282 - val_accuracy: 0.8477 - val_dice_coefficient: 0.7926 - val_jaccard_index: 0.6610
# Epoch 100/200
# 6/6 [==============================] - 92s 18s/step - loss: 0.0061 - accuracy: 0.8414 - dice_coefficient: 0.8989 - jaccard_index: 0.8171 - val_loss: 0.0087 - val_accuracy: 0.8197 - val_dice_coefficient: 0.8637 - val_jaccard_index: 0.7602
# Epoch 101/200
# 6/6 [==============================] - 103s 21s/step - loss: 0.0067 - accuracy: 0.8414 - dice_coefficient: 0.8986 - jaccard_index: 0.8162 - val_loss: 0.0135 - val_accuracy: 0.8483 - val_dice_coefficient: 0.8343 - val_jaccard_index: 0.7170
# Epoch 102/200
# 6/6 [==============================] - 109s 22s/step - loss: 0.0059 - accuracy: 0.8414 - dice_coefficient: 0.9011 - jaccard_index: 0.8205 - val_loss: 0.0297 - val_accuracy: 0.8655 - val_dice_coefficient: 0.7724 - val_jaccard_index: 0.6297
# Epoch 103/200
# 6/6 [==============================] - 99s 20s/step - loss: 0.0057 - accuracy: 0.8414 - dice_coefficient: 0.9112 - jaccard_index: 0.8370 - val_loss: 0.0187 - val_accuracy: 0.8483 - val_dice_coefficient: 0.8394 - val_jaccard_index: 0.7247
# Epoch 104/200
# 6/6 [==============================] - 97s 19s/step - loss: 0.0057 - accuracy: 0.8414 - dice_coefficient: 0.9151 - jaccard_index: 0.8437 - val_loss: 0.0069 - val_accuracy: 0.8315 - val_dice_coefficient: 0.8556 - val_jaccard_index: 0.7480
# Epoch 105/200
# 6/6 [==============================] - 110s 22s/step - loss: 0.0056 - accuracy: 0.8414 - dice_coefficient: 0.9090 - jaccard_index: 0.8336 - val_loss: 0.0204 - val_accuracy: 0.8481 - val_dice_coefficient: 0.8253 - val_jaccard_index: 0.7031
# Epoch 106/200
# 6/6 [==============================] - 94s 19s/step - loss: 0.0052 - accuracy: 0.8414 - dice_coefficient: 0.9114 - jaccard_index: 0.8376 - val_loss: 0.0247 - val_accuracy: 0.8583 - val_dice_coefficient: 0.8169 - val_jaccard_index: 0.6924
# Epoch 107/200
# 6/6 [==============================] - 105s 21s/step - loss: 0.0050 - accuracy: 0.8414 - dice_coefficient: 0.9202 - jaccard_index: 0.8525 - val_loss: 0.0256 - val_accuracy: 0.8482 - val_dice_coefficient: 0.8298 - val_jaccard_index: 0.7126
# Epoch 108/200
# 6/6 [==============================] - 90s 18s/step - loss: 0.0049 - accuracy: 0.8414 - dice_coefficient: 0.9217 - jaccard_index: 0.8550 - val_loss: 0.0071 - val_accuracy: 0.8306 - val_dice_coefficient: 0.8675 - val_jaccard_index: 0.7663
# Epoch 109/200
# 6/6 [==============================] - 95s 19s/step - loss: 0.0048 - accuracy: 0.8414 - dice_coefficient: 0.9229 - jaccard_index: 0.8571 - val_loss: 0.0261 - val_accuracy: 0.8481 - val_dice_coefficient: 0.8319 - val_jaccard_index: 0.7159
# Epoch 110/200
# 6/6 [==============================] - 105s 21s/step - loss: 0.0047 - accuracy: 0.8414 - dice_coefficient: 0.9229 - jaccard_index: 0.8574 - val_loss: 0.0372 - val_accuracy: 0.8768 - val_dice_coefficient: 0.7882 - val_jaccard_index: 0.6505
# Epoch 111/200
# 6/6 [==============================] - 95s 19s/step - loss: 0.0047 - accuracy: 0.8414 - dice_coefficient: 0.9238 - jaccard_index: 0.8587 - val_loss: 0.0245 - val_accuracy: 0.8482 - val_dice_coefficient: 0.8468 - val_jaccard_index: 0.7364
# Epoch 112/200
# 6/6 [==============================] - 88s 18s/step - loss: 0.0046 - accuracy: 0.8414 - dice_coefficient: 0.9245 - jaccard_index: 0.8599 - val_loss: 0.0323 - val_accuracy: 0.8479 - val_dice_coefficient: 0.8213 - val_jaccard_index: 0.7015
# Epoch 113/200
# 6/6 [==============================] - 95s 19s/step - loss: 0.0046 - accuracy: 0.8414 - dice_coefficient: 0.9265 - jaccard_index: 0.8633 - val_loss: 0.0277 - val_accuracy: 0.8481 - val_dice_coefficient: 0.8353 - val_jaccard_index: 0.7179
# Epoch 114/200
# 6/6 [==============================] - 103s 21s/step - loss: 0.0047 - accuracy: 0.8414 - dice_coefficient: 0.9231 - jaccard_index: 0.8577 - val_loss: 0.0357 - val_accuracy: 0.8590 - val_dice_coefficient: 0.8087 - val_jaccard_index: 0.6825
# Epoch 115/200
# 6/6 [==============================] - 91s 18s/step - loss: 0.0046 - accuracy: 0.8414 - dice_coefficient: 0.9235 - jaccard_index: 0.8582 - val_loss: 0.0246 - val_accuracy: 0.8481 - val_dice_coefficient: 0.8447 - val_jaccard_index: 0.7314
# Epoch 116/200
# 6/6 [==============================] - 89s 18s/step - loss: 0.0045 - accuracy: 0.8414 - dice_coefficient: 0.9285 - jaccard_index: 0.8668 - val_loss: 0.0304 - val_accuracy: 0.8473 - val_dice_coefficient: 0.8392 - val_jaccard_index: 0.7260
# Epoch 117/200
# 6/6 [==============================] - 96s 19s/step - loss: 0.0044 - accuracy: 0.8414 - dice_coefficient: 0.9278 - jaccard_index: 0.8658 - val_loss: 0.0337 - val_accuracy: 0.8480 - val_dice_coefficient: 0.8285 - val_jaccard_index: 0.7124
# Epoch 118/200
# 6/6 [==============================] - 102s 20s/step - loss: 0.0044 - accuracy: 0.8414 - dice_coefficient: 0.9277 - jaccard_index: 0.8656 - val_loss: 0.0769 - val_accuracy: 0.8643 - val_dice_coefficient: 0.7893 - val_jaccard_index: 0.6521
# Epoch 119/200
# 6/6 [==============================] - 93s 19s/step - loss: 0.0043 - accuracy: 0.8414 - dice_coefficient: 0.9263 - jaccard_index: 0.8631 - val_loss: 0.0418 - val_accuracy: 0.8480 - val_dice_coefficient: 0.8394 - val_jaccard_index: 0.7243
# Epoch 120/200
# 6/6 [==============================] - 108s 21s/step - loss: 0.0046 - accuracy: 0.8414 - dice_coefficient: 0.9309 - jaccard_index: 0.8709 - val_loss: 0.0464 - val_accuracy: 0.8758 - val_dice_coefficient: 0.7915 - val_jaccard_index: 0.6550
# Epoch 121/200
# 6/6 [==============================] - 100s 20s/step - loss: 0.0055 - accuracy: 0.8413 - dice_coefficient: 0.9127 - jaccard_index: 0.8402 - val_loss: 0.0203 - val_accuracy: 0.8481 - val_dice_coefficient: 0.8369 - val_jaccard_index: 0.7216
# Epoch 122/200
# 6/6 [==============================] - 94s 19s/step - loss: 0.0068 - accuracy: 0.8413 - dice_coefficient: 0.8992 - jaccard_index: 0.8173 - val_loss: 0.0256 - val_accuracy: 0.8594 - val_dice_coefficient: 0.8123 - val_jaccard_index: 0.6851
# Epoch 123/200
# 6/6 [==============================] - 110s 22s/step - loss: 0.0062 - accuracy: 0.8414 - dice_coefficient: 0.9018 - jaccard_index: 0.8215 - val_loss: 0.0139 - val_accuracy: 0.8487 - val_dice_coefficient: 0.8314 - val_jaccard_index: 0.7118
# Epoch 124/200
# 6/6 [==============================] - 95s 19s/step - loss: 0.0071 - accuracy: 0.8412 - dice_coefficient: 0.8836 - jaccard_index: 0.7924 - val_loss: 0.0152 - val_accuracy: 0.8483 - val_dice_coefficient: 0.8355 - val_jaccard_index: 0.7177
# Epoch 125/200
# 6/6 [==============================] - 102s 20s/step - loss: 0.0066 - accuracy: 0.8414 - dice_coefficient: 0.9013 - jaccard_index: 0.8207 - val_loss: 0.0232 - val_accuracy: 0.8478 - val_dice_coefficient: 0.7963 - val_jaccard_index: 0.6638
# Epoch 126/200
# 6/6 [==============================] - 109s 22s/step - loss: 0.0062 - accuracy: 0.8414 - dice_coefficient: 0.8984 - jaccard_index: 0.8162 - val_loss: 0.0183 - val_accuracy: 0.8583 - val_dice_coefficient: 0.8198 - val_jaccard_index: 0.6959
# Epoch 127/200
# 6/6 [==============================] - 104s 21s/step - loss: 0.0055 - accuracy: 0.8414 - dice_coefficient: 0.9122 - jaccard_index: 0.8388 - val_loss: 0.0226 - val_accuracy: 0.8480 - val_dice_coefficient: 0.8280 - val_jaccard_index: 0.7114
# Epoch 128/200
# 6/6 [==============================] - 92s 18s/step - loss: 0.0050 - accuracy: 0.8414 - dice_coefficient: 0.9187 - jaccard_index: 0.8500 - val_loss: 0.0279 - val_accuracy: 0.8378 - val_dice_coefficient: 0.8399 - val_jaccard_index: 0.7260
# Epoch 129/200
# 6/6 [==============================] - 102s 20s/step - loss: 0.0051 - accuracy: 0.8414 - dice_coefficient: 0.9224 - jaccard_index: 0.8562 - val_loss: 0.0210 - val_accuracy: 0.8480 - val_dice_coefficient: 0.8387 - val_jaccard_index: 0.7254
# Epoch 130/200
# 6/6 [==============================] - 108s 21s/step - loss: 0.0049 - accuracy: 0.8414 - dice_coefficient: 0.9181 - jaccard_index: 0.8492 - val_loss: 0.0314 - val_accuracy: 0.8758 - val_dice_coefficient: 0.7924 - val_jaccard_index: 0.6562
# Epoch 131/200
# 6/6 [==============================] - 102s 20s/step - loss: 0.0048 - accuracy: 0.8414 - dice_coefficient: 0.9242 - jaccard_index: 0.8594 - val_loss: 0.0260 - val_accuracy: 0.8481 - val_dice_coefficient: 0.8168 - val_jaccard_index: 0.6945
# Epoch 132/200
# 6/6 [==============================] - 91s 18s/step - loss: 0.0047 - accuracy: 0.8414 - dice_coefficient: 0.9233 - jaccard_index: 0.8577 - val_loss: 0.0146 - val_accuracy: 0.8474 - val_dice_coefficient: 0.8457 - val_jaccard_index: 0.7348
# Epoch 133/200
# 6/6 [==============================] - 111s 22s/step - loss: 0.0048 - accuracy: 0.8414 - dice_coefficient: 0.9218 - jaccard_index: 0.8552 - val_loss: 0.0159 - val_accuracy: 0.8481 - val_dice_coefficient: 0.8494 - val_jaccard_index: 0.7386
# Epoch 134/200
# 6/6 [==============================] - 90s 18s/step - loss: 0.0045 - accuracy: 0.8414 - dice_coefficient: 0.9297 - jaccard_index: 0.8688 - val_loss: 0.0075 - val_accuracy: 0.8204 - val_dice_coefficient: 0.8869 - val_jaccard_index: 0.7968
# Epoch 135/200
# 6/6 [==============================] - 99s 20s/step - loss: 0.0043 - accuracy: 0.8414 - dice_coefficient: 0.9279 - jaccard_index: 0.8659 - val_loss: 0.0187 - val_accuracy: 0.8481 - val_dice_coefficient: 0.8492 - val_jaccard_index: 0.7406
# Epoch 136/200
# 6/6 [==============================] - 110s 22s/step - loss: 0.0042 - accuracy: 0.8414 - dice_coefficient: 0.9344 - jaccard_index: 0.8770 - val_loss: 0.0390 - val_accuracy: 0.8749 - val_dice_coefficient: 0.7959 - val_jaccard_index: 0.6610
# Epoch 137/200
# 6/6 [==============================] - 93s 18s/step - loss: 0.0041 - accuracy: 0.8414 - dice_coefficient: 0.9319 - jaccard_index: 0.8727 - val_loss: 0.0235 - val_accuracy: 0.8480 - val_dice_coefficient: 0.8481 - val_jaccard_index: 0.7372
# Epoch 138/200
# 6/6 [==============================] - 113s 22s/step - loss: 0.0041 - accuracy: 0.8414 - dice_coefficient: 0.9327 - jaccard_index: 0.8742 - val_loss: 0.0381 - val_accuracy: 0.8758 - val_dice_coefficient: 0.7931 - val_jaccard_index: 0.6572
# Epoch 139/200
# 6/6 [==============================] - 92s 18s/step - loss: 0.0040 - accuracy: 0.8414 - dice_coefficient: 0.9350 - jaccard_index: 0.8781 - val_loss: 0.0283 - val_accuracy: 0.8480 - val_dice_coefficient: 0.8450 - val_jaccard_index: 0.7329
# Epoch 140/200
# 6/6 [==============================] - 109s 22s/step - loss: 0.0040 - accuracy: 0.8414 - dice_coefficient: 0.9321 - jaccard_index: 0.8732 - val_loss: 0.0256 - val_accuracy: 0.8488 - val_dice_coefficient: 0.8333 - val_jaccard_index: 0.7185
# Epoch 141/200
# 6/6 [==============================] - 86s 17s/step - loss: 0.0039 - accuracy: 0.8414 - dice_coefficient: 0.9359 - jaccard_index: 0.8797 - val_loss: 0.0245 - val_accuracy: 0.8481 - val_dice_coefficient: 0.8511 - val_jaccard_index: 0.7438
# Epoch 142/200
# 6/6 [==============================] - 103s 21s/step - loss: 0.0039 - accuracy: 0.8414 - dice_coefficient: 0.9340 - jaccard_index: 0.8766 - val_loss: 0.0251 - val_accuracy: 0.8481 - val_dice_coefficient: 0.8408 - val_jaccard_index: 0.7296
# Epoch 143/200
# 6/6 [==============================] - 99s 20s/step - loss: 0.0040 - accuracy: 0.8414 - dice_coefficient: 0.9337 - jaccard_index: 0.8760 - val_loss: 0.0225 - val_accuracy: 0.8481 - val_dice_coefficient: 0.8548 - val_jaccard_index: 0.7497
# Epoch 144/200
# 6/6 [==============================] - 89s 18s/step - loss: 0.0039 - accuracy: 0.8414 - dice_coefficient: 0.9365 - jaccard_index: 0.8808 - val_loss: 0.0286 - val_accuracy: 0.8583 - val_dice_coefficient: 0.8414 - val_jaccard_index: 0.7282
# Epoch 145/200
# 6/6 [==============================] - 98s 20s/step - loss: 0.0038 - accuracy: 0.8414 - dice_coefficient: 0.9368 - jaccard_index: 0.8814 - val_loss: 0.0248 - val_accuracy: 0.8481 - val_dice_coefficient: 0.8427 - val_jaccard_index: 0.7328
# Epoch 146/200
# 6/6 [==============================] - 103s 20s/step - loss: 0.0038 - accuracy: 0.8414 - dice_coefficient: 0.9374 - jaccard_index: 0.8824 - val_loss: 0.0368 - val_accuracy: 0.8767 - val_dice_coefficient: 0.7931 - val_jaccard_index: 0.6572
# Epoch 147/200
# 6/6 [==============================] - 90s 18s/step - loss: 0.0038 - accuracy: 0.8414 - dice_coefficient: 0.9351 - jaccard_index: 0.8785 - val_loss: 0.0278 - val_accuracy: 0.8480 - val_dice_coefficient: 0.8484 - val_jaccard_index: 0.7396
# Epoch 148/200
# 6/6 [==============================] - 102s 20s/step - loss: 0.0035 - accuracy: 0.8414 - dice_coefficient: 0.9418 - jaccard_index: 0.8901 - val_loss: 0.0281 - val_accuracy: 0.8481 - val_dice_coefficient: 0.8528 - val_jaccard_index: 0.7466
# Epoch 149/200
# 6/6 [==============================] - 87s 17s/step - loss: 0.0035 - accuracy: 0.8414 - dice_coefficient: 0.9421 - jaccard_index: 0.8908 - val_loss: 0.0269 - val_accuracy: 0.8481 - val_dice_coefficient: 0.8552 - val_jaccard_index: 0.7478
# Epoch 150/200
# 6/6 [==============================] - 105s 21s/step - loss: 0.0033 - accuracy: 0.8414 - dice_coefficient: 0.9434 - jaccard_index: 0.8930 - val_loss: 0.0389 - val_accuracy: 0.8656 - val_dice_coefficient: 0.8172 - val_jaccard_index: 0.6914
# Epoch 151/200
# 6/6 [==============================] - 95s 19s/step - loss: 0.0034 - accuracy: 0.8414 - dice_coefficient: 0.9400 - jaccard_index: 0.8871 - val_loss: 0.0284 - val_accuracy: 0.8481 - val_dice_coefficient: 0.8487 - val_jaccard_index: 0.7379
# Epoch 152/200
# 6/6 [==============================] - 88s 17s/step - loss: 0.0036 - accuracy: 0.8414 - dice_coefficient: 0.9392 - jaccard_index: 0.8856 - val_loss: 0.0275 - val_accuracy: 0.8378 - val_dice_coefficient: 0.8622 - val_jaccard_index: 0.7596
# Epoch 153/200
# 6/6 [==============================] - 97s 19s/step - loss: 0.0036 - accuracy: 0.8414 - dice_coefficient: 0.9386 - jaccard_index: 0.8846 - val_loss: 0.0141 - val_accuracy: 0.8483 - val_dice_coefficient: 0.8582 - val_jaccard_index: 0.7518
# Epoch 154/200
# 6/6 [==============================] - 107s 21s/step - loss: 0.0037 - accuracy: 0.8414 - dice_coefficient: 0.9361 - jaccard_index: 0.8802 - val_loss: 0.0384 - val_accuracy: 0.8647 - val_dice_coefficient: 0.8123 - val_jaccard_index: 0.6840
# Epoch 155/200
# 6/6 [==============================] - 91s 18s/step - loss: 0.0037 - accuracy: 0.8414 - dice_coefficient: 0.9391 - jaccard_index: 0.8853 - val_loss: 0.0216 - val_accuracy: 0.8481 - val_dice_coefficient: 0.8534 - val_jaccard_index: 0.7474
# Epoch 156/200
# 6/6 [==============================] - 110s 22s/step - loss: 0.0036 - accuracy: 0.8414 - dice_coefficient: 0.9399 - jaccard_index: 0.8868 - val_loss: 0.0449 - val_accuracy: 0.8655 - val_dice_coefficient: 0.8106 - val_jaccard_index: 0.6821
# Epoch 157/200
# 6/6 [==============================] - 98s 20s/step - loss: 0.0036 - accuracy: 0.8414 - dice_coefficient: 0.9376 - jaccard_index: 0.8827 - val_loss: 0.0226 - val_accuracy: 0.8480 - val_dice_coefficient: 0.8419 - val_jaccard_index: 0.7296
# Epoch 158/200
# 6/6 [==============================] - 96s 19s/step - loss: 0.0041 - accuracy: 0.8414 - dice_coefficient: 0.9325 - jaccard_index: 0.8739 - val_loss: 0.0259 - val_accuracy: 0.8473 - val_dice_coefficient: 0.8331 - val_jaccard_index: 0.7164
# Epoch 159/200
# 6/6 [==============================] - 100s 20s/step - loss: 0.0053 - accuracy: 0.8414 - dice_coefficient: 0.9186 - jaccard_index: 0.8500 - val_loss: 0.0147 - val_accuracy: 0.8483 - val_dice_coefficient: 0.8443 - val_jaccard_index: 0.7318
# Epoch 160/200
# 6/6 [==============================] - 109s 22s/step - loss: 0.0057 - accuracy: 0.8413 - dice_coefficient: 0.9091 - jaccard_index: 0.8337 - val_loss: 0.0148 - val_accuracy: 0.8483 - val_dice_coefficient: 0.8266 - val_jaccard_index: 0.7053
# Epoch 161/200
# 6/6 [==============================] - 94s 19s/step - loss: 0.0059 - accuracy: 0.8413 - dice_coefficient: 0.9139 - jaccard_index: 0.8417 - val_loss: 0.0158 - val_accuracy: 0.8482 - val_dice_coefficient: 0.8128 - val_jaccard_index: 0.6849
# Epoch 162/200
# 6/6 [==============================] - 113s 23s/step - loss: 0.0052 - accuracy: 0.8414 - dice_coefficient: 0.9134 - jaccard_index: 0.8410 - val_loss: 0.0202 - val_accuracy: 0.8482 - val_dice_coefficient: 0.8073 - val_jaccard_index: 0.6773
# Epoch 163/200
# 6/6 [==============================] - 101s 20s/step - loss: 0.0048 - accuracy: 0.8414 - dice_coefficient: 0.9271 - jaccard_index: 0.8643 - val_loss: 0.0200 - val_accuracy: 0.8480 - val_dice_coefficient: 0.8347 - val_jaccard_index: 0.7201
# Epoch 164/200
# 6/6 [==============================] - 89s 18s/step - loss: 0.0044 - accuracy: 0.8414 - dice_coefficient: 0.9271 - jaccard_index: 0.8646 - val_loss: 0.0235 - val_accuracy: 0.8376 - val_dice_coefficient: 0.8488 - val_jaccard_index: 0.7404
# Epoch 165/200
# 6/6 [==============================] - 109s 22s/step - loss: 0.0041 - accuracy: 0.8414 - dice_coefficient: 0.9340 - jaccard_index: 0.8764 - val_loss: 0.0272 - val_accuracy: 0.8480 - val_dice_coefficient: 0.8442 - val_jaccard_index: 0.7345
# Epoch 166/200
# 6/6 [==============================] - 93s 19s/step - loss: 0.0039 - accuracy: 0.8414 - dice_coefficient: 0.9322 - jaccard_index: 0.8735 - val_loss: 0.0057 - val_accuracy: 0.8315 - val_dice_coefficient: 0.8900 - val_jaccard_index: 0.8021
# Epoch 167/200
# 6/6 [==============================] - 116s 23s/step - loss: 0.0038 - accuracy: 0.8414 - dice_coefficient: 0.9381 - jaccard_index: 0.8837 - val_loss: 0.0296 - val_accuracy: 0.8481 - val_dice_coefficient: 0.8453 - val_jaccard_index: 0.7364
# Epoch 168/200
# 6/6 [==============================] - 95s 19s/step - loss: 0.0037 - accuracy: 0.8414 - dice_coefficient: 0.9379 - jaccard_index: 0.8833 - val_loss: 0.0075 - val_accuracy: 0.8196 - val_dice_coefficient: 0.8962 - val_jaccard_index: 0.8119
# Epoch 169/200
# 6/6 [==============================] - 110s 22s/step - loss: 0.0037 - accuracy: 0.8414 - dice_coefficient: 0.9386 - jaccard_index: 0.8846 - val_loss: 0.0282 - val_accuracy: 0.8481 - val_dice_coefficient: 0.8423 - val_jaccard_index: 0.7319
# Epoch 170/200
# 6/6 [==============================] - 91s 18s/step - loss: 0.0036 - accuracy: 0.8414 - dice_coefficient: 0.9414 - jaccard_index: 0.8894 - val_loss: 0.0337 - val_accuracy: 0.8369 - val_dice_coefficient: 0.8572 - val_jaccard_index: 0.7526
# Epoch 171/200
# 6/6 [==============================] - 101s 20s/step - loss: 0.0037 - accuracy: 0.8414 - dice_coefficient: 0.9393 - jaccard_index: 0.8857 - val_loss: 0.0272 - val_accuracy: 0.8481 - val_dice_coefficient: 0.8471 - val_jaccard_index: 0.7385
# Epoch 172/200
# 6/6 [==============================] - 106s 21s/step - loss: 0.0036 - accuracy: 0.8414 - dice_coefficient: 0.9399 - jaccard_index: 0.8869 - val_loss: 0.0491 - val_accuracy: 0.8646 - val_dice_coefficient: 0.8167 - val_jaccard_index: 0.6905
# Epoch 173/200
# 6/6 [==============================] - 100s 20s/step - loss: 0.0035 - accuracy: 0.8414 - dice_coefficient: 0.9419 - jaccard_index: 0.8905 - val_loss: 0.0323 - val_accuracy: 0.8480 - val_dice_coefficient: 0.8530 - val_jaccard_index: 0.7447
# Epoch 174/200
# 6/6 [==============================] - 92s 18s/step - loss: 0.0033 - accuracy: 0.8414 - dice_coefficient: 0.9432 - jaccard_index: 0.8927 - val_loss: 0.0275 - val_accuracy: 0.8490 - val_dice_coefficient: 0.8519 - val_jaccard_index: 0.7460
# Epoch 175/200
# 6/6 [==============================] - 112s 22s/step - loss: 0.0033 - accuracy: 0.8414 - dice_coefficient: 0.9441 - jaccard_index: 0.8942 - val_loss: 0.0320 - val_accuracy: 0.8481 - val_dice_coefficient: 0.8528 - val_jaccard_index: 0.7471
# Epoch 176/200
# 6/6 [==============================] - 87s 17s/step - loss: 0.0032 - accuracy: 0.8414 - dice_coefficient: 0.9474 - jaccard_index: 0.9000 - val_loss: 0.0370 - val_accuracy: 0.8472 - val_dice_coefficient: 0.8483 - val_jaccard_index: 0.7408
# Epoch 177/200
# 6/6 [==============================] - 101s 20s/step - loss: 0.0033 - accuracy: 0.8414 - dice_coefficient: 0.9475 - jaccard_index: 0.9004 - val_loss: 0.0360 - val_accuracy: 0.8480 - val_dice_coefficient: 0.8486 - val_jaccard_index: 0.7410
# Epoch 178/200
# 6/6 [==============================] - 110s 22s/step - loss: 0.0032 - accuracy: 0.8414 - dice_coefficient: 0.9452 - jaccard_index: 0.8964 - val_loss: 0.0427 - val_accuracy: 0.8368 - val_dice_coefficient: 0.8506 - val_jaccard_index: 0.7429
# Epoch 179/200
# 6/6 [==============================] - 105s 21s/step - loss: 0.0032 - accuracy: 0.8414 - dice_coefficient: 0.9436 - jaccard_index: 0.8935 - val_loss: 0.0389 - val_accuracy: 0.8480 - val_dice_coefficient: 0.8490 - val_jaccard_index: 0.7384
# Epoch 180/200
# 6/6 [==============================] - 92s 18s/step - loss: 0.0031 - accuracy: 0.8414 - dice_coefficient: 0.9451 - jaccard_index: 0.8961 - val_loss: 0.0087 - val_accuracy: 0.8197 - val_dice_coefficient: 0.9066 - val_jaccard_index: 0.8292
# Epoch 181/200
# 6/6 [==============================] - 106s 21s/step - loss: 0.0033 - accuracy: 0.8414 - dice_coefficient: 0.9431 - jaccard_index: 0.8926 - val_loss: 0.0345 - val_accuracy: 0.8480 - val_dice_coefficient: 0.8448 - val_jaccard_index: 0.7321
# Epoch 182/200
# 6/6 [==============================] - 88s 18s/step - loss: 0.0034 - accuracy: 0.8414 - dice_coefficient: 0.9437 - jaccard_index: 0.8936 - val_loss: 0.0363 - val_accuracy: 0.8369 - val_dice_coefficient: 0.8589 - val_jaccard_index: 0.7549
# Epoch 183/200
# 6/6 [==============================] - 106s 21s/step - loss: 0.0046 - accuracy: 0.8412 - dice_coefficient: 0.9342 - jaccard_index: 0.8768 - val_loss: 0.0278 - val_accuracy: 0.8481 - val_dice_coefficient: 0.8292 - val_jaccard_index: 0.7087
# Epoch 184/200
# 6/6 [==============================] - 85s 17s/step - loss: 0.0092 - accuracy: 0.8413 - dice_coefficient: 0.8888 - jaccard_index: 0.8002 - val_loss: 0.0126 - val_accuracy: 0.8594 - val_dice_coefficient: 0.7687 - val_jaccard_index: 0.6249
# Epoch 185/200
# 6/6 [==============================] - 103s 20s/step - loss: 0.0099 - accuracy: 0.8408 - dice_coefficient: 0.8486 - jaccard_index: 0.7389 - val_loss: 0.0138 - val_accuracy: 0.8482 - val_dice_coefficient: 0.8049 - val_jaccard_index: 0.6735
# Epoch 186/200
# 6/6 [==============================] - 88s 18s/step - loss: 0.0103 - accuracy: 0.8413 - dice_coefficient: 0.8632 - jaccard_index: 0.7608 - val_loss: 0.0131 - val_accuracy: 0.8307 - val_dice_coefficient: 0.7668 - val_jaccard_index: 0.6230
# Epoch 187/200
# 6/6 [==============================] - 98s 20s/step - loss: 0.0121 - accuracy: 0.8411 - dice_coefficient: 0.8162 - jaccard_index: 0.6905 - val_loss: 0.0150 - val_accuracy: 0.8481 - val_dice_coefficient: 0.7514 - val_jaccard_index: 0.6019
# Epoch 188/200
# 6/6 [==============================] - 105s 21s/step - loss: 0.0090 - accuracy: 0.8412 - dice_coefficient: 0.8603 - jaccard_index: 0.7555 - val_loss: 0.0132 - val_accuracy: 0.8380 - val_dice_coefficient: 0.8442 - val_jaccard_index: 0.7308
# Epoch 189/200
# 6/6 [==============================] - 84s 17s/step - loss: 0.0079 - accuracy: 0.8411 - dice_coefficient: 0.8869 - jaccard_index: 0.7974 - val_loss: 0.0198 - val_accuracy: 0.8481 - val_dice_coefficient: 0.8060 - val_jaccard_index: 0.6772
# Epoch 190/200
# 6/6 [==============================] - 103s 20s/step - loss: 0.0072 - accuracy: 0.8413 - dice_coefficient: 0.8886 - jaccard_index: 0.8004 - val_loss: 0.0137 - val_accuracy: 0.8594 - val_dice_coefficient: 0.8217 - val_jaccard_index: 0.6983
# Epoch 191/200
# 6/6 [==============================] - 85s 17s/step - loss: 0.0059 - accuracy: 0.8414 - dice_coefficient: 0.9012 - jaccard_index: 0.8206 - val_loss: 0.0139 - val_accuracy: 0.8484 - val_dice_coefficient: 0.8415 - val_jaccard_index: 0.7264
# Epoch 192/200
# 6/6 [==============================] - 102s 20s/step - loss: 0.0057 - accuracy: 0.8414 - dice_coefficient: 0.9114 - jaccard_index: 0.8374 - val_loss: 0.0423 - val_accuracy: 0.8540 - val_dice_coefficient: 0.7842 - val_jaccard_index: 0.6450
# Epoch 193/200
# 6/6 [==============================] - 88s 18s/step - loss: 0.0049 - accuracy: 0.8414 - dice_coefficient: 0.9176 - jaccard_index: 0.8483 - val_loss: 0.0206 - val_accuracy: 0.8482 - val_dice_coefficient: 0.8459 - val_jaccard_index: 0.7352
# Epoch 194/200
# 6/6 [==============================] - 102s 20s/step - loss: 0.0045 - accuracy: 0.8414 - dice_coefficient: 0.9267 - jaccard_index: 0.8638 - val_loss: 0.0463 - val_accuracy: 0.8543 - val_dice_coefficient: 0.8153 - val_jaccard_index: 0.6883
# Epoch 195/200
# 6/6 [==============================] - 96s 19s/step - loss: 0.0043 - accuracy: 0.8414 - dice_coefficient: 0.9315 - jaccard_index: 0.8720 - val_loss: 0.0248 - val_accuracy: 0.8482 - val_dice_coefficient: 0.8461 - val_jaccard_index: 0.7367
# Epoch 196/200
# 6/6 [==============================] - 89s 18s/step - loss: 0.0041 - accuracy: 0.8414 - dice_coefficient: 0.9327 - jaccard_index: 0.8742 - val_loss: 0.0072 - val_accuracy: 0.8307 - val_dice_coefficient: 0.8854 - val_jaccard_index: 0.7946
# Epoch 197/200
# 6/6 [==============================] - 93s 19s/step - loss: 0.0042 - accuracy: 0.8414 - dice_coefficient: 0.9323 - jaccard_index: 0.8734 - val_loss: 0.0276 - val_accuracy: 0.8480 - val_dice_coefficient: 0.8340 - val_jaccard_index: 0.7206
# Epoch 198/200
# 6/6 [==============================] - 107s 21s/step - loss: 0.0043 - accuracy: 0.8414 - dice_coefficient: 0.9295 - jaccard_index: 0.8687 - val_loss: 0.0657 - val_accuracy: 0.8643 - val_dice_coefficient: 0.7816 - val_jaccard_index: 0.6416
# Epoch 199/200
# 6/6 [==============================] - 95s 19s/step - loss: 0.0042 - accuracy: 0.8414 - dice_coefficient: 0.9346 - jaccard_index: 0.8776 - val_loss: 0.0307 - val_accuracy: 0.8481 - val_dice_coefficient: 0.8398 - val_jaccard_index: 0.7240
# Epoch 200/200
# 6/6 [==============================] - 87s 17s/step - loss: 0.0038 - accuracy: 0.8414 - dice_coefficient: 0.9365 - jaccard_index: 0.8807 - val_loss: 0.0379 - val_accuracy: 0.8590 - val_dice_coefficient: 0.8054 - val_jaccard_index: 0.6770
# 2/2 [==============================] - 22s 22s/step - loss: 0.0111 - accuracy: 0.8646 - dice_coefficient: 0.9013 - jaccard_index: 0.8205
# Test Loss: 0.011067278683185577
# Test Accuracy: 0.8646130561828613
# Test Dice Coefficient: 0.9013105630874634
# Test Jaccard Index: 0.8205133676528931

# %%
def display_results_with_marching_cubes(model, file_list, data_path, mask_path, num_images=3):
    target_shape = (128, 128, 64)  # Fixed shape for all volumes
    num_images = min(num_images, len(file_list))  # Ensure we do not exceed the number of files
    
    for i in range(num_images):
        # Load image and mask
        image_file_path = os.path.join(data_path, file_list[i])
        mask_file_path = os.path.join(mask_path, file_list[i])
        
        print(f"Processing file {i+1}/{num_images}: {file_list[i]}")
        
        try:
            image = nib.load(image_file_path).get_fdata(dtype=np.float32)
            mask = nib.load(mask_file_path).get_fdata(dtype=np.float32)
            
            # Resize image and mask to expected shape
            image = resize_image(image, target_shape[:2])
            mask = resize_image(mask, target_shape[:2])
            
            # Pad or crop image and mask to match target depth
            image = pad_or_crop_volume(image, target_shape)
            mask = pad_or_crop_volume(mask, target_shape)
            
            # Preprocess image and mask
            image = image[..., np.newaxis]
            mask = mask[..., np.newaxis]

            # Get prediction
            prediction = model.predict(np.expand_dims(image, axis=0))[0, ..., 0]
            
            # Calculate the volume
            voxel_volume = np.prod(image.shape) / np.sum(mask > 0)  # Example volume calculation
            liver_volume = calculate_volume(mask, voxel_volume)
            print(f"Calculated volume for {file_list[i]}: {liver_volume:.2f} cubic units")

            # 3D Visualization using marching cubes
            verts, faces, _, _ = marching_cubes(mask[..., 0], level=0.5)
            fig = plt.figure(figsize=(12, 6))

            # Subplot 1: Original Data (image slice)
            ax1 = fig.add_subplot(131)
            ax1.imshow(image[:, :, target_shape[2] // 2, 0], cmap='gray')
            ax1.set_title("Image Slice")
            ax1.axis('off')

            # Subplot 2: Ground Truth Mask (slice)
            ax2 = fig.add_subplot(132)
            ax2.imshow(mask[:, :, target_shape[2] // 2, 0], cmap='gray')
            ax2.set_title("Mask Slice")
            ax2.axis('off')

            # Subplot 3: 3D Reconstructed Surface
            ax3 = fig.add_subplot(133, projection='3d')
            mesh = Poly3DCollection(verts[faces], alpha=0.7, edgecolor='none')
            ax3.add_collection3d(mesh)
            ax3.set_xlim(0, mask.shape[0])
            ax3.set_ylim(0, mask.shape[1])
            ax3.set_zlim(0, mask.shape[2])
            ax3.set_title("3D Reconstructed Surface")
            ax3.set_xlabel("X axis")
            ax3.set_ylabel("Y axis")
            ax3.set_zlabel("Z axis")

            plt.tight_layout()
            plt.show()
        
        except Exception as e:
            print(f"Error processing file {file_list[i]}: {e}")

# Call the updated function
display_results_with_marching_cubes(model, val_files, data_path, mask_path)
# Out:
# Processing file 1/3: liver_10P.nii.gz
# 1/1 [==============================] - 0s 27ms/step
# Calculated volume for liver_10P.nii.gz: 758506.52 cubic units
# Processing file 2/3: liver_1P.nii.gz
# 1/1 [==============================] - 0s 26ms/step
# Calculated volume for liver_1P.nii.gz: 551736.86 cubic units
# Processing file 3/3: liver_16P.nii.gz
# 1/1 [==============================] - 0s 25ms/step
# Calculated volume for liver_16P.nii.gz: 782089.59 cubic units
