# %%
from skimage.measure import marching_cubes
from mpl_toolkits.mplot3d.art3d import Poly3DCollection

# %%
import os
import numpy as np
import cv2
import nibabel as nib
#%matplotlib inline
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv3D, MaxPooling3D, UpSampling3D, concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from skimage.transform import resize
from mpl_toolkits.mplot3d import Axes3D
import tensorflow as tf
import scipy.ndimage
# Out:
# 2024-12-19 12:45:51.199274: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-19 12:45:51.751300: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-19 12:45:51.751408: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-19 12:45:51.840612: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-19 12:45:52.020190: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-19 12:45:53.460925: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Function to load NIfTI files with memory mapping
def load_nifti_memmap(file_path):
    img = nib.load(file_path)
    data = img.get_fdata(dtype=np.float32, caching='unchanged')  # Memory-mapped array
    affine = img.affine
    header = img.header
    return data, affine, header

# Generator function to load data in batches
def data_generator(file_list, data_path, mask_path, batch_size, target_shape=None):
    while True:
        np.random.shuffle(file_list)
        for start in range(0, len(file_list), batch_size):
            end = min(start + batch_size, len(file_list))
            batch_files = file_list[start:end]
            
            X_batch = []
            y_batch = []
            
            for filename in batch_files:
                img_path = os.path.join(data_path, filename)
                corresponding_mask_path = os.path.join(mask_path, filename)
                
                image, _, _ = load_nifti_memmap(img_path)
                mask, _, _ = load_nifti_memmap(corresponding_mask_path)
                
                # Ensure image and mask have the same shape (and possibly resize if needed)
                if target_shape:
                    image = resize_volume(image, target_shape)
                    mask = resize_volume(mask, target_shape)
                
                X_batch.append(image)
                y_batch.append(mask)
            
            X_batch = np.array(X_batch)[..., np.newaxis]  # Adding channel dimension
            y_batch = np.array(y_batch)[..., np.newaxis]  # Adding channel dimension
            
            yield X_batch, y_batch

# Function to resize volumes (if needed)
def resize_volume(img, target_shape):
    current_shape = img.shape
    if current_shape == target_shape:
        return img
    # Example: using scipy for interpolation
    resized_img = scipy.ndimage.zoom(img, (target_shape[0]/current_shape[0], target_shape[1]/current_shape[1], target_shape[2]/current_shape[2]), order=3)
    return resized_img

def resize_image(image, target_shape):
    # Resize the image to match the target shape (height, width)
    return resize(image, target_shape, preserve_range=True, anti_aliasing=True)

def pad_or_crop_volume(volume, target_shape):
    current_shape = volume.shape
    
    # Calculate padding width for each dimension
    pad_width = [(0, max(target_shape[i] - current_shape[i], 0)) for i in range(3)]
    
    # Pad the volume to the target shape
    volume = np.pad(volume, pad_width, mode='constant', constant_values=0)
    
    # Calculate cropping dimensions for each dimension
    crop_start = [(volume.shape[i] - target_shape[i]) // 2 for i in range(3)]
    crop_end = [crop_start[i] + target_shape[i] for i in range(3)]
    
    # Crop the volume to the target shape
    slices = [slice(crop_start[i], crop_end[i]) for i in range(3)]
    volume = volume[slices[0], slices[1], slices[2]]
    
    return volume

def calculate_volume(mask, voxel_volume):
    # Calculate the volume based on the mask
    return np.sum(mask) * voxel_volume
    
def unet_3d(input_shape):
    inputs = Input(input_shape)
    
    # Downsampling
    c1 = Conv3D(32, (3, 3, 3), activation='relu', padding='same')(inputs)
    c1 = Conv3D(32, (3, 3, 3), activation='relu', padding='same')(c1)
    c1 = Conv3D(32, (3, 3, 3), activation='relu', padding='same')(c1)  # Added layer
    c1 = Conv3D(32, (3, 3, 3), activation='relu', padding='same')(c1)  # Added layer
    p1 = MaxPooling3D((2, 2, 2))(c1)
    
    c2 = Conv3D(64, (3, 3, 3), activation='relu', padding='same')(p1)
    c2 = Conv3D(64, (3, 3, 3), activation='relu', padding='same')(c2)
    c2 = Conv3D(64, (3, 3, 3), activation='relu', padding='same')(c2)  # Added layer
    c2 = Conv3D(64, (3, 3, 3), activation='relu', padding='same')(c2)  # Added layer
    p2 = MaxPooling3D((2, 2, 2))(c2)
    
    c3 = Conv3D(128, (3, 3, 3), activation='relu', padding='same')(p2)
    c3 = Conv3D(128, (3, 3, 3), activation='relu', padding='same')(c3)
    c3 = Conv3D(128, (3, 3, 3), activation='relu', padding='same')(c3)  # Added layer
    c3 = Conv3D(128, (3, 3, 3), activation='relu', padding='same')(c3)  # Added layer
    
    # Upsampling
    u4 = UpSampling3D((2, 2, 2))(c3)
    u4 = concatenate([u4, c2])
    c4 = Conv3D(64, (3, 3, 3), activation='relu', padding='same')(u4)
    c4 = Conv3D(64, (3, 3, 3), activation='relu', padding='same')(c4)
    c4 = Conv3D(64, (3, 3, 3), activation='relu', padding='same')(c4)  # Added layer
    c4 = Conv3D(64, (3, 3, 3), activation='relu', padding='same')(c4)  # Added layer
    
    u5 = UpSampling3D((2, 2, 2))(c4)
    u5 = concatenate([u5, c1])
    c5 = Conv3D(32, (3, 3, 3), activation='relu', padding='same')(u5)
    c5 = Conv3D(32, (3, 3, 3), activation='relu', padding='same')(c5)
    c5 = Conv3D(32, (3, 3, 3), activation='relu', padding='same')(c5)  # Added layer
    c5 = Conv3D(32, (3, 3, 3), activation='relu', padding='same')(c5)  # Added layer
    
    outputs = Conv3D(1, (1, 1, 1), activation='sigmoid')(c5)
    
    model = Model(inputs=[inputs], outputs=[outputs])
    return model
    
    model = Model(inputs, outputs)
    #model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy', dice_coefficient, jaccard_index])
    return model

# Dice coefficient
def dice_coefficient(y_true, y_pred):
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) + 1)

# Jaccard index
def jaccard_index(y_true, y_pred):
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
    return (intersection + 1) / (tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) - intersection + 1)

# Example paths (update these to your dataset paths)
data_path = r'/home/icmr/Downloads/niigz dicom/Arterial Phase'  # Update with the correct path
mask_path = r'/home/icmr/Downloads/niigz liver/Arterial Phase'  # Update with the correct path

# Verify paths exist
if not os.path.exists(data_path):
    raise FileNotFoundError(f"Data path not found: {data_path}")
if not os.path.exists(mask_path):
    raise FileNotFoundError(f"Mask path not found: {mask_path}")

# List of files
file_list = [filename for filename in os.listdir(data_path) if filename.endswith('.nii.gz')]
#file_list_test = 
# Split the dataset
train_val_files, test_files = train_test_split(file_list, test_size=0.2, random_state=42)
train_files, val_files = train_test_split(train_val_files, test_size=0.25, random_state=42)  # 0.25 * 0.8 = 0.2

# Define and compile the model
input_shape = (128, 128, 64, 1)  # Example input shape, adjust accordingly
model = unet_3d(input_shape)
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy', dice_coefficient, jaccard_index])
  
# Define callbacks
checkpoint = ModelCheckpoint('unet3d_best_model.h5', save_best_only=True, monitor='val_loss', mode='min')
#early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Define batch size
batch_size = 2

# Create data generators
train_generator = data_generator(train_files, data_path, mask_path, batch_size, target_shape=input_shape[:3])
val_generator = data_generator(val_files, data_path, mask_path, batch_size, target_shape=input_shape[:3])
test_generator = data_generator(test_files, data_path, mask_path, batch_size, target_shape=input_shape[:3])

# Calculate steps per epoch
steps_per_epoch = len(train_files) // batch_size
validation_steps = len(val_files) // batch_size
test_steps = len(test_files) // batch_size

# Train the model
history = model.fit(train_generator, validation_data=val_generator, epochs=200, steps_per_epoch=steps_per_epoch, validation_steps=validation_steps, callbacks=[checkpoint])

# Save the model
model.save('unet3d_model.h5')

# Evaluate the model on the test set
test_loss, test_accuracy, test_dice, test_jaccard = model.evaluate(test_generator, steps=test_steps)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
print(f"Test Dice Coefficient: {test_dice}")
print(f"Test Jaccard Index: {test_jaccard}")
# Out:
# 2024-12-19 12:48:52.626458: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 43322 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:51:00.0, compute capability: 8.6
# Epoch 1/200
# 2024-12-19 12:49:08.752933: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8902
# 2024-12-19 12:49:09.082504: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-12-19 12:49:09.771094: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-12-19 12:49:16.502832: I external/local_xla/xla/service/service.cc:168] XLA service 0x73b45db08c50 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-12-19 12:49:16.502876: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2024-12-19 12:49:16.521374: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1734592756.684352   21400 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 6/6 [==============================] - 72s 9s/step - loss: 5.5274 - accuracy: 0.6003 - dice_coefficient: 0.1190 - jaccard_index: 0.0651 - val_loss: 0.1310 - val_accuracy: 0.6708 - val_dice_coefficient: 0.2399 - val_jaccard_index: 0.1368
# Epoch 2/200
# /home/icmr/myenv_py311/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 6/6 [==============================] - 52s 10s/step - loss: 0.1022 - accuracy: 0.7309 - dice_coefficient: 0.2187 - jaccard_index: 0.1231 - val_loss: 0.1259 - val_accuracy: 0.6427 - val_dice_coefficient: 0.3008 - val_jaccard_index: 0.1772
# Epoch 3/200
# 6/6 [==============================] - 54s 11s/step - loss: 0.0833 - accuracy: 0.7309 - dice_coefficient: 0.2924 - jaccard_index: 0.1717 - val_loss: 0.1061 - val_accuracy: 0.6707 - val_dice_coefficient: 0.3608 - val_jaccard_index: 0.2204
# Epoch 4/200
# 6/6 [==============================] - 54s 11s/step - loss: 0.0782 - accuracy: 0.7308 - dice_coefficient: 0.3293 - jaccard_index: 0.1974 - val_loss: 0.0931 - val_accuracy: 0.6699 - val_dice_coefficient: 0.3873 - val_jaccard_index: 0.2404
# Epoch 5/200
# 6/6 [==============================] - 52s 10s/step - loss: 0.0729 - accuracy: 0.7304 - dice_coefficient: 0.3425 - jaccard_index: 0.2084 - val_loss: 0.0909 - val_accuracy: 0.6701 - val_dice_coefficient: 0.4456 - val_jaccard_index: 0.2869
# Epoch 6/200
# 6/6 [==============================] - 52s 10s/step - loss: 0.0640 - accuracy: 0.7301 - dice_coefficient: 0.4117 - jaccard_index: 0.2594 - val_loss: 0.0812 - val_accuracy: 0.6705 - val_dice_coefficient: 0.4542 - val_jaccard_index: 0.2941
# Epoch 7/200
# 6/6 [==============================] - 52s 10s/step - loss: 0.0606 - accuracy: 0.7309 - dice_coefficient: 0.4257 - jaccard_index: 0.2709 - val_loss: 0.0747 - val_accuracy: 0.6703 - val_dice_coefficient: 0.4866 - val_jaccard_index: 0.3219
# Epoch 8/200
# 6/6 [==============================] - 53s 10s/step - loss: 0.0582 - accuracy: 0.7316 - dice_coefficient: 0.4525 - jaccard_index: 0.2930 - val_loss: 0.0781 - val_accuracy: 0.6814 - val_dice_coefficient: 0.4810 - val_jaccard_index: 0.3171
# Epoch 9/200
# 6/6 [==============================] - 51s 10s/step - loss: 0.0556 - accuracy: 0.7347 - dice_coefficient: 0.4656 - jaccard_index: 0.3052 - val_loss: 0.0721 - val_accuracy: 0.6851 - val_dice_coefficient: 0.5223 - val_jaccard_index: 0.3535
# Epoch 10/200
# 6/6 [==============================] - 53s 11s/step - loss: 0.0525 - accuracy: 0.7364 - dice_coefficient: 0.5085 - jaccard_index: 0.3423 - val_loss: 0.0675 - val_accuracy: 0.6846 - val_dice_coefficient: 0.5389 - val_jaccard_index: 0.3688
# Epoch 11/200
# 6/6 [==============================] - 53s 11s/step - loss: 0.0500 - accuracy: 0.7366 - dice_coefficient: 0.4934 - jaccard_index: 0.3279 - val_loss: 0.0668 - val_accuracy: 0.6865 - val_dice_coefficient: 0.5593 - val_jaccard_index: 0.3882
# Epoch 12/200
# 6/6 [==============================] - 52s 10s/step - loss: 0.
200
# 6/6 [==============================] - 52s 10s/step - loss: 0.0064 - accuracy: 0.7400 - dice_coefficient: 0.9451 - jaccard_index: 0.8960 - val_loss: 0.0394 - val_accuracy: 0.6701 - val_dice_coefficient: 0.9198 - val_jaccard_index: 0.8516
# Epoch 121/200
# 6/6 [==============================] - 52s 10s/step - loss: 0.0064 - accuracy: 0.7400 - dice_coefficient: 0.9413 - jaccard_index: 0.8891 - val_loss: 0.0461 - val_accuracy: 0.6872 - val_dice_coefficient: 0.9079 - val_jaccard_index: 0.8316
# Epoch 122/200
# 6/6 [==============================] - 53s 11s/step - loss: 0.0065 - accuracy: 0.7400 - dice_coefficient: 0.9424 - jaccard_index: 0.8911 - val_loss: 0.0979 - val_accuracy: 0.6801 - val_dice_coefficient: 0.8907 - val_jaccard_index: 0.8029
# Epoch 123/200
# 6/6 [==============================] - 49s 10s/step - loss: 0.0065 - accuracy: 0.7400 - dice_coefficient: 0.9459 - jaccard_index: 0.8974 - val_loss: 0.0612 - val_accuracy: 0.6867 - val_dice_coefficient: 0.8963 - val_jaccard_index: 0.8130
# Epoch 124/200
# 6/6 [==============================] - 56s 11s/step - loss: 0.0066 - accuracy: 0.7400 - dice_coefficient: 0.9400 - jaccard_index: 0.8868 - val_loss: 0.0379 - val_accuracy: 0.6702 - val_dice_coefficient: 0.9197 - val_jaccard_index: 0.8514
# Epoch 125/200
# 6/6 [==============================] - 48s 10s/step - loss: 0.0063 - accuracy: 0.7400 - dice_coefficient: 0.9441 - jaccard_index: 0.8941 - val_loss: 0.0447 - val_accuracy: 0.6869 - val_dice_coefficient: 0.9004 - val_jaccard_index: 0.8188
# Epoch 126/200
# 6/6 [==============================] - 51s 10s/step - loss: 0.0062 - accuracy: 0.7400 - dice_coefficient: 0.9449 - jaccard_index: 0.8956 - val_loss: 0.0394 - val_accuracy: 0.6976 - val_dice_coefficient: 0.9128 - val_jaccard_index: 0.8399
# Epoch 127/200
# 6/6 [==============================] - 52s 10s/step - loss: 0.0061 - accuracy: 0.7400 - dice_coefficient: 0.9473 - jaccard_index: 0.9000 - val_loss: 0.0503 - val_accuracy: 0.6868 - val_dice_coefficient: 0.8998 - val_jaccard_index: 0.8179
# Epoch 128/200
# 6/6 [==============================] - 52s 10s/step - loss: 0.0061 - accuracy: 0.7400 - dice_coefficient: 0.9472 - jaccard_index: 0.8997 - val_loss: 0.0703 - val_accuracy: 0.6732 - val_dice_coefficient: 0.9022 - val_jaccard_index: 0.8218
# Epoch 129/200
# 6/6 [==============================] - 53s 11s/step - loss: 0.0065 - accuracy: 0.7399 - dice_coefficient: 0.9447 - jaccard_index: 0.8953 - val_loss: 0.0750 - val_accuracy: 0.6860 - val_dice_coefficient: 0.8678 - val_jaccard_index: 0.7666
# Epoch 130/200
# 6/6 [==============================] - 53s 11s/step - loss: 0.0069 - accuracy: 0.7399 - dice_coefficient: 0.9410 - jaccard_index: 0.8886 - val_loss: 0.0250 - val_accuracy: 0.6836 - val_dice_coefficient: 0.9096 - val_jaccard_index: 0.8343
# Epoch 131/200
# 6/6 [==============================] - 52s 10s/step - loss: 0.0069 - accuracy: 0.7399 - dice_coefficient: 0.9424 - jaccard_index: 0.8911 - val_loss: 0.0483 - val_accuracy: 0.6873 - val_dice_coefficient: 0.9110 - val_jaccard_index: 0.8366
# Epoch 132/200
# 6/6 [==============================] - 52s 10s/step - loss: 0.0078 - accuracy: 0.7399 - dice_coefficient: 0.9379 - jaccard_index: 0.8832 - val_loss: 0.0779 - val_accuracy: 0.7025 - val_dice_coefficient: 0.8372 - val_jaccard_index: 0.7200
# Epoch 133/200
# 6/6 [==============================] - 52s 10s/step - loss: 0.0086 - accuracy: 0.7398 - dice_coefficient: 0.9234 - jaccard_index: 0.8579 - val_loss: 0.0436 - val_accuracy: 0.6877 - val_dice_coefficient: 0.9059 - val_jaccard_index: 0.8280
# Epoch 134/200
# 6/6 [==============================] - 52s 10s/step - loss: 0.0079 - accuracy: 0.7399 - dice_coefficient: 0.9361 - jaccard_index: 0.8800 - val_loss: 0.0581 - val_accuracy: 0.7050 - val_dice_coefficient: 0.8931 - val_jaccard_index: 0.8070
# Epoch 135/200
# 6/6 [==============================] - 52s 10s/step - loss: 0.0074 - accuracy: 0.7399 - dice_coefficient: 0.9339 - jaccard_index: 0.8761 - val_loss: 0.0451 - val_accuracy: 0.6874 - val_dice_coefficient: 0.9011 - val_jaccard_index: 0.8203
# Epoch 136/200
# 6/6 [==============================] - 54s 11s/step - loss: 0.0070 - accuracy: 0.7399 - dice_coefficient: 0.9350 - jaccard_index: 0.8780 - val_loss: 0.0237 - val_accuracy: 0.7113 - val_dice_coefficient: 0.9001 - val_jaccard_index: 0.8188
# Epoch 137/200
# 6/6 [==============================] - 51s 10s/step - loss: 0.0067 - accuracy: 0.7399 - dice_coefficient: 0.9434 - jaccard_index: 0.8929 - val_loss: 0.0678 - val_accuracy: 0.6866 - val_dice_coefficient: 0.8883 - val_jaccard_index: 0.7990
# Epoch 138/200
# 6/6 [==============================] - 53s 10s/step - loss: 0.0066 - accuracy: 0.7399 - dice_coefficient: 0.9445 - jaccard_index: 0.8948 - val_loss: 0.0269 - val_accuracy: 0.7008 - val_dice_coefficient: 0.8998 - val_jaccard_index: 0.8181
# Epoch 139/200
# 6/6 [==============================] - 54s 11s/step - loss: 0.0070 - accuracy: 0.7399 - dice_coefficient: 0.9402 - jaccard_index: 0.8872 - val_loss: 0.0436 - val_accuracy: 0.6874 - val_dice_coefficient: 0.9057 - val_jaccard_index: 0.8276
# Epoch 140/200
# 6/6 [==============================] - 52s 10s/step - loss: 0.0063 - accuracy: 0.7400 - dice_coefficient: 0.9401 - jaccard_index: 0.8872 - val_loss: 0.0357 - val_accuracy: 0.7006 - val_dice_coefficient: 0.8850 - val_jaccard_index: 0.7940
# Epoch 141/200
# 6/6 [==============================] - 52s 10s/step - loss: 0.0060 - accuracy: 0.7400 - dice_coefficient: 0.9479 - jaccard_index: 0.9010 - val_loss: 0.0413 - val_accuracy: 0.6875 - val_dice_coefficient: 0.9179 - val_jaccard_index: 0.8484
# Epoch 142/200
# 6/6 [==============================] - 50s 10s/step - loss: 0.0058 - accuracy: 0.7400 - dice_coefficient: 0.9494 - jaccard_index: 0.9038 - val_loss: 0.0375 - val_accuracy: 0.7005 - val_dice_coefficient: 0.8848 - val_jaccard_index: 0.7935
# Epoch 143/200
# 6/6 [==============================] - 49s 10s/step - loss: 0.0057 - accuracy: 0.7399 - dice_coefficient: 0.9469 - jaccard_index: 0.8993 - val_loss: 0.0548 - val_accuracy: 0.6870 - val_dice_coefficient: 0.9071 - val_jaccard_index: 0.8305
# Epoch 144/200
# 6/6 [==============================] - 52s 10s/step - loss: 0.0056 - accuracy: 0.7400 - dice_coefficient: 0.9508 - jaccard_index: 0.9063 - val_loss: 0.0556 - val_accuracy: 0.6872 - val_dice_coefficient: 0.9127 - val_jaccard_index: 0.8397
# Epoch 145/200
# 6/6 [==============================] - 53s 11s/step - loss: 0.0055 - accuracy: 0.7400 - dice_coefficient: 0.9513 - jaccard_index: 0.9073 - val_loss: 0.0525 - val_accuracy: 0.6872 - val_dice_coefficient: 0.8999 - val_jaccard_index: 0.8186
# Epoch 146/200
# 6/6 [==============================] - 52s 10s/step - loss: 0.0054 - accuracy: 0.7400 - dice_coefficient: 0.9501 - jaccard_index: 0.9050 - val_loss: 0.0349 - val_accuracy: 0.7283 - val_dice_coefficient: 0.8830 - val_jaccard_index: 0.7905
# Epoch 147/200
# 6/6 [==============================] - 54s 11s/step - loss: 0.0054 - accuracy: 0.7400 - dice_coefficient: 0.9525 - jaccard_index: 0.9093 - val_loss: 0.0535 - val_accuracy: 0.6872 - val_dice_coefficient: 0.9120 - val_jaccard_index: 0.8387
# Epoch 148/200
# 6/6 [==============================] - 52s 10s/step - loss: 0.0052 - accuracy: 0.7400 - dice_coefficient: 0.9534 - jaccard_index: 0.9110 - val_loss: 0.0306 - val_accuracy: 0.7112 - val_dice_coefficient: 0.9034 - val_jaccard_index: 0.8246
# Epoch 149/200
# 6/6 [==============================] - 49s 10s/step - loss: 0.0056 - accuracy: 0.7400 - dice_coefficient: 0.9515 - jaccard_index: 0.9075 - val_loss: 0.0549 - val_accuracy: 0.6869 - val_dice_coefficient: 0.8984 - val_jaccard_index: 0.8156
# Epoch 150/200
# 6/6 [==============================] - 52s 10s/step - loss: 0.0058 - accuracy: 0.7400 - dice_coefficient: 0.9493 - jaccard_index: 0.9036 - val_loss: 0.0696 - val_accuracy: 0.6855 - val_dice_coefficient: 0.8709 - val_jaccard_index: 0.7714
# Epoch 151/200
# 6/6 [==============================] - 54s 11s/step - loss: 0.0057 - accuracy: 0.7399 - dice_coefficient: 0.9501 - jaccard_index: 0.9050 - val_loss: 0.0504 - val_accuracy: 0.6873 - val_dice_coefficient: 0.9107 - val_jaccard_index: 0.8364
# Epoch 152/200
# 6/6 [==============================] - 51s 10s/step - loss: 0.0060 - accuracy: 0.7400 - dice_coefficient: 0.9479 - jaccard_index: 0.9010 - val_loss: 0.0207 - val_accuracy: 0.6941 - val_dice_coefficient: 0.9216 - val_jaccard_index: 0.8546
# Epoch 153/200
# 6/6 [==============================] - 52s 10s/step - loss: 0.0056 - accuracy: 0.7399 - dice_coefficient: 0.9478 - jaccard_index: 0.9008 - val_loss: 0.0473 - val_accuracy: 0.6874 - val_dice_coefficient: 0.9113 - val_jaccard_index: 0.8371
# Epoch 154/200
# 6/6 [==============================] - 52s 10s/step - loss: 0.0056 - accuracy: 0.7400 - dice_coefficient: 0.9524 - jaccard_index: 0.9092 - val_loss: 0.0797 - val_accuracy: 0.6635 - val_dice_coefficient: 0.9100 - val_jaccard_index: 0.8350
# Epoch 155/200
# 6/6 [==============================] - 49s 10s/step - loss: 0.0054 - accuracy: 0.7400 - dice_coefficient: 0.9512 - jaccard_index: 0.9070 - val_loss: 0.0509 - val_accuracy: 0.6872 - val_dice_coefficient: 0.9117 - val_jaccard_index: 0.8381
200
# 6/6 [==============================] - 52s 10s/step - loss: 0.0049 - accuracy: 0.7400 - dice_coefficient: 0.9530 - jaccard_index: 0.9103 - val_loss: 0.0385 - val_accuracy: 0.7006 - val_dice_coefficient: 0.8983 - val_jaccard_index: 0.8157
# Epoch 169/200
# 6/6 [==============================] - 49s 10s/step - loss: 0.0048 - accuracy: 0.7400 - dice_coefficient: 0.9577 - jaccard_index: 0.9190 - val_loss: 0.0550 - val_accuracy: 0.6873 - val_dice_coefficient: 0.9116 - val_jaccard_index: 0.8375
# Epoch 170/200
# 6/6 [==============================] - 53s 11s/step - loss: 0.0048 - accuracy: 0.7400 - dice_coefficient: 0.9575 - jaccard_index: 0.9185 - val_loss: 0.0746 - val_accuracy: 0.6737 - val_dice_coefficient: 0.9122 - val_jaccard_index: 0.8387
# Epoch 171/200
# 6/6 [==============================] - 49s 10s/step - loss: 0.0047 - accuracy: 0.7400 - dice_coefficient: 0.9563 - jaccard_index: 0.9164 - val_loss: 0.0614 - val_accuracy: 0.6872 - val_dice_coefficient: 0.9061 - val_jaccard_index: 0.8284
# Epoch 172/200
# 6/6 [==============================] - 52s 10s/step - loss: 0.0046 - accuracy: 0.7400 - dice_coefficient: 0.9581 - jaccard_index: 0.9196 - val_loss: 0.0544 - val_accuracy: 0.6727 - val_dice_coefficient: 0.8924 - val_jaccard_index: 0.8058
# Epoch 173/200
# 6/6 [==============================] - 49s 10s/step - loss: 0.0045 - accuracy: 0.7400 - dice_coefficient: 0.9583 - jaccard_index: 0.9200 - val_loss: 0.0614 - val_accuracy: 0.6871 - val_dice_coefficient: 0.9062 - val_jaccard_index: 0.8285
# Epoch 174/200
# 6/6 [==============================] - 51s 10s/step - loss: 0.0045 - accuracy: 0.7400 - dice_coefficient: 0.9598 - jaccard_index: 0.9228 - val_loss: 0.0589 - val_accuracy: 0.6978 - val_dice_coefficient: 0.9193 - val_jaccard_index: 0.8509
# Epoch 175/200
# 6/6 [==============================] - 51s 10s/step - loss: 0.0044 - accuracy: 0.7400 - dice_coefficient: 0.9597 - jaccard_index: 0.9225 - val_loss: 0.0665 - val_accuracy: 0.6870 - val_dice_coefficient: 0.8985 - val_jaccard_index: 0.8163
# Epoch 176/200
# 6/6 [==============================] - 55s 11s/step - loss: 0.0044 - accuracy: 0.7400 - dice_coefficient: 0.9591 - jaccard_index: 0.9215 - val_loss: 0.0494 - val_accuracy: 0.6701 - val_dice_coefficient: 0.9256 - val_jaccard_index: 0.8614
# Epoch 177/200
# 6/6 [==============================] - 50s 10s/step - loss: 0.0049 - accuracy: 0.7400 - dice_coefficient: 0.9573 - jaccard_index: 0.9181 - val_loss: 0.0498 - val_accuracy: 0.6875 - val_dice_coefficient: 0.9173 - val_jaccard_index: 0.8472
# Epoch 178/200
# 6/6 [==============================] - 50s 10s/step - loss: 0.0049 - accuracy: 0.7400 - dice_coefficient: 0.9569 - jaccard_index: 0.9174 - val_loss: 0.0723 - val_accuracy: 0.6740 - val_dice_coefficient: 0.9162 - val_jaccard_index: 0.8454
# Epoch 179/200
# 6/6 [==============================] - 49s 10s/step - loss: 0.0048 - accuracy: 0.7400 - dice_coefficient: 0.9560 - jaccard_index: 0.9159 - val_loss: 0.0571 - val_accuracy: 0.6871 - val_dice_coefficient: 0.8968 - val_jaccard_index: 0.8136
# Epoch 180/200
# 6/6 [==============================] - 48s 10s/step - loss: 0.0046 - accuracy: 0.7400 - dice_coefficient: 0.9578 - jaccard_index: 0.9191 - val_loss: 0.0630 - val_accuracy: 0.7044 - val_dice_coefficient: 0.8960 - val_jaccard_index: 0.8118
# Epoch 181/200
# 6/6 [==============================] - 52s 10s/step - loss: 0.0046 - accuracy: 0.7400 - dice_coefficient: 0.9589 - jaccard_index: 0.9211 - val_loss: 0.0595 - val_accuracy: 0.6873 - val_dice_coefficient: 0.9168 - val_jaccard_index: 0.8468
# Epoch 182/200
# 6/6 [==============================] - 48s 10s/step - loss: 0.0045 - accuracy: 0.7400 - dice_coefficient: 0.9594 - jaccard_index: 0.9221 - val_loss: 0.0484 - val_accuracy: 0.7005 - val_dice_coefficient: 0.8933 - val_jaccard_index: 0.8074
# Epoch 183/200
# 6/6 [==============================] - 50s 10s/step - loss: 0.0043 - accuracy: 0.7400 - dice_coefficient: 0.9591 - jaccard_index: 0.9215 - val_loss: 0.0669 - val_accuracy: 0.6869 - val_dice_coefficient: 0.9118 - val_jaccard_index: 0.8385
# Epoch 184/200
# 6/6 [==============================] - 50s 10s/step - loss: 0.0043 - accuracy: 0.7400 - dice_coefficient: 0.9605 - jaccard_index: 0.9240 - val_loss: 0.0770 - val_accuracy: 0.6767 - val_dice_coefficient: 0.9046 - val_jaccard_index: 0.8258
# Epoch 185/200
# 6/6 [==============================] - 55s 11s/step - loss: 0.0044 - accuracy: 0.7400 - dice_coefficient: 0.9595 - jaccard_index: 0.9221 - val_loss: 0.0664 - val_accuracy: 0.6871 - val_dice_coefficient: 0.8999 - val_jaccard_index: 0.8186
# Epoch 186/200
# 6/6 [==============================] - 53s 11s/step - loss: 0.0043 - accuracy: 0.7400 - dice_coefficient: 0.9595 - jaccard_index: 0.9223 - val_loss: 0.0732 - val_accuracy: 0.7145 - val_dice_coefficient: 0.8879 - val_jaccard_index: 0.7988
# Epoch 187/200
# 6/6 [==============================] - 53s 10s/step - loss: 0.0041 - accuracy: 0.7400 - dice_coefficient: 0.9611 - jaccard_index: 0.9251 - val_loss: 0.0733 - val_accuracy: 0.6872 - val_dice_coefficient: 0.9153 - val_jaccard_index: 0.8443
# Epoch 188/200
# 6/6 [==============================] - 55s 11s/step - loss: 0.0042 - accuracy: 0.7400 - dice_coefficient: 0.9620 - jaccard_index: 0.9268 - val_loss: 0.0909 - val_accuracy: 0.6763 - val_dice_coefficient: 0.8959 - val_jaccard_index: 0.8115
# Epoch 189/200
# 6/6 [==============================] - 49s 10s/step - loss: 0.0044 - accuracy: 0.7400 - dice_coefficient: 0.9603 - jaccard_index: 0.9238 - val_loss: 0.0787 - val_accuracy: 0.6867 - val_dice_coefficient: 0.8911 - val_jaccard_index: 0.8042
# Epoch 190/200
# 6/6 [==============================] - 49s 10s/step - loss: 0.0045 - accuracy: 0.7400 - dice_coefficient: 0.9597 - jaccard_index: 0.9226 - val_loss: 0.0720 - val_accuracy: 0.6871 - val_dice_coefficient: 0.9107 - val_jaccard_index: 0.8366
# Epoch 191/200
# 6/6 [==============================] - 53s 11s/step - loss: 0.0046 - accuracy: 0.7400 - dice_coefficient: 0.9583 - jaccard_index: 0.9200 - val_loss: 0.0616 - val_accuracy: 0.6874 - val_dice_coefficient: 0.9175 - val_jaccard_index: 0.8477
# Epoch 192/200
# 6/6 [==============================] - 52s 10s/step - loss: 0.0045 - accuracy: 0.7400 - dice_coefficient: 0.9585 - jaccard_index: 0.9203 - val_loss: 0.0819 - val_accuracy: 0.6739 - val_dice_coefficient: 0.9170 - val_jaccard_index: 0.8468
# Epoch 193/200
# 6/6 [==============================] - 55s 11s/step - loss: 0.0042 - accuracy: 0.7400 - dice_coefficient: 0.9605 - jaccard_index: 0.9241 - val_loss: 0.0732 - val_accuracy: 0.6871 - val_dice_coefficient: 0.9011 - val_jaccard_index: 0.8206
# Epoch 194/200
# 6/6 [==============================] - 54s 11s/step - loss: 0.0041 - accuracy: 0.7400 - dice_coefficient: 0.9612 - jaccard_index: 0.9254 - val_loss: 0.0816 - val_accuracy: 0.7015 - val_dice_coefficient: 0.9151 - val_jaccard_index: 0.8435
# Epoch 195/200
# 6/6 [==============================] - 53s 10s/step - loss: 0.0042 - accuracy: 0.7400 - dice_coefficient: 0.9604 - jaccard_index: 0.9238 - val_loss: 0.0669 - val_accuracy: 0.6871 - val_dice_coefficient: 0.9005 - val_jaccard_index: 0.8199
# Epoch 196/200
# 6/6 [==============================] - 51s 10s/step - loss: 0.0040 - accuracy: 0.7400 - dice_coefficient: 0.9621 - jaccard_index: 0.9270 - val_loss: 0.1091 - val_accuracy: 0.6908 - val_dice_coefficient: 0.9035 - val_jaccard_index: 0.8241
# Epoch 197/200
# 6/6 [==============================] - 52s 10s/step - loss: 0.0038 - accuracy: 0.7400 - dice_coefficient: 0.9630 - jaccard_index: 0.9287 - val_loss: 0.0791 - val_accuracy: 0.6872 - val_dice_coefficient: 0.9113 - val_jaccard_index: 0.8371
# Epoch 198/200
# 6/6 [==============================] - 51s 10s/step - loss: 0.0042 - accuracy: 0.7400 - dice_coefficient: 0.9626 - jaccard_index: 0.9278 - val_loss: 0.0793 - val_accuracy: 0.6740 - val_dice_coefficient: 0.9216 - val_jaccard_index: 0.8547
# Epoch 199/200
# 6/6 [==============================] - 52s 10s/step - loss: 0.0045 - accuracy: 0.7400 - dice_coefficient: 0.9584 - jaccard_index: 0.9203 - val_loss: 0.0682 - val_accuracy: 0.6872 - val_dice_coefficient: 0.9096 - val_jaccard_index: 0.8342
# Epoch 200/200
# 6/6 [==============================] - 54s 11s/step - loss: 0.0043 - accuracy: 0.7400 - dice_coefficient: 0.9610 - jaccard_index: 0.9249 - val_loss: 0.0620 - val_accuracy: 0.6593 - val_dice_coefficient: 0.9125 - val_jaccard_index: 0.8392
# 2/2 [==============================] - 19s 19s/step - loss: 0.0440 - accuracy: 0.8564 - dice_coefficient: 0.8615 - jaccard_index: 0.7568
# Test Loss: 0.044023312628269196
# Test Accuracy: 0.8563785552978516
# Test Dice Coefficient: 0.861528754234314
# Test Jaccard Index: 0.7567802667617798

# %%
def display_results_with_marching_cubes(model, file_list, data_path, mask_path, num_images=25):
    target_shape = (128, 128, 64)  # Fixed shape for all volumes
    num_images = min(num_images, len(file_list))  # Ensure we do not exceed the number of files
    
    for i in range(num_images):
        # Load image and mask
        image_file_path = os.path.join(data_path, file_list[i])
        mask_file_path = os.path.join(mask_path, file_list[i])
        
        print(f"Processing file {i+1}/{num_images}: {file_list[i]}")
        
        try:
            image = nib.load(image_file_path).get_fdata(dtype=np.float32)
            mask = nib.load(mask_file_path).get_fdata(dtype=np.float32)
            
            # Resize image and mask to expected shape
            image = resize_image(image, target_shape[:2])
            mask = resize_image(mask, target_shape[:2])
            
            # Pad or crop image and mask to match target depth
            image = pad_or_crop_volume(image, target_shape)
            mask = pad_or_crop_volume(mask, target_shape)
            
            # Preprocess image and mask
            image = image[..., np.newaxis]
            mask = mask[..., np.newaxis]

            # Get prediction
            prediction = model.predict(np.expand_dims(image, axis=0))[0, ..., 0]
            
            # Calculate the volume
            voxel_volume = np.prod(image.shape) / np.sum(mask > 0)  # Example volume calculation
            liver_volume = calculate_volume(mask, voxel_volume)
            print(f"Calculated volume for {file_list[i]}: {liver_volume:.2f} cubic units")

            # 3D Visualization using marching cubes
            verts, faces, _, _ = marching_cubes(mask[..., 0], level=0.5)
            fig = plt.figure(figsize=(12, 6))

            # Subplot 1: Original Data (image slice)
            ax1 = fig.add_subplot(131)
            ax1.imshow(image[:, :, target_shape[2] // 2, 0], cmap='gray')
            ax1.set_title("Image Slice")
            ax1.axis('off')

            # Subplot 2: Ground Truth Mask (slice)
            ax2 = fig.add_subplot(132)
            ax2.imshow(mask[:, :, target_shape[2] // 2, 0], cmap='gray')
            ax2.set_title("Mask Slice")
            ax2.axis('off')

            # Subplot 3: 3D Reconstructed Surface
            ax3 = fig.add_subplot(133, projection='3d')
            mesh = Poly3DCollection(verts[faces], alpha=0.7, edgecolor='none')
            ax3.add_collection3d(mesh)
            ax3.set_xlim(0, mask.shape[0])
            ax3.set_ylim(0, mask.shape[1])
            ax3.set_zlim(0, mask.shape[2])
            ax3.set_title("3D Reconstructed Surface")
            ax3.set_xlabel("X axis")
            ax3.set_ylabel("Y axis")
            ax3.set_zlabel("Z axis")

            plt.tight_layout()
            plt.show()
        
        except Exception as e:
            print(f"Error processing file {file_list[i]}: {e}")

# Call the updated function
display_results_with_marching_cubes(model, val_files, data_path, mask_path)
# Out:
# Processing file 1/4: Dliver9A.nii.gz
# 1/1 [==============================] - 4s 4s/step
# Calculated volume for Dliver9A.nii.gz: 903930.66 cubic units
# Processing file 2/4: Dliver7A.nii.gz
# 1/1 [==============================] - 0s 39ms/step
# Calculated volume for Dliver7A.nii.gz: 840915.49 cubic units
# Processing file 3/4: Dliver16A.nii.gz
# 1/1 [==============================] - 0s 26ms/step
# Calculated volume for Dliver16A.nii.gz: 786437.59 cubic units
# Processing file 4/4: Dliver6A.nii.gz
# 1/1 [==============================] - 0s 27ms/step
# Calculated volume for Dliver6A.nii.gz: 815949.66 cubic units
