# %%
from skimage.measure import marching_cubes
from mpl_toolkits.mplot3d.art3d import Poly3DCollection

# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
# Requirement already satisfied: numpy>=1.23.2 in ./myenv_py311/lib/python3.11/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./myenv_py311/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in ./myenv_py311/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 4.7 MB/s eta 0:00:00a 0:00:01
# Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Using cached tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.2.3 pytz-2024.2 tzdata-2024.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import numpy as np
import cv2
import nibabel as nib
import pandas as pd
#%matplotlib inline
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv3D, MaxPooling3D, UpSampling3D, concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.callbacks import Callback 
from skimage.transform import resize
from mpl_toolkits.mplot3d import Axes3D
import tensorflow as tf
import scipy.ndimage
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 5
#       3 import cv2
#       4 import nibabel as nib
# ----> 5 import pandas as pd
#       6 #%matplotlib inline
#       7 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# Function to load NIfTI files with memory mapping
def load_nifti_memmap(file_path):
    img = nib.load(file_path)
    data = img.get_fdata(dtype=np.float32, caching='unchanged')  # Memory-mapped array
    affine = img.affine
    header = img.header
    return data, affine, header

# Generator function to load data in batches
def data_generator(file_list, data_path, mask_path, batch_size, target_shape=None):
    while True:
        np.random.shuffle(file_list)
        for start in range(0, len(file_list), batch_size):
            end = min(start + batch_size, len(file_list))
            batch_files = file_list[start:end]
            
            X_batch = []
            y_batch = []
            
            for filename in batch_files:
                img_path = os.path.join(data_path, filename)
                corresponding_mask_path = os.path.join(mask_path, filename)
                
                image, _, _ = load_nifti_memmap(img_path)
                mask, _, _ = load_nifti_memmap(corresponding_mask_path)
                
                # Ensure image and mask have the same shape (and possibly resize if needed)
                if target_shape:
                    image = resize_volume(image, target_shape)
                    mask = resize_volume(mask, target_shape)
                
                X_batch.append(image)
                y_batch.append(mask)
            
            X_batch = np.array(X_batch)[..., np.newaxis]  # Adding channel dimension
            y_batch = np.array(y_batch)[..., np.newaxis]  # Adding channel dimension
            
            yield X_batch, y_batch

# Function to resize volumes (if needed)
def resize_volume(img, target_shape):
    current_shape = img.shape
    if current_shape == target_shape:
        return img
    # Example: using scipy for interpolation
    resized_img = scipy.ndimage.zoom(img, (target_shape[0]/current_shape[0], target_shape[1]/current_shape[1], target_shape[2]/current_shape[2]), order=3)
    return resized_img

def resize_image(image, target_shape):
    # Resize the image to match the target shape (height, width)
    return resize(image, target_shape, preserve_range=True, anti_aliasing=True)

def pad_or_crop_volume(volume, target_shape):
    current_shape = volume.shape
    
    # Calculate padding width for each dimension
    pad_width = [(0, max(target_shape[i] - current_shape[i], 0)) for i in range(3)]
    
    # Pad the volume to the target shape
    volume = np.pad(volume, pad_width, mode='constant', constant_values=0)
    
    # Calculate cropping dimensions for each dimension
    crop_start = [(volume.shape[i] - target_shape[i]) // 2 for i in range(3)]
    crop_end = [crop_start[i] + target_shape[i] for i in range(3)]
    
    # Crop the volume to the target shape
    slices = [slice(crop_start[i], crop_end[i]) for i in range(3)]
    volume = volume[slices[0], slices[1], slices[2]]
    
    return volume

def calculate_volume(mask, voxel_volume):
    # Calculate the volume based on the mask
    return np.sum(mask) * voxel_volume
    
def unet_3d(input_shape):
    inputs = Input(input_shape)
    
    # Downsampling
    c1 = Conv3D(32, (3, 3, 3), activation='relu', padding='same')(inputs)
    c1 = Conv3D(32, (3, 3, 3), activation='relu', padding='same')(c1)
    c1 = Conv3D(32, (3, 3, 3), activation='relu', padding='same')(c1)  # Added layer
    c1 = Conv3D(32, (3, 3, 3), activation='relu', padding='same')(c1)  # Added layer
    p1 = MaxPooling3D((2, 2, 2))(c1)
    
    c2 = Conv3D(64, (3, 3, 3), activation='relu', padding='same')(p1)
    c2 = Conv3D(64, (3, 3, 3), activation='relu', padding='same')(c2)
    c2 = Conv3D(64, (3, 3, 3), activation='relu', padding='same')(c2)  # Added layer
    c2 = Conv3D(64, (3, 3, 3), activation='relu', padding='same')(c2)  # Added layer
    p2 = MaxPooling3D((2, 2, 2))(c2)
    
    c3 = Conv3D(128, (3, 3, 3), activation='relu', padding='same')(p2)
    c3 = Conv3D(128, (3, 3, 3), activation='relu', padding='same')(c3)
    c3 = Conv3D(128, (3, 3, 3), activation='relu', padding='same')(c3)  # Added layer
    c3 = Conv3D(128, (3, 3, 3), activation='relu', padding='same')(c3)  # Added layer
    p3 = MaxPooling3D((2, 2, 2))(c3)
    
    c4 = Conv3D(256, (3, 3, 3), activation='relu', padding='same')(p3)
    c4 = Conv3D(256, (3, 3, 3), activation='relu', padding='same')(c4)
    c4 = Conv3D(256, (3, 3, 3), activation='relu', padding='same')(c4)  # Added layer
    c4 = Conv3D(256, (3, 3, 3), activation='relu', padding='same')(c4)  # Added layer
    
    # Upsampling
    u5 = UpSampling3D((2, 2, 2))(c4)
    u5 = concatenate([u5, c3])
    c5 = Conv3D(128, (3, 3, 3), activation='relu', padding='same')(u5)
    c5 = Conv3D(128, (3, 3, 3), activation='relu', padding='same')(c5)
    c5 = Conv3D(128, (3, 3, 3), activation='relu', padding='same')(c5)  # Added layer
    c5 = Conv3D(128, (3, 3, 3), activation='relu', padding='same')(c5)  # Added layer
    
    u6 = UpSampling3D((2, 2, 2))(c5)
    u6 = concatenate([u6, c2])
    c6 = Conv3D(64, (3, 3, 3), activation='relu', padding='same')(u6)
    c6 = Conv3D(64, (3, 3, 3), activation='relu', padding='same')(c6)
    c6 = Conv3D(64, (3, 3, 3), activation='relu', padding='same')(c6)  # Added layer
    c6 = Conv3D(64, (3, 3, 3), activation='relu', padding='same')(c6)  # Added layer
    
    u7 = UpSampling3D((2, 2, 2))(c6)
    u7 = concatenate([u7, c1])
    c7 = Conv3D(32, (3, 3, 3), activation='relu', padding='same')(u7)
    c7 = Conv3D(32, (3, 3, 3), activation='relu', padding='same')(c7)
    c7 = Conv3D(32, (3, 3, 3), activation='relu', padding='same')(c7)  # Added layer
    c7 = Conv3D(32, (3, 3, 3), activation='relu', padding='same')(c7)  # Added layer

    outputs = Conv3D(1, (1, 1, 1), activation='sigmoid')(c7)
    
    return Model(inputs, outputs)

    model = Model(inputs=[inputs], outputs=[outputs])
    return model
    
    model = Model(inputs, outputs)
    #model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy', dice_coefficient, jaccard_index])
    return model

# Dice coefficient
def dice_coefficient(y_true, y_pred):
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) + 1)

# Jaccard index
def jaccard_index(y_true, y_pred):
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
    return (intersection + 1) / (tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) - intersection + 1)

# Example paths (update these to your dataset paths)
#data_path = r'/home/icmr/Documents/DATASET/MSD_LIVER/Portal/Train/imageTr'  # Update with the correct path
#mask_path = r'/home/icmr/Documents/DATASET/MSD_LIVER/Portal/Train/LabelTr'  # Update with the correct path

# Paths for data and masks
train_data_path = r'/home/icmr/Documents/DATASET/MSD_LIVER/Portal/Train/imageTr'
train_mask_path = r'/home/icmr/Documents/DATASET/MSD_LIVER/Portal/Train/LabelTr'

val_data_path = r'/home/icmr/Documents/DATASET/MSD_LIVER/Portal/Val/imageVal'
val_mask_path = r'/home/icmr/Documents/DATASET/MSD_LIVER/Portal/Val/LabelVal'

test_data_path = r'/home/icmr/Documents/DATASET/MSD_LIVER/Portal/Test/imageTs'
test_mask_path = r'/home/icmr/Documents/DATASET/MSD_LIVER/Portal/Test/LabelTs'
'''
# Verify paths exist
if not os.path.exists(data_path):
    raise FileNotFoundError(f"Data path not found: {data_path}")
if not os.path.exists(mask_path):
    raise FileNotFoundError(f"Mask path not found: {mask_path}")
'''
# Verify paths exist
for path in [train_data_path, train_mask_path, val_data_path, val_mask_path, test_data_path, test_mask_path]:
    if not os.path.exists(path):
        raise FileNotFoundError(f"Path not found: {path}")


# List of files
#file_list = [filename for filename in os.listdir(data_path) if filename.endswith('.nii.gz')]
#file_list_test = 
# Split the dataset
#train_val_files, test_files = train_test_split(file_list, test_size=0.2, random_state=42)
#train_files, val_files = train_test_split(train_val_files, test_size=0.25, random_state=42)  # 0.25 * 0.8 = 0.2

# File lists for each dataset
train_files = [filename for filename in os.listdir(train_data_path) if filename.endswith('.nii.gz')]
val_files = [filename for filename in os.listdir(val_data_path) if filename.endswith('.nii.gz')]
test_files = [filename for filename in os.listdir(test_data_path) if filename.endswith('.nii.gz')]


# Define and compile the model
input_shape = (128, 128, 64, 1)  # Example input shape, adjust accordingly
model = unet_3d(input_shape)
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy', dice_coefficient, jaccard_index])
  
# Define callbacks
#checkpoint = ModelCheckpoint('unet3d_best_model.h5', save_best_only=True, monitor='val_loss', mode='min')
#early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Define batch size
batch_size = 2
'''
# Create data generators
train_generator = data_generator(train_files, data_path, mask_path, batch_size, target_shape=input_shape[:3])
val_generator = data_generator(val_files, data_path, mask_path, batch_size, target_shape=input_shape[:3])
test_generator = data_generator(test_files, data_path, mask_path, batch_size, target_shape=input_shape[:3])
'''
# Data generators
train_generator = data_generator(train_files, train_data_path, train_mask_path, batch_size, target_shape=input_shape[:3])
val_generator = data_generator(val_files, val_data_path, val_mask_path, batch_size, target_shape=input_shape[:3])
test_generator = data_generator(test_files, test_data_path, test_mask_path, batch_size, target_shape=input_shape[:3])


# Calculate steps per epoch
steps_per_epoch = len(train_files) // batch_size
validation_steps = len(val_files) // batch_size
test_steps = len(test_files) // batch_size

# Train the model
#history = model.fit(train_generator, validation_data=val_generator, epochs=200, steps_per_epoch=steps_per_epoch, validation_steps=validation_steps, callbacks=[checkpoint])

# Save the model
model.save('unet3d_model.h5')

# Define custom callback for metrics
class MetricsLogger(Callback):
    def __init__(self, val_generator, val_steps, test_generator, test_steps):
        super().__init__()
        self.val_generator = val_generator
        self.val_steps = val_steps
        self.test_generator = test_generator
        self.test_steps = test_steps
        self.logs = []

    def on_epoch_end(self, epoch, logs=None):
        # Evaluate on validation set
        val_loss, val_accuracy, val_dice, val_jaccard = self.model.evaluate(
            self.val_generator, steps=self.val_steps, verbose=0
        )
        # Evaluate on test set
        test_loss, test_accuracy, test_dice, test_jaccard = self.model.evaluate(
            self.test_generator, steps=self.test_steps, verbose=0
        )
        # Log metrics
        self.logs.append({
            'epoch': epoch + 1,
            'train_loss': logs.get('loss'),
            'train_accuracy': logs.get('accuracy'),
            'val_loss': val_loss,
            'val_accuracy': val_accuracy,
            'val_dice': val_dice,
            'val_jaccard': val_jaccard,
            'test_loss': test_loss,
            'test_accuracy': test_accuracy,
            'test_dice': test_dice,
            'test_jaccard': test_jaccard,
        })
        print(f"Epoch {epoch + 1}: "
              f"Train Loss: {logs.get('loss')}, Train Accuracy: {logs.get('accuracy')}, "
              f"Val Loss: {val_loss}, Val Accuracy: {val_accuracy}, "
              f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")

# Define callbacks
checkpoint = ModelCheckpoint('unet3d_best_model.h5', save_best_only=True, monitor='val_loss', mode='min')
metrics_logger = MetricsLogger(val_generator, validation_steps, test_generator, test_steps)

# Train the model
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=200,
    steps_per_epoch=steps_per_epoch,
    validation_steps=validation_steps,
    callbacks=[checkpoint, metrics_logger]
)

# Final evaluation on test set
final_test_loss, final_test_accuracy, final_test_dice, final_test_jaccard = model.evaluate(
    test_generator, steps=test_steps
)
print("\nFinal Test Metrics:")
print(f"Test Loss: {final_test_loss}")
print(f"Test Accuracy: {final_test_accuracy}")
print(f"Test Dice Coefficient: {final_test_dice}")
print(f"Test Jaccard Index: {final_test_jaccard}")

# Save metrics logs
import pandas as pd
metrics_df = pd.DataFrame(metrics_logger.logs)
metrics_df.to_csv('metrics_log.csv', index=False)

# Display metrics as a table
print("\nMetrics per Epoch:")
print(metrics_df)
# Out:
# Epoch 1/200
# 2025-01-02 13:33:14.792684: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8902
# 2025-01-02 13:33:15.178452: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2025-01-02 13:33:15.899759: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2025-01-02 13:33:23.068544: I external/local_xla/xla/service/service.cc:168] XLA service 0x7e26f62fb720 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-01-02 13:33:23.068580: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2025-01-02 13:33:23.086843: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1735805003.249205   26176 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 21/21 [==============================] - ETA: 0s - loss: 297.0812 - accuracy: 0.7387 - dice_coefficient: 0.0842 - jaccard_index: 0.0461 Epoch 1: Train Loss: 297.0812072753906, Train Accuracy: 0.7386783957481384, Val Loss: 0.9292182922363281, Val Accuracy: 0.9188788533210754, Test Loss: 0.6909465789794922, Test Accuracy: 0.9072973132133484
# 21/21 [==============================] - 1057s 51s/step - loss: 297.0812 - accuracy: 0.7387 - dice_coefficient: 0.0842 - jaccard_index: 0.0461 - val_loss: 0.8529 - val_accuracy: 0.9196 - val_dice_coefficient: 2.5050e-05 - val_jaccard_index: 2.5042e-05
# Epoch 2/200
# 21/21 [==============================] - ETA: 0s - loss: 0.5386 - accuracy: 0.8078 - dice_coefficient: 0.0377 - jaccard_index: 0.0201 Epoch 2: Train Loss: 0.5385604500770569, Train Accuracy: 0.807770848274231, Val Loss: 0.09953001141548157, Val Accuracy: 0.9197618365287781, Test Loss: 0.08982580900192261, Test Accuracy: 0.9069165587425232
# 21/21 [==============================] - 1034s 52s/step - loss: 0.5386 - accuracy: 0.8078 - dice_coefficient: 0.0377 - jaccard_index: 0.0201 - val_loss: 0.0967 - val_accuracy: 0.9207 - val_dice_coefficient: 0.0928 - val_jaccard_index: 0.0487
# Epoch 3/200
# 21/21 [==============================] - ETA: 0s - loss: 0.1184 - accuracy: 0.8106 - dice_coefficient: 0.1504 - jaccard_index: 0.0824 Epoch 3: Train Loss: 0.11837004125118256, Train Accuracy: 0.8106353282928467, Val Loss: 0.08315442502498627, Val Accuracy: 0.9181401133537292, Test Loss: 0.07774960994720459, Test Accuracy: 0.9073582887649536
# 21/21 [==============================] - 970s 48s/step - loss: 0.1184 - accuracy: 0.8106 - dice_coefficient: 0.1504 - jaccard_index: 0.0824 - val_loss: 0.0842 - val_accuracy: 0.9163 - val_dice_coefficient: 0.1452 - val_jaccard_index: 0.0784
# Epoch 4/200
# 21/21 [==============================] - ETA: 0s - loss: 0.1306 - accuracy: 0.8110 - dice_coefficient: 0.1760 - jaccard_index: 0.0975Epoch 4: Train Loss: 0.13062913715839386, Train Accuracy: 0.8109976649284363, Val Loss: 0.08228295296430588, Val Accuracy: 0.9183052182197571, Test Loss: 0.08441072702407837, Test Accuracy: 0.9031333923339844
# 21/21 [==============================] - 951s 48s/step - loss: 0.1306 - accuracy: 0.8110 - dice_coefficient: 0.1760 - jaccard_index: 0.0975 - val_loss: 0.0762 - val_accuracy: 0.9214 - val_dice_coefficient: 0.1697 - val_jaccard_index: 0.0928
# Epoch 5/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0945 - accuracy: 0.8108 - dice_coefficient: 0.2034 - jaccard_index: 0.1139Epoch 5: Train Loss: 0.09454186260700226, Train Accuracy: 0.8108445405960083, Val Loss: 0.07482952624559402, Val Accuracy: 0.9160129427909851, Test Loss: 0.06932367384433746, Test Accuracy: 0.905190646648407
# 21/21 [==============================] - 838s 42s/step - loss: 0.0945 - accuracy: 0.8108 - dice_coefficient: 0.2034 - jaccard_index: 0.1139 - val_loss: 0.0699 - val_accuracy: 0.9235 - val_dice_coefficient: 0.2003 - val_jaccard_index: 0.1115
# Epoch 6/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0934 - accuracy: 0.8113 - dice_coefficient: 0.2259 - jaccard_index: 0.1278Epoch 6: Train Loss: 0.09341196715831757, Train Accuracy: 0.8113458752632141, Val Loss: 0.06872417777776718, Val Accuracy: 0.9199352264404297, Test Loss: 0.06659837067127228, Test Accuracy: 0.9021428823471069
# 21/21 [==============================] - 748s 37s/step - loss: 0.0934 - accuracy: 0.8113 - dice_coefficient: 0.2259 - jaccard_index: 0.1278 - val_loss: 0.0696 - val_accuracy: 0.9197 - val_dice_coefficient: 0.1953 - val_jaccard_index: 0.1085
# Epoch 7/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0887 - accuracy: 0.8116 - dice_coefficient: 0.2307 - jaccard_index: 0.1308Epoch 7: Train Loss: 0.08869479596614838, Train Accuracy: 0.8115764856338501, Val Loss: 0.06286638230085373, Val Accuracy: 0.9209403991699219, Test Loss: 0.05982377752661705, Test Accuracy: 0.90802001953125
# 21/21 [==============================] - 770s 38s/step - loss: 0.0887 - accuracy: 0.8116 - dice_coefficient: 0.2307 - jaccard_index: 0.1308 - val_loss: 0.0633 - val_accuracy: 0.9197 - val_dice_coefficient: 0.2288 - val_jaccard_index: 0.1293
# Epoch 8/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0821 - accuracy: 0.8115 - dice_coefficient: 0.2673 - jaccard_index: 0.1547Epoch 8: Train Loss: 0.08214876055717468, Train Accuracy: 0.8114970922470093, Val Loss: 0.05943787842988968, Val Accuracy: 0.9204216003417969, Test Loss: 0.056154198944568634, Test Accuracy: 0.9080455899238586
# 21/21 [==============================] - 764s 38s/step - loss: 0.0821 - accuracy: 0.8115 - dice_coefficient: 0.2673 - jaccard_index: 0.1547 - val_loss: 0.0601 - val_accuracy: 0.9184 - val_dice_coefficient: 0.2611 - val_jaccard_index: 0.1505
# Epoch 9/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0788 - accuracy: 0.8120 - dice_coefficient: 0.2818 - jaccard_index: 0.1644Epoch 9: Train Loss: 0.07876788824796677, Train Accuracy: 0.8119508028030396, Val Loss: 0.05187896639108658, Val Accuracy: 0.9223867654800415, Test Loss: 0.05084133520722389, Test Accuracy: 0.9074314832687378
# 21/21 [==============================] - 743s 37s/step - loss: 0.0788 - accuracy: 0.8120 - dice_coefficient: 0.2818 - jaccard_index: 0.1644 - val_loss: 0.0546 - val_accuracy: 0.9190 - val_dice_coefficient: 0.2759 - val_jaccard_index: 0.1602
# Epoch 10/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0738 - accuracy: 0.8121 - dice_coefficient: 0.3138 - jaccard_index: 0.1867Epoch 10: Train Loss: 0.07377823442220688, Train Accuracy: 0.8120677471160889, Val Loss: 0.056727319955825806, Val Accuracy: 0.9134081602096558, Test Loss: 0.04794567823410034, Test Accuracy: 0.9159975051879883
# 21/21 [==============================] - 767s 38s/step - loss: 0.0738 - accuracy: 0.8121 - dice_coefficient: 0.3138 - jaccard_index: 0.1867 - val_loss: 0.0518 - val_accuracy: 0.9239 - val_dice_coefficient: 0.2953 - val_jaccard_index: 0.1734
# Epoch 11/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0692 - accuracy: 0.8123 - dice_coefficient: 0.3488 - jaccard_index: 0.2117Epoch 11: Train Loss: 0.06919819116592407, Train Accuracy: 0.8122590184211731, Val Loss: 0.04671595245599747, Val Accuracy: 0.9280972480773926, Test Loss: 0.04777485132217407, Test Accuracy: 0.9057248830795288
# 21/21 [==============================] - 751s 38s/step - loss: 0.0692 - accuracy: 0.8123 - dice_coefficient: 0.3488 - jaccard_index: 0.2117 - val_loss: 0.0494 - val_accuracy: 0.9209 - val_dice_coefficient: 0.3176 - val_jaccard_index: 0.1893
# Epoch 12/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0641 - accuracy: 0.8133 - dice_coefficient: 0.3839 - jaccard_index: 0.2384Epoch 12: Train Loss: 0.06408195942640305, Train Accuracy: 0.8133244514465332, Val Loss: 0.04467359930276871, Val Accuracy: 0.9236653447151184, Test Loss: 0.041868600994348526, Test Accuracy: 0.9118195176124573
# 21/21 [==============================] - 793s 40s/step - loss: 0.0641 - accuracy: 0.8133 - dice_coefficient: 0.3839 - jaccard_index: 0.2384 - val_loss: 0.0489 - val_accuracy: 0.9175 - val_dice_coefficient: 0.3909 - val_jaccard_index: 0.2433
# Epoch 13/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0659 - accuracy: 0.8148 - dice_coefficient: 0.3879 - jaccard_index: 0.2424Epoch 13: Train Loss: 0.06592189520597458, Train Accuracy: 0.814751148223877, Val Loss: 0.045283056795597076, Val Accuracy: 0.9207412600517273, Test Loss: 0.04364708065986633, Test Accuracy: 0.9067317843437195
# 21/21 [==============================] - 733s 37s/step - loss: 0.0659 - accuracy: 0.8148 - dice_coefficient: 0.3879 - jaccard_index: 0.2424 - val_loss: 0.0459 - val_accuracy: 0.9171 - val_dice_coefficient: 0.4138 - val_jaccard_index: 0.2611
# Epoch 14/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0629 - accuracy: 0.8141 - dice_coefficient: 0.4052 - jaccard_index: 0.2552Epoch 14: Train Loss: 0.06286559253931046, Train Accuracy: 0.8141255974769592, Val Loss: 0.041616253554821014, Val Accuracy: 0.925902247428894, Test Loss: 0.03780781850218773, Test Accuracy: 0.911920428276062
# 21/21 [==============================] - 748s 37s/step - loss: 0.0629 - accuracy: 0.8141 - dice_coefficient: 0.4052 - jaccard_index: 0.2552 - val_loss: 0.0449 - val_accuracy: 0.9179 - val_dice_coefficient: 0.3647 - val_jaccard_index: 0.2232
# Epoch 15/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0580 - accuracy: 0.8169 - dice_coefficient: 0.4452 - jaccard_index: 0.2875Epoch 15: Train Loss: 0.05804527550935745, Train Accuracy: 0.8168579936027527, Val Loss: 0.04428035393357277, Val Accuracy: 0.9199716448783875, Test Loss: 0.03762977197766304, Test Accuracy: 0.9105888605117798
# 21/21 [==============================] - 762s 38s/step - loss: 0.0580 - accuracy: 0.8169 - dice_coefficient: 0.4452 - jaccard_index: 0.2875 - val_loss: 0.0447 - val_accuracy: 0.9200 - val_dice_coefficient: 0.3821 - val_jaccard_index: 0.2366
# Epoch 16/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0799 - accuracy: 0.8100 - dice_coefficient: 0.3733 - jaccard_index: 0.2352Epoch 16: Train Loss: 0.07986835390329361, Train Accuracy: 0.8100218772888184, Val Loss: 0.06102942302823067, Val Accuracy: 0.9140233993530273, Test Loss: 0.05695480480790138, Test Accuracy: 0.9053949117660522
# 21/21 [==============================] - 733s 37s/step - loss: 0.0799 - accuracy: 0.8100 - dice_coefficient: 0.3733 - jaccard_index: 0.2352 - val_loss: 0.0567 - val_accuracy: 0.9178 - val_dice_coefficient: 0.3525 - val_jaccard_index: 0.2146
# Epoch 17/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0687 - accuracy: 0.8120 - dice_coefficient: 0.3395 - jaccard_index: 0.2050Epoch 17: Train Loss: 0.06873258203268051, Train Accuracy: 0.8119937181472778, Val Loss: 0.04789787530899048, Val Accuracy: 0.9170390963554382, Test Loss: 0.04346093162894249, Test Accuracy: 0.9052333235740662
# 21/21 [==============================] - 740s 37s/step - loss: 0.0687 - accuracy: 0.8120 - dice_coefficient: 0.3395 - jaccard_index: 0.2050 - val_loss: 0.0431 - val_accuracy: 0.9268 - val_dice_coefficient: 0.3330 - val_jaccard_index: 0.2000
# Epoch 18/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0598 - accuracy: 0.8144 - dice_coefficient: 0.4059 - jaccard_index: 0.2556Epoch 18: Train Loss: 0.05978930741548538, Train Accuracy: 0.8144168853759766, Val Loss: 0.04115638881921768, Val Accuracy: 0.921741783618927, Test Loss: 0.039843715727329254, Test Accuracy: 0.917023241519928
# 21/21 [==============================] - 777s 39s/step - loss: 0.0598 - accuracy: 0.8144 - dice_coefficient: 0.4059 - jaccard_index: 0.2556 - val_loss: 0.0397 - val_accuracy: 0.9200 - val_dice_coefficient: 0.4270 - val_jaccard_index: 0.2716
# Epoch 19/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0539 - accuracy: 0.8183 - dice_coefficient: 0.4646 - jaccard_index: 0.3041Epoch 19: Train Loss: 0.05389247089624405, Train Accuracy: 0.8182536363601685, Val Loss: 0.039116472005844116, Val Accuracy: 0.921025276184082, Test Loss: 0.03457370772957802, Test Accuracy: 0.9072114825248718
# 21/21 [==============================] - 728s 36s/step - loss: 0.0539 - accuracy: 0.8183 - dice_coefficient: 0.4646 - jaccard_index: 0.3041 - val_loss: 0.0368 - val_accuracy: 0.9238 - val_dice_coefficient: 0.4167 - val_jaccard_index: 0.2640
# Epoch 20/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0546 - accuracy: 0.8172 - dice_coefficient: 0.4750 - jaccard_index: 0.3137Epoch 20: Train Loss: 0.054619256407022476, Train Accuracy: 0.8172469139099121, Val Loss: 0.04643874615430832, Val Accuracy: 0.9153434038162231, Test Loss: 0.04367949441075325, Test Accuracy: 0.9110454320907593
# 21/21 [==============================] - 763s 38s/step - loss: 0.0546 - accuracy: 0.8172 - dice_coefficient: 0.4750 - jaccard_index: 0.3137 - val_loss: 0.0466 - val_accuracy: 0.9212 - val_dice_coefficient: 0.4479 - val_jaccard_index: 0.2903
# Epoch 21/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0542 - accuracy: 0.8178 - dice_coefficient: 0.5101 - jaccard_index: 0.3443Epoch 21: Train Loss: 0.05417080223560333, Train Accuracy: 0.8178145885467529, Val Loss: 0.03445892408490181, Val Accuracy: 0.9191944003105164, Test Loss: 0.03301604464650154, Test Accuracy: 0.9089818596839905
# 21/21 [==============================] - 738s 37s/step - loss: 0.0542 - accuracy: 0.8178 - dice_coefficient: 0.5101 - jaccard_index: 0.3443 - val_loss: 0.0347 - val_accuracy: 0.9226 - val_dice_coefficient: 0.5437 - val_jaccard_index: 0.3743
# Epoch 22/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0463 - accuracy: 0.8193 - dice_coefficient: 0.5706 - jaccard_index: 0.4005Epoch 22: Train Loss: 0.04634862765669823, Train Accuracy: 0.8193368315696716, Val Loss: 0.025724628940224648, Val Accuracy: 0.9241483807563782, Test Loss: 0.027247196063399315, Test Accuracy: 0.9129959940910339
# 21/21 [==============================] - 754s 38s/step - loss: 0.0463 - accuracy: 0.8193 - dice_coefficient: 0.5706 - jaccard_index: 0.4005 - val_loss: 0.0306 - val_accuracy: 0.9241 - val_dice_coefficient: 0.5470 - val_jaccard_index: 0.3786
# Epoch 23/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0406 - accuracy: 0.8200 - dice_coefficient: 0.6069 - jaccard_index: 0.4382Epoch 23: Train Loss: 0.040554795414209366, Train Accuracy: 0.820030927658081, Val Loss: 0.02550778165459633, Val Accuracy: 0.924290657043457, Test Loss: 0.02555304765701294, Test Accuracy: 0.9113443493843079
# 21/21 [==============================] - 734s 37s/step - loss: 0.0406 - accuracy: 0.8200 - dice_coefficient: 0.6069 - jaccard_index: 0.4382 - val_loss: 0.0267 - val_accuracy: 0.9248 - val_dice_coefficient: 0.6072 - val_jaccard_index: 0.4404
# Epoch 24/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0456 - accuracy: 0.8193 - dice_coefficient: 0.6000 - jaccard_index: 0.4326Epoch 24: Train Loss: 0.04557475075125694, Train Accuracy: 0.8193289637565613, Val Loss: 0.03999009728431702, Val Accuracy: 0.9213696718215942, Test Loss: 0.045524824410676956, Test Accuracy: 0.9089195132255554
# 21/21 [==============================] - 755s 38s/step - loss: 0.0456 - accuracy: 0.8193 - dice_coefficient: 0.6000 - jaccard_index: 0.4326 - val_loss: 0.0428 - val_accuracy: 0.9181 - val_dice_coefficient: 0.5496 - val_jaccard_index: 0.3793
# Epoch 25/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0411 - accuracy: 0.8198 - dice_coefficient: 0.6351 - jaccard_index: 0.4690Epoch 25: Train Loss: 0.04110278561711311, Train Accuracy: 0.8197687268257141, Val Loss: 0.02609271928668022, Val Accuracy: 0.9258106350898743, Test Loss: 0.024346662685275078, Test Accuracy: 0.9100275635719299
# 21/21 [==============================] - 738s 37s/step - loss: 0.0411 - accuracy: 0.8198 - dice_coefficient: 0.6351 - jaccard_index: 0.4690 - val_loss: 0.0269 - val_accuracy: 0.9239 - val_dice_coefficient: 0.6031 - val_jaccard_index: 0.4347
# Epoch 26/200
# 21/21 [==============================] - ETA: 0s - loss: 0.9208 - accuracy: 0.8014 - dice_coefficient: 0.4001 - jaccard_index: 0.2902Epoch 26: Train Loss: 0.9208401441574097, Train Accuracy: 0.8013651967048645, Val Loss: 0.09966801851987839, Val Accuracy: 0.9161927103996277, Test Loss: 0.09092183411121368, Test Accuracy: 0.9056723713874817
# 21/21 [==============================] - 733s 37s/step - loss: 0.9208 - accuracy: 0.8014 - dice_coefficient: 0.4001 - jaccard_index: 0.2902 - val_loss: 0.0950 - val_accuracy: 0.9196 - val_dice_coefficient: 0.0384 - val_jaccard_index: 0.0196
# Epoch 27/200
# 21/21 [==============================] - ETA: 0s - loss: 0.2386 - accuracy: 0.7891 - dice_coefficient: 0.0394 - jaccard_index: 0.0203Epoch 27: Train Loss: 0.23858283460140228, Train Accuracy: 0.7890526652336121, Val Loss: 0.1180461198091507, Val Accuracy: 0.917695164680481, Test Loss: 0.11258187144994736, Test Accuracy: 0.9091719388961792
# 21/21 [==============================] - 760s 38s/step - loss: 0.2386 - accuracy: 0.7891 - dice_coefficient: 0.0394 - jaccard_index: 0.0203 - val_loss: 0.1116 - val_accuracy: 0.9270 - val_dice_coefficient: 0.0348 - val_jaccard_index: 0.0177
# Epoch 28/200
# 21/21 [==============================] - ETA: 0s - loss: 0.1425 - accuracy: 0.8122 - dice_coefficient: 0.0583 - jaccard_index: 0.0303Epoch 28: Train Loss: 0.14248138666152954, Train Accuracy: 0.8122124671936035, Val Loss: 0.12407615035772324, Val Accuracy: 0.9195510149002075, Test Loss: 0.12297989428043365, Test Accuracy: 0.910525918006897
# 21/21 [==============================] - 756s 38s/step - loss: 0.1425 - accuracy: 0.8122 - dice_coefficient: 0.0583 - jaccard_index: 0.0303 - val_loss: 0.1222 - val_accuracy: 0.9227 - val_dice_coefficient: 0.0528 - val_jaccard_index: 0.0271
# Epoch 29/200
# 21/21 [==============================] - ETA: 0s - loss: 0.2894 - accuracy: 0.8122 - dice_coefficient: 0.0366 - jaccard_index: 0.0188Epoch 29: Train Loss: 0.289379745721817, Train Accuracy: 0.8122124671936035, Val Loss: 0.10565589368343353, Val Accuracy: 0.9193339347839355, Test Loss: 0.10062523931264877, Test Accuracy: 0.9072973132133484
# 21/21 [==============================] - 749s 37s/step - loss: 0.2894 - accuracy: 0.8122 - dice_coefficient: 0.0366 - jaccard_index: 0.0188 - val_loss: 0.1033 - val_accuracy: 0.9217 - val_dice_coefficient: 0.0286 - val_jaccard_index: 0.0145
# Epoch 30/200
# 21/21 [==============================] - ETA: 0s - loss: 0.1518 - accuracy: 0.8122 - dice_coefficient: 0.0321 - jaccard_index: 0.0165Epoch 30: Train Loss: 0.15178431570529938, Train Accuracy: 0.8121970295906067, Val Loss: 0.2146153748035431, Val Accuracy: 0.9240444302558899, Test Loss: 0.2156592756509781, Test Accuracy: 0.9079546928405762
# 21/21 [==============================] - 738s 37s/step - loss: 0.1518 - accuracy: 0.8122 - dice_coefficient: 0.0321 - jaccard_index: 0.0165 - val_loss: 0.2237 - val_accuracy: 0.9095 - val_dice_coefficient: 0.0532 - val_jaccard_index: 0.0274
# Epoch 31/200
# 21/21 [==============================] - ETA: 0s - loss: 0.1498 - accuracy: 0.8122 - dice_coefficient: 0.0391 - jaccard_index: 0.0200Epoch 31: Train Loss: 0.14983458817005157, Train Accuracy: 0.8122082948684692, Val Loss: 0.12919114530086517, Val Accuracy: 0.9138842821121216, Test Loss: 0.11941739171743393, Test Accuracy: 0.9103401899337769
# 21/21 [==============================] - 752s 38s/step - loss: 0.1498 - accuracy: 0.8122 - dice_coefficient: 0.0391 - jaccard_index: 0.0200 - val_loss: 0.1238 - val_accuracy: 0.9196 - val_dice_coefficient: 0.0461 - val_jaccard_index: 0.0236
# Epoch 32/200
# 21/21 [==============================] - ETA: 0s - loss: 0.1478 - accuracy: 0.8122 - dice_coefficient: 0.0453 - jaccard_index: 0.0232Epoch 32: Train Loss: 0.14777855575084686, Train Accuracy: 0.8122124671936035, Val Loss: 0.13446399569511414, Val Accuracy: 0.9237638711929321, Test Loss: 0.13337071239948273, Test Accuracy: 0.9063564538955688
# 21/21 [==============================] - 731s 37s/step - loss: 0.1478 - accuracy: 0.8122 - dice_coefficient: 0.0453 - jaccard_index: 0.0232 - val_loss: 0.1386 - val_accuracy: 0.9149 - val_dice_coefficient: 0.0430 - val_jaccard_index: 0.0220
# Epoch 33/200
# 21/21 [==============================] - ETA: 0s - loss: 0.1687 - accuracy: 0.8122 - dice_coefficient: 0.0362 - jaccard_index: 0.0185Epoch 33: Train Loss: 0.1686885505914688, Train Accuracy: 0.8122090101242065, Val Loss: 0.12154950201511383, Val Accuracy: 0.9195582270622253, Test Loss: 0.1173974871635437, Test Accuracy: 0.9078783988952637
# 21/21 [==============================] - 754s 38s/step - loss: 0.1687 - accuracy: 0.8122 - dice_coefficient: 0.0362 - jaccard_index: 0.0185 - val_loss: 0.1237 - val_accuracy: 0.9153 - val_dice_coefficient: 0.0360 - val_jaccard_index: 0.0184
# Epoch 34/200
# 21/21 [==============================] - ETA: 0s - loss: 0.1491 - accuracy: 0.8122 - dice_coefficient: 0.0330 - jaccard_index: 0.0168Epoch 34: Train Loss: 0.14908452332019806, Train Accuracy: 0.8121987581253052, Val Loss: 0.10680023580789566, Val Accuracy: 0.9140003323554993, Test Loss: 0.09181108325719833, Test Accuracy: 0.9150022268295288
# 21/21 [==============================] - 748s 37s/step - loss: 0.1491 - accuracy: 0.8122 - dice_coefficient: 0.0330 - jaccard_index: 0.0168 - val_loss: 0.0994 - val_accuracy: 0.9169 - val_dice_coefficient: 0.0322 - val_jaccard_index: 0.0164
# Epoch 35/200
# 21/21 [==============================] - ETA: 0s - loss: 0.1408 - accuracy: 0.8122 - dice_coefficient: 0.0369 - jaccard_index: 0.0188Epoch 35: Train Loss: 0.14081571996212006, Train Accuracy: 0.8122044801712036, Val Loss: 0.10617691278457642, Val Accuracy: 0.9163713455200195, Test Loss: 0.10170812904834747, Test Accuracy: 0.9048251509666443
# 21/21 [==============================] - 737s 37s/step - loss: 0.1408 - accuracy: 0.8122 - dice_coefficient: 0.0369 - jaccard_index: 0.0188 - val_loss: 0.0929 - val_accuracy: 0.9268 - val_dice_coefficient: 0.0305 - val_jaccard_index: 0.0155
# Epoch 36/200
# 21/21 [==============================] - ETA: 0s - loss: 0.1355 - accuracy: 0.8122 - dice_coefficient: 0.0423 - jaccard_index: 0.0216Epoch 36: Train Loss: 0.1354597806930542, Train Accuracy: 0.8122124671936035, Val Loss: 0.09556038677692413, Val Accuracy: 0.9171503186225891, Test Loss: 0.09013541042804718, Test Accuracy: 0.9072973132133484
# 21/21 [==============================] - 746s 37s/step - loss: 0.1355 - accuracy: 0.8122 - dice_coefficient: 0.0423 - jaccard_index: 0.0216 - val_loss: 0.0931 - val_accuracy: 0.9196 - val_dice_coefficient: 0.0404 - val_jaccard_index: 0.0207
# Epoch 37/200
# 21/21 [==============================] - ETA: 0s - loss: 0.1549 - accuracy: 0.8122 - dice_coefficient: 0.0535 - jaccard_index: 0.0276Epoch 37: Train Loss: 0.1548895686864853, Train Accuracy: 0.8122005462646484, Val Loss: 0.09368862211704254, Val Accuracy: 0.9175904393196106, Test Loss: 0.08875550329685211, Test Accuracy: 0.9090451598167419
# 21/21 [==============================] - 766s 38s/step - loss: 0.1549 - accuracy: 0.8122 - dice_coefficient: 0.0535 - jaccard_index: 0.0276 - val_loss: 0.0905 - val_accuracy: 0.9172 - val_dice_coefficient: 0.0481 - val_jaccard_index: 0.0247
# Epoch 38/200
# 21/21 [==============================] - ETA: 0s - loss: 0.1303 - accuracy: 0.8122 - dice_coefficient: 0.0550 - jaccard_index: 0.0283Epoch 38: Train Loss: 0.1303091198205948, Train Accuracy: 0.8122121691703796, Val Loss: 0.09223462641239166, Val Accuracy: 0.9195510149002075, Test Loss: 0.09251295030117035, Test Accuracy: 0.8994165062904358
# 21/21 [==============================] - 721s 36s/step - loss: 0.1303 - accuracy: 0.8122 - dice_coefficient: 0.0550 - jaccard_index: 0.0283 - val_loss: 0.0971 - val_accuracy: 0.9178 - val_dice_coefficient: 0.0578 - val_jaccard_index: 0.0298
# Epoch 39/200
# 21/21 [==============================] - ETA: 0s - loss: 0.1245 - accuracy: 0.8122 - dice_coefficient: 0.0729 - jaccard_index: 0.0379Epoch 39: Train Loss: 0.12448004633188248, Train Accuracy: 0.8122082948684692, Val Loss: 0.08624474704265594, Val Accuracy: 0.9169985055923462, Test Loss: 0.07948505133390427, Test Accuracy: 0.908842146396637
# 21/21 [==============================] - 754s 38s/step - loss: 0.1245 - accuracy: 0.8122 - dice_coefficient: 0.0729 - jaccard_index: 0.0379 - val_loss: 0.0806 - val_accuracy: 0.9221 - val_dice_coefficient: 0.0695 - val_jaccard_index: 0.0362
# Epoch 40/200
# 21/21 [==============================] - ETA: 0s - loss: 0.1208 - accuracy: 0.8122 - dice_coefficient: 0.1037 - jaccard_index: 0.0548Epoch 40: Train Loss: 0.12078540772199631, Train Accuracy: 0.8121899366378784, Val Loss: 0.07055892050266266, Val Accuracy: 0.9196773767471313, Test Loss: 0.07131128758192062, Test Accuracy: 0.9070799946784973
# 21/21 [==============================] - 739s 37s/step - loss: 0.1208 - accuracy: 0.8122 - dice_coefficient: 0.1037 - jaccard_index: 0.0548 - val_loss: 0.0752 - val_accuracy: 0.9150 - val_dice_coefficient: 0.1555 - val_jaccard_index: 0.0845
# Epoch 41/200
# 21/21 [==============================] - ETA: 0s - loss: 0.1093 - accuracy: 0.8129 - dice_coefficient: 0.1873 - jaccard_index: 0.1043Epoch 41: Train Loss: 0.10929764062166214, Train Accuracy: 0.8128819465637207, Val Loss: 0.07026635110378265, Val Accuracy: 0.9183593988418579, Test Loss: 0.0695134848356247, Test Accuracy: 0.9183928370475769
# 21/21 [==============================] - 783s 39s/step - loss: 0.1093 - accuracy: 0.8129 - dice_coefficient: 0.1873 - jaccard_index: 0.1043 - val_loss: 0.0707 - val_accuracy: 0.9194 - val_dice_coefficient: 0.2509 - val_jaccard_index: 0.1439
# Epoch 42/200
# 21/21 [==============================] - ETA: 0s - loss: 0.1012 - accuracy: 0.8131 - dice_coefficient: 0.2164 - jaccard_index: 0.1225Epoch 42: Train Loss: 0.10124482214450836, Train Accuracy: 0.813059389591217, Val Loss: 0.06801678240299225, Val Accuracy: 0.9203299283981323, Test Loss: 0.07020629942417145, Test Accuracy: 0.9007517695426941
# 21/21 [==============================] - 741s 37s/step - loss: 0.1012 - accuracy: 0.8131 - dice_coefficient: 0.2164 - jaccard_index: 0.1225 - val_loss: 0.0692 - val_accuracy: 0.9170 - val_dice_coefficient: 0.2967 - val_jaccard_index: 0.1749
# Epoch 43/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0926 - accuracy: 0.8143 - dice_coefficient: 0.2691 - jaccard_index: 0.1568Epoch 43: Train Loss: 0.09260646253824234, Train Accuracy: 0.8143081665039062, Val Loss: 0.07754095643758774, Val Accuracy: 0.9176793098449707, Test Loss: 0.08245345205068588, Test Accuracy: 0.9043858647346497
# 21/21 [==============================] - 750s 37s/step - loss: 0.0926 - accuracy: 0.8143 - dice_coefficient: 0.2691 - jaccard_index: 0.1568 - val_loss: 0.0783 - val_accuracy: 0.9142 - val_dice_coefficient: 0.2932 - val_jaccard_index: 0.1722
# Epoch 44/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0858 - accuracy: 0.8150 - dice_coefficient: 0.3155 - jaccard_index: 0.1884Epoch 44: Train Loss: 0.08578313887119293, Train Accuracy: 0.8149617314338684, Val Loss: 0.05664943903684616, Val Accuracy: 0.9189949035644531, Test Loss: 0.0558292455971241, Test Accuracy: 0.9164885878562927
# 21/21 [==============================] - 759s 38s/step - loss: 0.0858 - accuracy: 0.8150 - dice_coefficient: 0.3155 - jaccard_index: 0.1884 - val_loss: 0.0527 - val_accuracy: 0.9267 - val_dice_coefficient: 0.2790 - val_jaccard_index: 0.1625
# Epoch 45/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0858 - accuracy: 0.8142 - dice_coefficient: 0.3315 - jaccard_index: 0.2002Epoch 45: Train Loss: 0.08575865626335144, Train Accuracy: 0.8142162561416626, Val Loss: 0.043706707656383514, Val Accuracy: 0.9272289276123047, Test Loss: 0.04898810386657715, Test Accuracy: 0.9125030636787415
# 21/21 [==============================] - 732s 37s/step - loss: 0.0858 - accuracy: 0.8142 - dice_coefficient: 0.3315 - jaccard_index: 0.2002 - val_loss: 0.0462 - val_accuracy: 0.9239 - val_dice_coefficient: 0.3596 - val_jaccard_index: 0.2193
# Epoch 46/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0773 - accuracy: 0.8154 - dice_coefficient: 0.3923 - jaccard_index: 0.2452Epoch 46: Train Loss: 0.0773160308599472, Train Accuracy: 0.8153611421585083, Val Loss: 0.05158098414540291, Val Accuracy: 0.9216211438179016, Test Loss: 0.056161198765039444, Test Accuracy: 0.914604663848877
# 21/21 [==============================] - 770s 38s/step - loss: 0.0773 - accuracy: 0.8154 - dice_coefficient: 0.3923 - jaccard_index: 0.2452 - val_loss: 0.0526 - val_accuracy: 0.9208 - val_dice_coefficient: 0.3753 - val_jaccard_index: 0.2320
# Epoch 47/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0767 - accuracy: 0.8152 - dice_coefficient: 0.3470 - jaccard_index: 0.2117Epoch 47: Train Loss: 0.07668594270944595, Train Accuracy: 0.81524658203125, Val Loss: 0.04126758128404617, Val Accuracy: 0.9191427230834961, Test Loss: 0.048524778336286545, Test Accuracy: 0.9126906394958496
# 21/21 [==============================] - 731s 37s/step - loss: 0.0767 - accuracy: 0.8152 - dice_coefficient: 0.3470 - jaccard_index: 0.2117 - val_loss: 0.0417 - val_accuracy: 0.9220 - val_dice_coefficient: 0.4425 - val_jaccard_index: 0.2850
# Epoch 48/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0717 - accuracy: 0.8161 - dice_coefficient: 0.4306 - jaccard_index: 0.2756Epoch 48: Train Loss: 0.07169324904680252, Train Accuracy: 0.8161175847053528, Val Loss: 0.04275824502110481, Val Accuracy: 0.9240677952766418, Test Loss: 0.04600781574845314, Test Accuracy: 0.9112081527709961
# 21/21 [==============================] - 765s 38s/step - loss: 0.0717 - accuracy: 0.8161 - dice_coefficient: 0.4306 - jaccard_index: 0.2756 - val_loss: 0.0444 - val_accuracy: 0.9225 - val_dice_coefficient: 0.4089 - val_jaccard_index: 0.2588
# Epoch 49/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0683 - accuracy: 0.8170 - dice_coefficient: 0.4246 - jaccard_index: 0.2712Epoch 49: Train Loss: 0.06830966472625732, Train Accuracy: 0.8169603943824768, Val Loss: 0.0410735085606575, Val Accuracy: 0.9181047677993774, Test Loss: 0.042667124420404434, Test Accuracy: 0.9112053513526917
# 21/21 [==============================] - 741s 37s/step - loss: 0.0683 - accuracy: 0.8170 - dice_coefficient: 0.4246 - jaccard_index: 0.2712 - val_loss: 0.0394 - val_accuracy: 0.9285 - val_dice_coefficient: 0.4259 - val_jaccard_index: 0.2709
# Epoch 50/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0665 - accuracy: 0.8167 - dice_coefficient: 0.4459 - jaccard_index: 0.2896Epoch 50: Train Loss: 0.06653834134340286, Train Accuracy: 0.8166961669921875, Val Loss: 0.041781820356845856, Val Accuracy: 0.9249194264411926, Test Loss: 0.04240349680185318, Test Accuracy: 0.9111725687980652
# 21/21 [==============================] - 753s 38s/step - loss: 0.0665 - accuracy: 0.8167 - dice_coefficient: 0.4459 - jaccard_index: 0.2896 - val_loss: 0.0387 - val_accuracy: 0.9307 - val_dice_coefficient: 0.3929 - val_jaccard_index: 0.2458
# Epoch 51/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0618 - accuracy: 0.8175 - dice_coefficient: 0.4765 - jaccard_index: 0.3147Epoch 51: Train Loss: 0.06177089363336563, Train Accuracy: 0.8174979090690613, Val Loss: 0.10099586099386215, Val Accuracy: 0.9038594365119934, Test Loss: 0.10904733091592789, Test Accuracy: 0.8876411318778992
# 21/21 [==============================] - 742s 37s/step - loss: 0.0618 - accuracy: 0.8175 - dice_coefficient: 0.4765 - jaccard_index: 0.3147 - val_loss: 0.1086 - val_accuracy: 0.8951 - val_dice_coefficient: 0.2565 - val_jaccard_index: 0.1477
# Epoch 52/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0674 - accuracy: 0.8154 - dice_coefficient: 0.4275 - jaccard_index: 0.2733Epoch 52: Train Loss: 0.06742420792579651, Train Accuracy: 0.8154057264328003, Val Loss: 0.03584732860326767, Val Accuracy: 0.9223984479904175, Test Loss: 0.038583964109420776, Test Accuracy: 0.9159470796585083
# 21/21 [==============================] - 744s 37s/step - loss: 0.0674 - accuracy: 0.8154 - dice_coefficient: 0.4275 - jaccard_index: 0.2733 - val_loss: 0.0381 - val_accuracy: 0.9212 - val_dice_coefficient: 0.4738 - val_jaccard_index: 0.3117
# Epoch 53/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0584 - accuracy: 0.8178 - dice_coefficient: 0.4903 - jaccard_index: 0.3275Epoch 53: Train Loss: 0.058438170701265335, Train Accuracy: 0.8178237080574036, Val Loss: 0.0348082073032856, Val Accuracy: 0.9246301651000977, Test Loss: 0.040315888822078705, Test Accuracy: 0.9076279997825623
# 21/21 [==============================] - 724s 36s/step - loss: 0.0584 - accuracy: 0.8178 - dice_coefficient: 0.4903 - jaccard_index: 0.3275 - val_loss: 0.0354 - val_accuracy: 0.9234 - val_dice_coefficient: 0.5731 - val_jaccard_index: 0.4029
# Epoch 54/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0582 - accuracy: 0.8178 - dice_coefficient: 0.4903 - jaccard_index: 0.3266Epoch 54: Train Loss: 0.05816163495182991, Train Accuracy: 0.8178272247314453, Val Loss: 0.03610113263130188, Val Accuracy: 0.9204131960868835, Test Loss: 0.035014282912015915, Test Accuracy: 0.9149432182312012
# 21/21 [==============================] - 758s 38s/step - loss: 0.0582 - accuracy: 0.8178 - dice_coefficient: 0.4903 - jaccard_index: 0.3266 - val_loss: 0.0322 - val_accuracy: 0.9260 - val_dice_coefficient: 0.5367 - val_jaccard_index: 0.3673
# Epoch 55/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0536 - accuracy: 0.8183 - dice_coefficient: 0.5361 - jaccard_index: 0.3680Epoch 55: Train Loss: 0.05356030911207199, Train Accuracy: 0.8183390498161316, Val Loss: 0.03065674379467964, Val Accuracy: 0.919700026512146, Test Loss: 0.038079023361206055, Test Accuracy: 0.9148337244987488
# 21/21 [==============================] - 765s 38s/step - loss: 0.0536 - accuracy: 0.8183 - dice_coefficient: 0.5361 - jaccard_index: 0.3680 - val_loss: 0.0307 - val_accuracy: 0.9326 - val_dice_coefficient: 0.5421 - val_jaccard_index: 0.3724
# Epoch 56/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0509 - accuracy: 0.8187 - dice_coefficient: 0.5403 - jaccard_index: 0.3736Epoch 56: Train Loss: 0.050937339663505554, Train Accuracy: 0.8186720609664917, Val Loss: 0.027771130204200745, Val Accuracy: 0.9285807609558105, Test Loss: 0.033610764890909195, Test Accuracy: 0.9114103317260742
# 21/21 [==============================] - 741s 37s/step - loss: 0.0509 - accuracy: 0.8187 - dice_coefficient: 0.5403 - jaccard_index: 0.3736 - val_loss: 0.0285 - val_accuracy: 0.9258 - val_dice_coefficient: 0.6010 - val_jaccard_index: 0.4314
# Epoch 57/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0507 - accuracy: 0.8189 - dice_coefficient: 0.5691 - jaccard_index: 0.3996Epoch 57: Train Loss: 0.05070391669869423, Train Accuracy: 0.8189388513565063, Val Loss: 0.029277270659804344, Val Accuracy: 0.9317784309387207, Test Loss: 0.031783439218997955, Test Accuracy: 0.9131451845169067
# 21/21 [==============================] - 747s 37s/step - loss: 0.0507 - accuracy: 0.8189 - dice_coefficient: 0.5691 - jaccard_index: 0.3996 - val_loss: 0.0282 - val_accuracy: 0.9210 - val_dice_coefficient: 0.6059 - val_jaccard_index: 0.4357
# Epoch 58/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0461 - accuracy: 0.8194 - dice_coefficient: 0.5925 - jaccard_index: 0.4242Epoch 58: Train Loss: 0.046098753809928894, Train Accuracy: 0.8193519115447998, Val Loss: 0.034313637763261795, Val Accuracy: 0.9248115420341492, Test Loss: 0.04235363006591797, Test Accuracy: 0.9079331159591675
# 21/21 [==============================] - 730s 36s/step - loss: 0.0461 - accuracy: 0.8194 - dice_coefficient: 0.5925 - jaccard_index: 0.4242 - val_loss: 0.0361 - val_accuracy: 0.9249 - val_dice_coefficient: 0.5278 - val_jaccard_index: 0.3596
# Epoch 59/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0471 - accuracy: 0.8194 - dice_coefficient: 0.5637 - jaccard_index: 0.3955Epoch 59: Train Loss: 0.04713810607790947, Train Accuracy: 0.8194449543952942, Val Loss: 0.03270523250102997, Val Accuracy: 0.9269797205924988, Test Loss: 0.033259663730859756, Test Accuracy: 0.9111682176589966
# 21/21 [==============================] - 739s 37s/step - loss: 0.0471 - accuracy: 0.8194 - dice_coefficient: 0.5637 - jaccard_index: 0.3955 - val_loss: 0.0289 - val_accuracy: 0.9283 - val_dice_coefficient: 0.5477 - val_jaccard_index: 0.3783
# Epoch 60/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0429 - accuracy: 0.8197 - dice_coefficient: 0.6081 - jaccard_index: 0.4402Epoch 60: Train Loss: 0.042919863015413284, Train Accuracy: 0.819739818572998, Val Loss: 0.026720833033323288, Val Accuracy: 0.9185290336608887, Test Loss: 0.03932247683405876, Test Accuracy: 0.9141404032707214
# 21/21 [==============================] - 768s 38s/step - loss: 0.0429 - accuracy: 0.8197 - dice_coefficient: 0.6081 - jaccard_index: 0.4402 - val_loss: 0.0306 - val_accuracy: 0.9268 - val_dice_coefficient: 0.5062 - val_jaccard_index: 0.3419
# Epoch 61/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0475 - accuracy: 0.8192 - dice_coefficient: 0.5739 - jaccard_index: 0.4075Epoch 61: Train Loss: 0.04746519774198532, Train Accuracy: 0.8192445039749146, Val Loss: 0.029348086565732956, Val Accuracy: 0.9246990084648132, Test Loss: 0.03347790241241455, Test Accuracy: 0.9073347449302673
# 21/21 [==============================] - 735s 37s/step - loss: 0.0475 - accuracy: 0.8192 - dice_coefficient: 0.5739 - jaccard_index: 0.4075 - val_loss: 0.0302 - val_accuracy: 0.9256 - val_dice_coefficient: 0.5512 - val_jaccard_index: 0.3825
# Epoch 62/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0441 - accuracy: 0.8195 - dice_coefficient: 0.6247 - jaccard_index: 0.4573Epoch 62: Train Loss: 0.04410993307828903, Train Accuracy: 0.8195287585258484, Val Loss: 0.030160892754793167, Val Accuracy: 0.9291203618049622, Test Loss: 0.029334839433431625, Test Accuracy: 0.9212965369224548
# 21/21 [==============================] - 750s 37s/step - loss: 0.0441 - accuracy: 0.8195 - dice_coefficient: 0.6247 - jaccard_index: 0.4573 - val_loss: 0.0285 - val_accuracy: 0.9258 - val_dice_coefficient: 0.5828 - val_jaccard_index: 0.4117
# Epoch 63/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0404 - accuracy: 0.8203 - dice_coefficient: 0.6154 - jaccard_index: 0.4478Epoch 63: Train Loss: 0.04036444053053856, Train Accuracy: 0.8202753663063049, Val Loss: 0.022700276225805283, Val Accuracy: 0.9264794588088989, Test Loss: 0.029898375272750854, Test Accuracy: 0.9132566452026367
# 21/21 [==============================] - 747s 37s/step - loss: 0.0404 - accuracy: 0.8203 - dice_coefficient: 0.6154 - jaccard_index: 0.4478 - val_loss: 0.0213 - val_accuracy: 0.9286 - val_dice_coefficient: 0.6593 - val_jaccard_index: 0.4941
# Epoch 64/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0365 - accuracy: 0.8206 - dice_coefficient: 0.6684 - jaccard_index: 0.5056Epoch 64: Train Loss: 0.036542825400829315, Train Accuracy: 0.820559024810791, Val Loss: 0.02508143149316311, Val Accuracy: 0.9287121891975403, Test Loss: 0.030209321528673172, Test Accuracy: 0.9138297438621521
# 21/21 [==============================] - 746s 37s/step - loss: 0.0365 - accuracy: 0.8206 - dice_coefficient: 0.6684 - jaccard_index: 0.5056 - val_loss: 0.0113 - val_accuracy: 0.9225 - val_dice_coefficient: 0.6973 - val_jaccard_index: 0.5374
# Epoch 65/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0378 - accuracy: 0.8203 - dice_coefficient: 0.6462 - jaccard_index: 0.4817Epoch 65: Train Loss: 0.037764910608530045, Train Accuracy: 0.8202946186065674, Val Loss: 0.014606447890400887, Val Accuracy: 0.9276756048202515, Test Loss: 0.03541385754942894, Test Accuracy: 0.9152392745018005
# 21/21 [==============================] - 740s 37s/step - loss: 0.0378 - accuracy: 0.8203 - dice_coefficient: 0.6462 - jaccard_index: 0.4817 - val_loss: -3.6520e-04 - val_accuracy: 0.9216 - val_dice_coefficient: 0.6558 - val_jaccard_index: 0.4959
# Epoch 66/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0485 - accuracy: 0.8190 - dice_coefficient: 0.5554 - jaccard_index: 0.3935Epoch 66: Train Loss: 0.04853684455156326, Train Accuracy: 0.8190043568611145, Val Loss: 0.024291450157761574, Val Accuracy: 0.9285340309143066, Test Loss: 0.030613897368311882, Test Accuracy: 0.9140615463256836
# 21/21 [==============================] - 755s 38s/step - loss: 0.0485 - accuracy: 0.8190 - dice_coefficient: 0.5554 - jaccard_index: 0.3935 - val_loss: 0.0189 - val_accuracy: 0.9261 - val_dice_coefficient: 0.6274 - val_jaccard_index: 0.4598
# Epoch 67/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0435 - accuracy: 0.8197 - dice_coefficient: 0.6187 - jaccard_index: 0.4549Epoch 67: Train Loss: 0.0434759221971035, Train Accuracy: 0.8196665644645691, Val Loss: 0.024219688028097153, Val Accuracy: 0.9281374216079712, Test Loss: 0.03677794337272644, Test Accuracy: 0.9152957797050476
# 21/21 [==============================] - 753s 38s/step - loss: 0.0435 - accuracy: 0.8197 - dice_coefficient: 0.6187 - jaccard_index: 0.4549 - val_loss: 0.0247 - val_accuracy: 0.9292 - val_dice_coefficient: 0.5287 - val_jaccard_index: 0.3605
# Epoch 68/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0478 - accuracy: 0.8196 - dice_coefficient: 0.5922 - jaccard_index: 0.4301Epoch 68: Train Loss: 0.04783334583044052, Train Accuracy: 0.8196360468864441, Val Loss: 0.02306721732020378, Val Accuracy: 0.9250448346138, Test Loss: 0.04212697595357895, Test Accuracy: 0.906260073184967
# 21/21 [==============================] - 735s 37s/step - loss: 0.0478 - accuracy: 0.8196 - dice_coefficient: 0.5922 - jaccard_index: 0.4301 - val_loss: 0.0237 - val_accuracy: 0.9245 - val_dice_coefficient: 0.5667 - val_jaccard_index: 0.4020
# Epoch 69/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0681 - accuracy: 0.8166 - dice_coefficient: 0.3793 - jaccard_index: 0.2587Epoch 69: Train Loss: 0.068113774061203, Train Accuracy: 0.8166121244430542, Val Loss: 0.04240450635552406, Val Accuracy: 0.9237293004989624, Test Loss: 0.04423728585243225, Test Accuracy: 0.9145928621292114
# 21/21 [==============================] - 751s 38s/step - loss: 0.0681 - accuracy: 0.8166 - dice_coefficient: 0.3793 - jaccard_index: 0.2587 - val_loss: 0.0511 - val_accuracy: 0.9206 - val_dice_coefficient: 0.3783 - val_jaccard_index: 0.2377
# Epoch 70/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0548 - accuracy: 0.8195 - dice_coefficient: 0.5531 - jaccard_index: 0.3896Epoch 70: Train Loss: 0.05481191352009773, Train Accuracy: 0.8194746375083923, Val Loss: 0.045194029808044434, Val Accuracy: 0.9194710850715637, Test Loss: 0.04458291083574295, Test Accuracy: 0.9073163270950317
# 21/21 [==============================] - 752s 38s/step - loss: 0.0548 - accuracy: 0.8195 - dice_coefficient: 0.5531 - jaccard_index: 0.3896 - val_loss: 0.0535 - val_accuracy: 0.9165 - val_dice_coefficient: 0.3170 - val_jaccard_index: 0.1895
# Epoch 71/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0463 - accuracy: 0.8186 - dice_coefficient: 0.5469 - jaccard_index: 0.3849Epoch 71: Train Loss: 0.04630662128329277, Train Accuracy: 0.8185840845108032, Val Loss: 0.03405188024044037, Val Accuracy: 0.9260514974594116, Test Loss: 0.03683563321828842, Test Accuracy: 0.9120887517929077
# 21/21 [==============================] - 736s 37s/step - loss: 0.0463 - accuracy: 0.8186 - dice_coefficient: 0.5469 - jaccard_index: 0.3849 - val_loss: 0.0321 - val_accuracy: 0.9235 - val_dice_coefficient: 0.5425 - val_jaccard_index: 0.3789
# Epoch 72/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0376 - accuracy: 0.8198 - dice_coefficient: 0.6519 - jaccard_index: 0.4916Epoch 72: Train Loss: 0.037591107189655304, Train Accuracy: 0.8198353052139282, Val Loss: -0.00865238718688488, Val Accuracy: 0.9241287112236023, Test Loss: 0.03437936305999756, Test Accuracy: 0.9129192233085632
# 21/21 [==============================] - 760s 38s/step - loss: 0.0376 - accuracy: 0.8198 - dice_coefficient: 0.6519 - jaccard_index: 0.4916 - val_loss: -0.0601 - val_accuracy: 0.9247 - val_dice_coefficient: 0.6132 - val_jaccard_index: 0.4467
# Epoch 73/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0569 - accuracy: 0.8184 - dice_coefficient: 0.5168 - jaccard_index: 0.3534Epoch 73: Train Loss: 0.056874435395002365, Train Accuracy: 0.8183513879776001, Val Loss: 0.04139820113778114, Val Accuracy: 0.9232577085494995, Test Loss: 0.0393281914293766, Test Accuracy: 0.9087939858436584
# 21/21 [==============================] - 748s 37s/step - loss: 0.0569 - accuracy: 0.8184 - dice_coefficient: 0.5168 - jaccard_index: 0.3534 - val_loss: 0.0407 - val_accuracy: 0.9240 - val_dice_coefficient: 0.4237 - val_jaccard_index: 0.2714
# Epoch 74/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0443 - accuracy: 0.8198 - dice_coefficient: 0.6048 - jaccard_index: 0.4385Epoch 74: Train Loss: 0.04426802322268486, Train Accuracy: 0.8198420405387878, Val Loss: 0.03179601579904556, Val Accuracy: 0.9224891662597656, Test Loss: 0.03371052071452141, Test Accuracy: 0.9175516366958618
# 21/21 [==============================] - 753s 38s/step - loss: 0.0443 - accuracy: 0.8198 - dice_coefficient: 0.6048 - jaccard_index: 0.4385 - val_loss: 0.0345 - val_accuracy: 0.9231 - val_dice_coefficient: 0.5294 - val_jaccard_index: 0.3674
# Epoch 75/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0331 - accuracy: 0.8195 - dice_coefficient: 0.6492 - jaccard_index: 0.4932Epoch 75: Train Loss: 0.03306835517287254, Train Accuracy: 0.8194518089294434, Val Loss: -0.05290114879608154, Val Accuracy: 0.9202979207038879, Test Loss: 0.07082385569810867, Test Accuracy: 0.9154223203659058
# 21/21 [==============================] - 740s 37s/step - loss: 0.0331 - accuracy: 0.8195 - dice_coefficient: 0.6492 - jaccard_index: 0.4932 - val_loss: 0.0138 - val_accuracy: 0.9287 - val_dice_coefficient: 0.5861 - val_jaccard_index: 0.4202
# Epoch 76/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0568 - accuracy: 0.8160 - dice_coefficient: 0.4731 - jaccard_index: 0.3302Epoch 76: Train Loss: 0.05676749348640442, Train Accuracy: 0.8160277605056763, Val Loss: 0.04574928060173988, Val Accuracy: 0.9237270355224609, Test Loss: 0.05102235823869705, Test Accuracy: 0.9102965593338013
# 21/21 [==============================] - 741s 37s/step - loss: 0.0568 - accuracy: 0.8160 - dice_coefficient: 0.4731 - jaccard_index: 0.3302 - val_loss: 0.0475 - val_accuracy: 0.9199 - val_dice_coefficient: 0.3784 - val_jaccard_index: 0.2342
# Epoch 77/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0550 - accuracy: 0.8178 - dice_coefficient: 0.5391 - jaccard_index: 0.3794Epoch 77: Train Loss: 0.0549628809094429, Train Accuracy: 0.8178207874298096, Val Loss: 0.025695255026221275, Val Accuracy: 0.9240492582321167, Test Loss: 0.036092907190322876, Test Accuracy: 0.9106190800666809
# 21/21 [==============================] - 742s 37s/step - loss: 0.0550 - accuracy: 0.8178 - dice_coefficient: 0.5391 - jaccard_index: 0.3794 - val_loss: 0.0183 - val_accuracy: 0.9212 - val_dice_coefficient: 0.6497 - val_jaccard_index: 0.4853
# Epoch 78/200
# 21/21 [==============================] - ETA: 0s - loss: 0.0617 - accuracy: 0.8175 - dice_coefficient: 0.5000 - jaccard_index: 0.3540Epoch 78: Train Loss: 0.06169359013438225, Train Accuracy: 0.8175301551818848, Val Loss: 0.034085772931575775, Val Accuracy: 0.9236017465591431, Test Loss: 0.03456810489296913, Test Accuracy: 0.9111534357070923
# 21/21 [==============================] - 748s 37s/step - loss: 0.0617 - accuracy: 0.8175 - dice_coefficient: 0.5000 - jaccard_index: 0.3540 - val_loss: 0.0339 - val_accuracy: 0.9225 - val_dice_coefficient: 0.5079 - val_jaccard_index: 0.3417
# Epoch 79/200
# ...
# 21/21 [==============================] - 744s 37s/step - loss: 0.1404 - accuracy: 0.8122 - dice_coefficient: 0.0324 - jaccard_index: 0.0165 - val_loss: 0.1120 - val_accuracy: 0.9111 - val_dice_coefficient: 0.0295 - val_jaccard_index: 0.0150
# Epoch 176/200
# 21/21 [==============================] - ETA: 0s - loss: 0.1408 - accuracy: 0.8122 - dice_coefficient: 0.0329 - jaccard_index: 0.0167Epoch 176: Train Loss: 0.14079439640045166, Train Accuracy: 0.8122107982635498, Val Loss: 0.10059845447540283, Val Accuracy: 0.9206011891365051, Test Loss: 0.09534281492233276, Test Accuracy: 0.9072973132133484
# 21/21 [==============================] - 749s 37s/step - loss: 0.1408 - accuracy: 0.8122 - dice_coefficient: 0.0329 - jaccard_index: 0.0167 - val_loss: 0.1011 - val_accuracy: 0.9196 - val_dice_coefficient: 0.0271 - val_jaccard_index: 0.0137
# Epoch 177/200
# 21/21 [==============================] - ETA: 0s - loss: 0.1401 - accuracy: 0.8122 - dice_coefficient: 0.0346 - jaccard_index: 0.0176Epoch 177: Train Loss: 0.14011237025260925, Train Accuracy: 0.8122124671936035, Val Loss: 0.09487820416688919, Val Accuracy: 0.9238488078117371, Test Loss: 0.09422536194324493, Test Accuracy: 0.9081354737281799
# 21/21 [==============================] - 738s 37s/step - loss: 0.1401 - accuracy: 0.8122 - dice_coefficient: 0.0346 - jaccard_index: 0.0176 - val_loss: 0.1026 - val_accuracy: 0.9165 - val_dice_coefficient: 0.0289 - val_jaccard_index: 0.0147
# Epoch 178/200
# 21/21 [==============================] - ETA: 0s - loss: 0.1393 - accuracy: 0.8122 - dice_coefficient: 0.0342 - jaccard_index: 0.0174Epoch 178: Train Loss: 0.13931764662265778, Train Accuracy: 0.812212347984314, Val Loss: 0.09884408861398697, Val Accuracy: 0.9195510149002075, Test Loss: 0.09057917445898056, Test Accuracy: 0.9126786589622498
# 21/21 [==============================] - 740s 37s/step - loss: 0.1393 - accuracy: 0.8122 - dice_coefficient: 0.0342 - jaccard_index: 0.0174 - val_loss: 0.0944 - val_accuracy: 0.9221 - val_dice_coefficient: 0.0265 - val_jaccard_index: 0.0134
# Epoch 179/200
# 21/21 [==============================] - ETA: 0s - loss: 0.1395 - accuracy: 0.8122 - dice_coefficient: 0.0340 - jaccard_index: 0.0173Epoch 179: Train Loss: 0.13948816061019897, Train Accuracy: 0.8122124671936035, Val Loss: 0.10467441380023956, Val Accuracy: 0.9178758859634399, Test Loss: 0.09440813213586807, Test Accuracy: 0.905042827129364
# 21/21 [==============================] - 742s 37s/step - loss: 0.1395 - accuracy: 0.8122 - dice_coefficient: 0.0340 - jaccard_index: 0.0173 - val_loss: 0.0954 - val_accuracy: 0.9211 - val_dice_coefficient: 0.0268 - val_jaccard_index: 0.0136
# Epoch 180/200
# 21/21 [==============================] - ETA: 0s - loss: 0.1392 - accuracy: 0.8122 - dice_coefficient: 0.0339 - jaccard_index: 0.0173Epoch 180: Train Loss: 0.1391906589269638, Train Accuracy: 0.812212347984314, Val Loss: 0.09564997255802155, Val Accuracy: 0.9227787852287292, Test Loss: 0.0941540002822876, Test Accuracy: 0.9070108532905579
# 21/21 [==============================] - 752s 38s/step - loss: 0.1392 - accuracy: 0.8122 - dice_coefficient: 0.0339 - jaccard_index: 0.0173 - val_loss: 0.0943 - val_accuracy: 0.9229 - val_dice_coefficient: 0.0269 - val_jaccard_index: 0.0136
# Epoch 181/200
# 21/21 [==============================] - ETA: 0s - loss: 0.1387 - accuracy: 0.8122 - dice_coefficient: 0.0346 - jaccard_index: 0.0176Epoch 181: Train Loss: 0.13867035508155823, Train Accuracy: 0.8122124671936035, Val Loss: 0.09944862127304077, Val Accuracy: 0.9219155311584473, Test Loss: 0.09590481221675873, Test Accuracy: 0.8992608785629272
# 21/21 [==============================] - 724s 36s/step - loss: 0.1387 - accuracy: 0.8122 - dice_coefficient: 0.0346 - jaccard_index: 0.0176 - val_loss: 0.0990 - val_accuracy: 0.9196 - val_dice_coefficient: 0.0281 - val_jaccard_index: 0.0142
# Epoch 182/200
# 21/21 [==============================] - ETA: 0s - loss: 0.1386 - accuracy: 0.8122 - dice_coefficient: 0.0353 - jaccard_index: 0.0180Epoch 182: Train Loss: 0.13859856128692627, Train Accuracy: 0.8122124671936035, Val Loss: 0.10218237340450287, Val Accuracy: 0.9193387031555176, Test Loss: 0.09261342138051987, Test Accuracy: 0.9077104330062866
# 21/21 [==============================] - 744s 37s/step - loss: 0.1386 - accuracy: 0.8122 - dice_coefficient: 0.0353 - jaccard_index: 0.0180 - val_loss: 0.0971 - val_accuracy: 0.9176 - val_dice_coefficient: 0.0275 - val_jaccard_index: 0.0139
# Epoch 183/200
# 21/21 [==============================] - ETA: 0s - loss: 0.1386 - accuracy: 0.8122 - dice_coefficient: 0.0344 - jaccard_index: 0.0175Epoch 183: Train Loss: 0.13859666883945465, Train Accuracy: 0.8122124671936035, Val Loss: 0.09850259125232697, Val Accuracy: 0.9195510149002075, Test Loss: 0.09252846240997314, Test Accuracy: 0.9072973132133484
# 21/21 [==============================] - 754s 38s/step - loss: 0.1386 - accuracy: 0.8122 - dice_coefficient: 0.0344 - jaccard_index: 0.0175 - val_loss: 0.1010 - val_accuracy: 0.9180 - val_dice_coefficient: 0.0284 - val_jaccard_index: 0.0144
# Epoch 184/200
# 21/21 [==============================] - ETA: 0s - loss: 0.1385 - accuracy: 0.8122 - dice_coefficient: 0.0354 - jaccard_index: 0.0180Epoch 184: Train Loss: 0.13853365182876587, Train Accuracy: 0.8122124671936035, Val Loss: 0.10000953823328018, Val Accuracy: 0.9185476303100586, Test Loss: 0.09432686865329742, Test Accuracy: 0.9069463014602661
# 21/21 [==============================] - 741s 37s/step - loss: 0.1385 - accuracy: 0.8122 - dice_coefficient: 0.0354 - jaccard_index: 0.0180 - val_loss: 0.0998 - val_accuracy: 0.9189 - val_dice_coefficient: 0.0280 - val_jaccard_index: 0.0142
# Epoch 185/200
# 21/21 [==============================] - ETA: 0s - loss: 0.1385 - accuracy: 0.8122 - dice_coefficient: 0.0346 - jaccard_index: 0.0176Epoch 185: Train Loss: 0.138497456908226, Train Accuracy: 0.8122125267982483, Val Loss: 0.09869034588336945, Val Accuracy: 0.9190669059753418, Test Loss: 0.09143243730068207, Test Accuracy: 0.9064592123031616
# 21/21 [==============================] - 750s 37s/step - loss: 0.1385 - accuracy: 0.8122 - dice_coefficient: 0.0346 - jaccard_index: 0.0176 - val_loss: 0.0997 - val_accuracy: 0.9183 - val_dice_coefficient: 0.0280 - val_jaccard_index: 0.0142
# Epoch 186/200
# 21/21 [==============================] - ETA: 0s - loss: 0.1386 - accuracy: 0.8122 - dice_coefficient: 0.0337 - jaccard_index: 0.0172Epoch 186: Train Loss: 0.1386033296585083, Train Accuracy: 0.812212347984314, Val Loss: 0.10085184872150421, Val Accuracy: 0.9186542630195618, Test Loss: 0.09261481463909149, Test Accuracy: 0.906764805316925
# 21/21 [==============================] - 729s 36s/step - loss: 0.1386 - accuracy: 0.8122 - dice_coefficient: 0.0337 - jaccard_index: 0.0172 - val_loss: 0.0989 - val_accuracy: 0.9196 - val_dice_coefficient: 0.0280 - val_jaccard_index: 0.0142
# Epoch 187/200
# 21/21 [==============================] - ETA: 0s - loss: 0.1386 - accuracy: 0.8122 - dice_coefficient: 0.0345 - jaccard_index: 0.0176Epoch 187: Train Loss: 0.13864223659038544, Train Accuracy: 0.8122124671936035, Val Loss: 0.10974438488483429, Val Accuracy: 0.9131223559379578, Test Loss: 0.09274277836084366, Test Accuracy: 0.9083862900733948
# 21/21 [==============================] - 729s 36s/step - loss: 0.1386 - accuracy: 0.8122 - dice_coefficient: 0.0345 - jaccard_index: 0.0176 - val_loss: 0.0964 - val_accuracy: 0.9204 - val_dice_coefficient: 0.0271 - val_jaccard_index: 0.0137
# Epoch 188/200
# 21/21 [==============================] - ETA: 0s - loss: 0.1385 - accuracy: 0.8122 - dice_coefficient: 0.0354 - jaccard_index: 0.0181Epoch 188: Train Loss: 0.1384788304567337, Train Accuracy: 0.812212347984314, Val Loss: 0.0995304211974144, Val Accuracy: 0.9195510149002075, Test Loss: 0.09487688541412354, Test Accuracy: 0.9090242385864258
# 21/21 [==============================] - 756s 38s/step - loss: 0.1385 - accuracy: 0.8122 - dice_coefficient: 0.0354 - jaccard_index: 0.0181 - val_loss: 0.0947 - val_accuracy: 0.9236 - val_dice_coefficient: 0.0270 - val_jaccard_index: 0.0137
# Epoch 189/200
# 21/21 [==============================] - ETA: 0s - loss: 0.1384 - accuracy: 0.8122 - dice_coefficient: 0.0354 - jaccard_index: 0.0181Epoch 189: Train Loss: 0.1383599191904068, Train Accuracy: 0.8122122883796692, Val Loss: 0.09667596966028214, Val Accuracy: 0.9193094968795776, Test Loss: 0.08964250236749649, Test Accuracy: 0.9131200909614563
# 21/21 [==============================] - 745s 37s/step - loss: 0.1384 - accuracy: 0.8122 - dice_coefficient: 0.0354 - jaccard_index: 0.0181 - val_loss: 0.1054 - val_accuracy: 0.9135 - val_dice_coefficient: 0.0297 - val_jaccard_index: 0.0151
# Epoch 190/200
# 21/21 [==============================] - ETA: 0s - loss: 0.1383 - accuracy: 0.8122 - dice_coefficient: 0.0349 - jaccard_index: 0.0178Epoch 190: Train Loss: 0.1383252739906311, Train Accuracy: 0.8122122883796692, Val Loss: 0.10085570812225342, Val Accuracy: 0.9181532859802246, Test Loss: 0.09297000616788864, Test Accuracy: 0.9072973132133484
# 21/21 [==============================] - 743s 37s/step - loss: 0.1383 - accuracy: 0.8122 - dice_coefficient: 0.0349 - jaccard_index: 0.0178 - val_loss: 0.0945 - val_accuracy: 0.9231 - val_dice_coefficient: 0.0270 - val_jaccard_index: 0.0137
# Epoch 191/200
# 21/21 [==============================] - ETA: 0s - loss: 0.1384 - accuracy: 0.8122 - dice_coefficient: 0.0358 - jaccard_index: 0.0183Epoch 191: Train Loss: 0.13838410377502441, Train Accuracy: 0.8122124671936035, Val Loss: 0.10360671579837799, Val Accuracy: 0.9160820841789246, Test Loss: 0.09488549083471298, Test Accuracy: 0.9056400060653687
# 21/21 [==============================] - 726s 36s/step - loss: 0.1384 - accuracy: 0.8122 - dice_coefficient: 0.0358 - jaccard_index: 0.0183 - val_loss: 0.0990 - val_accuracy: 0.9196 - val_dice_coefficient: 0.0280 - val_jaccard_index: 0.0142
# Epoch 192/200
# 21/21 [==============================] - ETA: 0s - loss: 0.1384 - accuracy: 0.8122 - dice_coefficient: 0.0350 - jaccard_index: 0.0179Epoch 192: Train Loss: 0.13835179805755615, Train Accuracy: 0.8122124671936035, Val Loss: 0.09851162135601044, Val Accuracy: 0.9197922945022583, Test Loss: 0.08918266743421555, Test Accuracy: 0.9164136648178101
# 21/21 [==============================] - 779s 39s/step - loss: 0.1384 - accuracy: 0.8122 - dice_coefficient: 0.0350 - jaccard_index: 0.0179 - val_loss: 0.0903 - val_accuracy: 0.9239 - val_dice_coefficient: 0.0255 - val_jaccard_index: 0.0129
# Epoch 193/200
# 21/21 [==============================] - ETA: 0s - loss: 0.1385 - accuracy: 0.8122 - dice_coefficient: 0.0349 - jaccard_index: 0.0178Epoch 193: Train Loss: 0.13852965831756592, Train Accuracy: 0.812212347984314, Val Loss: 0.09775859862565994, Val Accuracy: 0.9195510149002075, Test Loss: 0.09234093129634857, Test Accuracy: 0.9071411490440369
# 21/21 [==============================] - 752s 38s/step - loss: 0.1385 - accuracy: 0.8122 - dice_coefficient: 0.0349 - jaccard_index: 0.0178 - val_loss: 0.1030 - val_accuracy: 0.9151 - val_dice_coefficient: 0.0285 - val_jaccard_index: 0.0145
# Epoch 194/200
# 21/21 [==============================] - ETA: 0s - loss: 0.1382 - accuracy: 0.8122 - dice_coefficient: 0.0340 - jaccard_index: 0.0173Epoch 194: Train Loss: 0.13817916810512543, Train Accuracy: 0.812212347984314, Val Loss: 0.10350514948368073, Val Accuracy: 0.9129583239555359, Test Loss: 0.0938527062535286, Test Accuracy: 0.8992620706558228
# 21/21 [==============================] - 694s 35s/step - loss: 0.1382 - accuracy: 0.8122 - dice_coefficient: 0.0340 - jaccard_index: 0.0173 - val_loss: 0.0987 - val_accuracy: 0.9208 - val_dice_coefficient: 0.0281 - val_jaccard_index: 0.0142
# Epoch 195/200
# 21/21 [==============================] - ETA: 0s - loss: 0.1383 - accuracy: 0.8122 - dice_coefficient: 0.0361 - jaccard_index: 0.0184Epoch 195: Train Loss: 0.13829362392425537, Train Accuracy: 0.812212347984314, Val Loss: 0.10005764663219452, Val Accuracy: 0.9178057909011841, Test Loss: 0.09045714884996414, Test Accuracy: 0.9150293469429016
# 21/21 [==============================] - 762s 38s/step - loss: 0.1383 - accuracy: 0.8122 - dice_coefficient: 0.0361 - jaccard_index: 0.0184 - val_loss: 0.0869 - val_accuracy: 0.9290 - val_dice_coefficient: 0.0251 - val_jaccard_index: 0.0127
# Epoch 196/200
# 21/21 [==============================] - ETA: 0s - loss: 0.1381 - accuracy: 0.8122 - dice_coefficient: 0.0360 - jaccard_index: 0.0184Epoch 196: Train Loss: 0.13813765347003937, Train Accuracy: 0.8122124671936035, Val Loss: 0.10036643594503403, Val Accuracy: 0.9191383123397827, Test Loss: 0.09475570917129517, Test Accuracy: 0.9041872620582581
# 21/21 [==============================] - 732s 37s/step - loss: 0.1381 - accuracy: 0.8122 - dice_coefficient: 0.0360 - jaccard_index: 0.0184 - val_loss: 0.0985 - val_accuracy: 0.9196 - val_dice_coefficient: 0.0282 - val_jaccard_index: 0.0143
# Epoch 197/200
# 21/21 [==============================] - ETA: 0s - loss: 0.1383 - accuracy: 0.8122 - dice_coefficient: 0.0344 - jaccard_index: 0.0175Epoch 197: Train Loss: 0.13825677335262299, Train Accuracy: 0.8122124671936035, Val Loss: 0.09639526158571243, Val Accuracy: 0.9194161295890808, Test Loss: 0.0914841890335083, Test Accuracy: 0.9072973132133484
# 21/21 [==============================] - 739s 37s/step - loss: 0.1383 - accuracy: 0.8122 - dice_coefficient: 0.0344 - jaccard_index: 0.0175 - val_loss: 0.0958 - val_accuracy: 0.9194 - val_dice_coefficient: 0.0268 - val_jaccard_index: 0.0136
# Epoch 198/200
# 21/21 [==============================] - ETA: 0s - loss: 0.1381 - accuracy: 0.8122 - dice_coefficient: 0.0348 - jaccard_index: 0.0177Epoch 198: Train Loss: 0.1380573809146881, Train Accuracy: 0.8122124671936035, Val Loss: 0.099098339676857, Val Accuracy: 0.9195510149002075, Test Loss: 0.0919087752699852, Test Accuracy: 0.907719612121582
# 21/21 [==============================] - 744s 37s/step - loss: 0.1381 - accuracy: 0.8122 - dice_coefficient: 0.0348 - jaccard_index: 0.0177 - val_loss: 0.1045 - val_accuracy: 0.9178 - val_dice_coefficient: 0.0304 - val_jaccard_index: 0.0154
# Epoch 199/200
# 21/21 [==============================] - ETA: 0s - loss: 0.1380 - accuracy: 0.8122 - dice_coefficient: 0.0359 - jaccard_index: 0.0183Epoch 199: Train Loss: 0.13796880841255188, Train Accuracy: 0.8122124671936035, Val Loss: 0.0926121175289154, Val Accuracy: 0.9213325381278992, Test Loss: 0.09147757291793823, Test Accuracy: 0.9105132222175598
# 21/21 [==============================] - 760s 38s/step - loss: 0.1380 - accuracy: 0.8122 - dice_coefficient: 0.0359 - jaccard_index: 0.0183 - val_loss: 0.1044 - val_accuracy: 0.9155 - val_dice_coefficient: 0.0298 - val_jaccard_index: 0.0151
# Epoch 200/200
# 21/21 [==============================] - ETA: 0s - loss: 0.1380 - accuracy: 0.8122 - dice_coefficient: 0.0342 - jaccard_index: 0.0174Epoch 200: Train Loss: 0.13801680505275726, Train Accuracy: 0.8122124671936035, Val Loss: 0.10380514711141586, Val Accuracy: 0.915520191192627, Test Loss: 0.08901964128017426, Test Accuracy: 0.9060125350952148
# 21/21 [==============================] - 709s 35s/step - loss: 0.1380 - accuracy: 0.8122 - dice_coefficient: 0.0342 - jaccard_index: 0.0174 - val_loss: 0.0978 - val_accuracy: 0.9226 - val_dice_coefficient: 0.0277 - val_jaccard_index: 0.0140
# 7/7 [==============================] - 222s 37s/step - loss: 0.0907 - accuracy: 0.9151 - dice_coefficient: 0.0259 - jaccard_index: 0.0131
#
# Final Test Metrics:
# Test Loss: 0.09068445861339569
# Test Accuracy: 0.9150708913803101
# Test Dice Coefficient: 0.025896847248077393
# Test Jaccard Index: 0.013124711811542511
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 286
#     283 print(f"Test Jaccard Index: {final_test_jaccard}")
#     285 # Save metrics logs
# --> 286 import pandas as pd
#     287 metrics_df = pd.DataFrame(metrics_logger.logs)
#     288 metrics_df.to_csv('metrics_log.csv', index=False)
#
# ModuleNotFoundError: No module named 'pandas'

# %%
def display_results(model, file_list, test_data_path, test_mask_path):
    target_shape = (128, 128, 64)  # Fixed shape for all volumes
    
    # Iterate through all files in the file list
    for i in range(len(file_list)):
        # Load image and mask
        image_file_path = os.path.join(test_data_path, file_list[i])
        mask_file_path = os.path.join(test_mask_path, file_list[i])
        
        print(f"Processing file {i+1}/{len(file_list)}: {file_list[i]}")
        
        try:
            # Load image and mask data from .nii files
            image = nib.load(image_file_path).get_fdata(dtype=np.float32)
            mask = nib.load(mask_file_path).get_fdata(dtype=np.float32)
            
            # Resize image and mask to expected shape
            image = resize_image(image, target_shape[:2])
            mask = resize_image(mask, target_shape[:2])
            
            # Pad or crop image and mask to match target depth
            image = pad_or_crop_volume(image, target_shape)
            mask = pad_or_crop_volume(mask, target_shape)
            
            # Preprocess image and mask
            image = image[..., np.newaxis]
            mask = mask[..., np.newaxis]

            # Get prediction
            prediction = model.predict(np.expand_dims(image, axis=0))[0, ..., 0]
            
            # Visualize each slice of the image
            for z in range(target_shape[2]):
                fig, axs = plt.subplots(1, 3, figsize=(15, 5))
                
                # Subplot 1: Original Image Slice
                axs[0].imshow(image[:, :, z, 0], cmap='gray')
                axs[0].set_title(f"Image Slice {z}")
                axs[0].axis('off')

                # Subplot 2: Ground Truth Mask Slice
                axs[1].imshow(mask[:, :, z, 0], cmap='gray')
                axs[1].set_title(f"Mask Slice {z}")
                axs[1].axis('off')

                # Subplot 3: Prediction Slice
                axs[2].imshow(prediction[:, :, z], cmap='gray')
                axs[2].set_title(f"Prediction Slice {z}")
                axs[2].axis('off')

                plt.tight_layout()
                plt.show()
        
        except Exception as e:
            print(f"Error processing file {file_list[i]}: {e}")

# Call the function 
display_results(model, test_data_path, test_mask_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 58
#      55             print(f"Error processing file {file_list[i]}: {e}")
#      57 # Call the function
# ---> 58 display_results(model, test_data_path, test_mask_path)
#
# NameError: name 'model' is not defined
